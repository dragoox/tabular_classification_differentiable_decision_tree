# %% [markdown]
# <h1> Tabular Data Classification with Differentiable Decision Tree.ipynb </h1>
# <h1> Name : Patrick Sutanto </h1>

# %% [markdown]
# # Description
#
# In this notebook, we will conduct classification tasks using four distinct datasets: the Iris dataset, the Pima Indians Diabetes Database, the Breast Cancer Wisconsin (Diagnostic) dataset, and the Adult Dataset. Each dataset represents unique challenges in classification, and our goal is to apply deep learning-based methods to explore and solve these tasks.
#
# - Iris Dataset: This classic dataset consists of measurements from three different Iris species. We'll classify samples into one of these three species based on four features: sepal length, sepal width, petal length, and petal width.
#
# - Pima Indians Diabetes Database: This dataset contains diagnostic data collected from Pima Indian women, with the objective of predicting the onset of diabetes based on various health measurements, such as blood glucose level, body mass index, age, and more.
#
# - Breast Cancer Wisconsin (Diagnostic) Dataset: Here, the task is to classify tumor samples as benign or malignant based on features computed from cell nuclei present in breast mass images. The dataset provides insights into texture, area, smoothness, and other characteristics critical for accurate diagnostics.
#
# - Adult Dataset: This dataset, commonly used in income prediction tasks, includes features such as age, work class, education, occupation, and more. Our goal is to predict whether a person's income exceeds $50,000 per year, based on these socioeconomic factors.
#
# For each dataset, we will use a primary classification method called the Differentiable Decision Tree. This deep learning technique combines the interpretability of traditional decision trees with the flexibility of gradient-based learning, making it well-suited for diverse data types and complex patterns.
#
# In addition to preprocessing each dataset for model compatibility, we will try to use the data augmentation techniques of Mixup and also various regularization method such as and L2 normalization, to enhance model robustness and prevent overfitting. These augmentations aim to create more diverse training data representations, allowing the model to generalize better across unseen examples.
#
# We will preprocess each dataset to ensure compatibility with the Differentiable Decision Tree model, explore underlying data distributions, and adjust hyperparameters to maximize performance. The evaluation process will involve accuracy, macro-F1 score, and a confusion matrix to thoroughly assess model performance across classes. Additionally, we will apply k-fold cross-validation to ensure the model generalizes well across different subsets of the data, promoting robust, reliable results.

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix, f1_score
from copy import deepcopy

# %%
class Node(nn.Module) :
  def __init__(self, num_feature, num_output, num_depth) :
    super(Node, self).__init__()
    self.num_depth = num_depth
    init_std = 0.1

    self.beta = nn.Parameter(torch.randn(1, num_feature)*init_std)
    self.theta = nn.Parameter(torch.randn(1, num_feature)*init_std)
    self.weight_a = nn.Parameter(torch.randn(1)*init_std)


    self.child = []
    if num_depth > 0 :
      self.child_left = Node(num_feature, num_output, num_depth - 1)
      self.child_right = Node(num_feature, num_output, num_depth - 1)
    else :
      self.label_weight = nn.Parameter(torch.randn(1, num_output)*init_std)



  def forward(self, x) :
    # assume x is B x D
    if self.num_depth == 0 :
      return self.label_weight
    else :
      gate_value = torch.sum(x*self.beta - self.theta,dim=-1, keepdim = True)*self.weight_a
      gate_value = torch.sigmoid(gate_value)
      # print(gate_value.shape)

      left_value = self.child_left(x)
      right_value = self.child_right(x)
      value = gate_value*left_value + (1 - gate_value)*right_value
      return value

  def forward_discrete_estimate(self,x) :
    if self.num_depth == 0 :
      return self.label_weight
    else :
      max_index = self.beta.argmax(-1).squeeze()
      to_compare = self.theta.squeeze()[max_index]/self.beta.squeeze()[max_index]
      is_left =  (x[:, max_index:max_index+1]>= to_compare).float()

      value = is_left*self.child_left.forward_discrete_estimate(x) + (1 - is_left)*self.child_right.forward_discrete_estimate(x)


      return value

  def forward_discrete(self,x) :
    if self.num_depth == 0 :
      return self.label_weight.squeeze().argmax()
    else :
      max_index = self.beta.argmax(-1).squeeze()
      to_compare = self.theta.squeeze()[max_index]/self.beta.squeeze()[max_index]
      is_left =  (x[:, max_index] >= to_compare).float()

      gate_value = torch.sum(x*self.beta - self.theta,dim=-1, keepdim = True)*self.weight_a
      gate_value = torch.sigmoid(gate_value)
      value = gate_value*self.child_left(x) + (1 - gate_value)*self.child_right(x)

      value = is_left*self.child_left.forward_discrete(x) + (1 - is_left)*self.child_right.forward_discrete(x)


      return value

  def create_rules(self) :
    self.create_rules_reccur(self.num_depth, True)

  def create_rules_reccur(self, max_depth, is_from_left) :
    if self.num_depth == 0 :
      label_now = self.label_weight.squeeze().argmax()
      label_now = label_now.detach().cpu().numpy()
      num_space = " ".join([""]*4*(max_depth - self.num_depth))
      if self.num_depth != max_depth :
        if is_from_left :
          print(num_space, "LEFT:")
        else :
          print(num_space, "RIGHT:")
      print(num_space, "RETURN", label_now)
    else :
      max_index = self.beta.argmax(-1).squeeze()
      to_compare = self.theta.squeeze()[max_index]/self.beta.squeeze()[max_index]
      # is_left =  (x[:, max_index] >= to_compare).float()

      max_index = max_index.detach().cpu().numpy()
      to_compare =  to_compare.detach().cpu().numpy()
      num_space = " ".join([""]*4*(max_depth - self.num_depth))

      if self.num_depth != max_depth :
        if is_from_left :
          print(num_space, "LEFT:")
        else :
          print(num_space, "RIGHT:")
      print(num_space, "WHEN feature", max_index, "is bigger than", to_compare, "then go to left, else go to right")
      self.child_left.create_rules_reccur(max_depth, True)
      self.child_right.create_rules_reccur(max_depth, False)

# %%
class LinearTree(Node) :
  def __init__(self, num_input, num_feature, num_output, num_depth) :
    super(LinearTree, self).__init__(num_feature, num_output, num_depth)
    self.linear1 = nn.Linear(num_input, num_feature*4)
    self.linear2 = nn.Linear(num_feature*4, num_feature*4)
    self.linear3 = nn.Linear(num_feature*4, num_feature*4)
    self.linear4 = nn.Linear(num_feature*4, num_feature)

  def basic_forward(self, x) :
    yhat = F.relu(self.linear1(x))
    yhat = F.relu(self.linear2(yhat))
    yhat = F.relu(self.linear3(yhat))
    yhat = F.relu(self.linear4(yhat))

    return yhat

  def forward(self, x) :
    # assume x is B x D
    yhat = self.basic_forward(x)
    yhat = super().forward(yhat)

    return yhat

  def forward_discrete_estimate(self,x) :
    yhat = self.basic_forward(x)
    yhat = super().forward_discrete_estimate(yhat)

    return yhat

  def forward_discrete(self,x) :
    yhat = self.basic_forward(x)
    yhat = super().forward_discrete(yhat)

    return yhat

# %%
def train_model(model, x_train, y_train,
                num_iteration = 2000,
                batch_size = 512,
                lr =  6e-4,
                l2_weight = 0,
                ent_weight = 0,
                focus_on_cont = False,
                apply_label_weight = True,
                label_weight_power = 1,
                apply_mixup_aug = True) :
  """
  Input :
  model = Tree model that will be trained
  x_train = all training dataset containing all the feature
  y_train = all training label
  batch_size = use gradient descent if possible, else uses mini batch gradient descent
  lr = learning rate for the optimizers
  l2_weight = weight of the L2 normalization for the feature weight of the tree only
  ent_weight = weight of the entropy normalization for the bias of the tree only
  focus_on_cont = if true, the output is aggregation of all leaf, if not output only 1 leaf
  apply_label_weight = weight the label when the class is imbalanced
  label_weight_power = power of the label_weight, if the label weight is not strong enough
  apply_mixup_aug = use mixup data augmentation or not
  """


  optim = torch.optim.Adam(model.parameters(), lr)
  num_label = int(y_train.max()) + 1
  all_class_label_weight = []
  for label_now_idx in range(num_label) :
    all_class_label_weight.append(np.sum(y_train == label_now_idx))
  all_class_label_weight = np.stack(all_class_label_weight)
  print("Num Label:", all_class_label_weight)
  all_class_label_weight = 1/all_class_label_weight
  all_class_label_weight = all_class_label_weight/all_class_label_weight.min()
  all_class_label_weight = all_class_label_weight**(label_weight_power)

  # all_class_label_weight = np.array([1, 10])
  print("Label Weight:", all_class_label_weight)
  all_class_label_weight = torch.as_tensor(all_class_label_weight).float()

  if apply_mixup_aug :
    batch_size = batch_size*2

  for itr in range(num_iteration) :
    if batch_size >= len(x_train) :
      x_now = torch.as_tensor(x_train.astype(float)).float()
      y_now = torch.LongTensor(y_train)
    else :
      rand_idx = np.random.randint(0, len(x_train), batch_size)
      x_now = torch.as_tensor(x_train[rand_idx].astype(float)).float()
      y_now = torch.LongTensor(y_train[rand_idx])


    loss_weight = all_class_label_weight[y_now].reshape(len(y_now), 1)
    y_now = F.one_hot(y_now, num_label)
    if apply_mixup_aug :
      rand_unif = np.random.rand(len(x_now)//2).reshape(len(x_now)//2, 1)
      rand_unif = torch.as_tensor(rand_unif).float()

      x_now = rand_unif*x_now[:len(x_now)//2] + (1-rand_unif)*x_now[len(x_now)//2:]
      y_now = rand_unif*y_now[:len(y_now)//2] + (1-rand_unif)*y_now[len(y_now)//2:]
      loss_weight = rand_unif*loss_weight[:len(loss_weight)//2] + (1-rand_unif)*loss_weight[len(loss_weight)//2:]

    yhat = model(x_now)
    discrete_yhat = model.forward_discrete_estimate(x_now)

    if not focus_on_cont :
      yhat = torch.softmax(discrete_yhat + yhat - yhat.detach(), -1)
    else :
      yhat = torch.softmax(yhat + discrete_yhat - discrete_yhat.detach(), -1)
    # yhat = torch.softmax(discrete_yhat , -1)


    l2_total = 0
    ent_total = 0
    counter = 0
    for module_now in model.modules() :
      if type(module_now) == Node :
        counter = counter + 1

        beta_prob = torch.softmax(module_now.beta,-1) # *x_now - module_now.theta
        ent_now = -torch.sum(beta_prob*torch.log(beta_prob),-1)
        ent_now = torch.mean(ent_now)

        ent_total = ent_total + ent_now



        l2_now = torch.mean(module_now.theta**2) # torch.mean(module_now.beta**2) +

        l2_total = l2_total + l2_now
    l2_total = l2_total/counter
    ent_total = ent_total/counter

    if apply_label_weight :
      loss = loss_weight* torch.sum(y_now*torch.log(yhat),-1)
    else :
      loss = torch.sum(y_now*torch.log(yhat),-1)
    loss = -torch.mean(loss) + l2_weight*l2_total  + ent_weight*ent_total

    optim.zero_grad()
    loss.backward()
    optim.step()

    if itr % 10 == 0 :
      print(itr, loss)
  return model

# %%
def k_fold(x_all, y_all, num_k = 10, use_mlp = False, normalize = True, **train_config) :
  """
  Input :
  x_all = all dataset containing all the feature
  y_all = all label
  num_k = number of the k in the k-fold
  use_mlp = wether to use MLP to extract feature first
  normalize = wether to normalize the data using z-norm or not
  train_config = the model training configuration
  """

  all_model = []
  all_results = {
      "confusion_matrix":[],
      "accuracy":[],
      "f1_score":[],
  }

  num_incr = len(x_all)//num_k
  for k in range(num_k) :
    x_train = np.concatenate((x_all[:num_incr*k], x_all[num_incr*(k+1):] ), 0)
    x_test = x_all[num_incr*k:num_incr*(k+1)]
    y_train = np.concatenate((y_all[:num_incr*k], y_all[num_incr*(k+1):] ), 0)
    y_test = y_all[num_incr*k:num_incr*(k+1)]

    if normalize :
      x_mu = x_train.mean(0, keepdims = True)
      x_std = np.var(x_train,0, keepdims=True)**(1/2)

      x_train = (x_train - x_mu)/x_std
      x_test = (x_test - x_mu)/x_std

    if use_mlp :
      model = LinearTree(x_train.shape[1], 16 , int(y_all.max() + 1), 3)
    else :
      model = Node(x_train.shape[1], int(y_all.max() + 1), 3)

    print('=============================================================')
    print(x_train.shape, y_train.shape)
    print(x_test.shape, y_test.shape)
    print(model)
    print('=============================================================')
    print(train_config)
    model = train_model(model, x_train, y_train, **train_config)
    all_model.append(deepcopy(model))

    x_now = torch.as_tensor(x_test.astype(float)).float()
    y_now = torch.LongTensor(y_test)
    yhat = model.forward_discrete_estimate(x_now).detach().cpu().numpy()
    y_now = y_now.detach().cpu().numpy()
    yhat = (yhat.argmax(-1))

    all_results['accuracy'].append(np.mean((yhat == y_now)))
    all_results['f1_score'].append(f1_score(y_now, yhat, average='macro'))
    all_results['confusion_matrix'].append(confusion_matrix(y_now, yhat))

    print("RULES:")
    model.create_rules()

    print("accuracy:\n", all_results['accuracy'][-1])
    print("f1_score:\n", all_results['f1_score'][-1])
    print("confusion_matrix:\n", all_results['confusion_matrix'][-1])
  return all_results, all_model

# %% [markdown]
# # Iris Datasets

# %%
# !wget https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv
# Out:
# --2024-10-26 12:03:48--  https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3975 (3.9K) [text/plain]
# Saving to: ‘iris.csv.7’
#
# iris.csv.7          100%[===================>]   3.88K  --.-KB/s    in 0s
#
# 2024-10-26 12:03:48 (43.0 MB/s) - ‘iris.csv.7’ saved [3975/3975]

# %%
iris_dataset = pd.read_csv("/content/iris.csv")
iris_dataset = iris_dataset.to_numpy()
np.random.shuffle(iris_dataset)

x_all = iris_dataset[:,0:4]
y_all = iris_dataset[:,4:]
y_all = (0*(y_all == "Setosa") + 1*(y_all == "Virginica") + 2*(y_all == "Versicolor")).squeeze()

# %%
all_results, all_model = k_fold(x_all, y_all, 10, False, True, batch_size = 64, l2_weight=0.1)
# Out:
# =============================================================
# (135, 4) (135,)
# (15, 4) (15,)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 64, 'l2_weight': 0.1}
# Num Label: [45 46 44]
# Label Weight: [1.02222222 1.         1.04545455]
# 0 tensor(1.1090, grad_fn=<AddBackward0>)
# 10 tensor(1.1030, grad_fn=<AddBackward0>)
# 20 tensor(1.0929, grad_fn=<AddBackward0>)
# 30 tensor(1.0934, grad_fn=<AddBackward0>)
# 40 tensor(1.0854, grad_fn=<AddBackward0>)
# 50 tensor(1.0998, grad_fn=<AddBackward0>)
# 60 tensor(1.0795, grad_fn=<AddBackward0>)
# 70 tensor(1.0901, grad_fn=<AddBackward0>)
# 80 tensor(1.0837, grad_fn=<AddBackward0>)
# 90 tensor(1.0844, grad_fn=<AddBackward0>)
# 100 tensor(1.0698, grad_fn=<AddBackward0>)
# 110 tensor(1.0693, grad_fn=<AddBackward0>)
# 120 tensor(1.0664, grad_fn=<AddBackward0>)
# 130 tensor(1.0856, grad_fn=<AddBackward0>)
# 140 tensor(1.0818, grad_fn=<AddBackward0>)
# 150 tensor(1.0671, grad_fn=<AddBackward0>)
# 160 tensor(1.0601, grad_fn=<AddBackward0>)
# 170 tensor(1.0548, grad_fn=<AddBackward0>)
# 180 tensor(1.0590, grad_fn=<AddBackward0>)
# 190 tensor(1.0410, grad_fn=<AddBackward0>)
# 200 tensor(1.0382, grad_fn=<AddBackward0>)
# 210 tensor(1.0578, grad_fn=<AddBackward0>)
# 220 tensor(1.0425, grad_fn=<AddBackward0>)
# 230 tensor(1.0545, grad_fn=<AddBackward0>)
# 240 tensor(1.0159, grad_fn=<AddBackward0>)
# 250 tensor(1.0501, grad_fn=<AddBackward0>)
# 260 tensor(1.0271, grad_fn=<AddBackward0>)
# 270 tensor(1.0249, grad_fn=<AddBackward0>)
# 280 tensor(1.0447, grad_fn=<AddBackward0>)
# 290 tensor(1.0429, grad_fn=<AddBackward0>)
# 300 tensor(1.0359, grad_fn=<AddBackward0>)
# 310 tensor(1.0342, grad_fn=<AddBackward0>)
# 320 tensor(1.0404, grad_fn=<AddBackward0>)
# 330 tensor(1.0595, grad_fn=<AddBackward0>)
# 340 tensor(1.0341, grad_fn=<AddBackward0>)
# 350 tensor(1.0370, grad_fn=<AddBackward0>)
# 360 tensor(1.0389, grad_fn=<AddBackward0>)
# 370 tensor(1.0088, grad_fn=<AddBackward0>)
# 380 tensor(1.0264, grad_fn=<AddBackward0>)
# 390 tensor(1.0506, grad_fn=<AddBackward0>)
# 400 tensor(1.0430, grad_fn=<AddBackward0>)
# 410 tensor(1.0257, grad_fn=<AddBackward0>)
# 420 tensor(1.0224, grad_fn=<AddBackward0>)
# 430 tensor(1.0124, grad_fn=<AddBackward0>)
# 440 tensor(0.9881, grad_fn=<AddBackward0>)
# 450 tensor(1.0097, grad_fn=<AddBackward0>)
# 460 tensor(0.9982, grad_fn=<AddBackward0>)
# 470 tensor(0.9915, grad_fn=<AddBackward0>)
# 480 tensor(0.9971, grad_fn=<AddBackward0>)
# 490 tensor(0.9801, grad_fn=<AddBackward0>)
# 500 tensor(0.9899, grad_fn=<AddBackward0>)
# 510 tensor(1.0053, grad_fn=<AddBackward0>)
# 520 tensor(1.0093, grad_fn=<AddBackward0>)
# 530 tensor(1.0044, grad_fn=<AddBackward0>)
# 540 tensor(1.0000, grad_fn=<AddBackward0>)
# 550 tensor(0.9485, grad_fn=<AddBackward0>)
# 560 tensor(0.9787, grad_fn=<AddBackward0>)
# 570 tensor(0.9678, grad_fn=<AddBackward0>)
# 580 tensor(0.9838, grad_fn=<AddBackward0>)
# 590 tensor(0.9598, grad_fn=<AddBackward0>)
# 600 tensor(0.9674, grad_fn=<AddBackward0>)
# 610 tensor(0.9671, grad_fn=<AddBackward0>)
# 620 tensor(0.9498, grad_fn=<AddBackward0>)
# 630 tensor(0.9283, grad_fn=<AddBackward0>)
# 640 tensor(0.9623, grad_fn=<AddBackward0>)
# 650 tensor(0.9367, grad_fn=<AddBackward0>)
# 660 tensor(0.9521, grad_fn=<AddBackward0>)
# 670 tensor(0.9173, grad_fn=<AddBackward0>)
# 680 tensor(0.9251, grad_fn=<AddBackward0>)
# 690 tensor(0.9293, grad_fn=<AddBackward0>)
# 700 tensor(0.9297, grad_fn=<AddBackward0>)
# 710 tensor(0.9345, grad_fn=<AddBackward0>)
# 720 tensor(0.9479, grad_fn=<AddBackward0>)
# 730 tensor(0.9100, grad_fn=<AddBackward0>)
# 740 tensor(0.9239, grad_fn=<AddBackward0>)
# 750 tensor(0.9585, grad_fn=<AddBackward0>)
# 760 tensor(0.9102, grad_fn=<AddBackward0>)
# 770 tensor(0.9093, grad_fn=<AddBackward0>)
# 780 tensor(0.8867, grad_fn=<AddBackward0>)
# 790 tensor(0.9193, grad_fn=<AddBackward0>)
# 800 tensor(0.9827, grad_fn=<AddBackward0>)
# 810 tensor(0.9018, grad_fn=<AddBackward0>)
# 820 tensor(0.9528, grad_fn=<AddBackward0>)
# 830 tensor(0.9002, grad_fn=<AddBackward0>)
# 840 tensor(0.8859, grad_fn=<AddBackward0>)
# 850 tensor(0.8995, grad_fn=<AddBackward0>)
# 860 tensor(0.8742, grad_fn=<AddBackward0>)
# 870 tensor(0.9130, grad_fn=<AddBackward0>)
# 880 tensor(0.8631, grad_fn=<AddBackward0>)
# 890 tensor(0.8993, grad_fn=<AddBackward0>)
# 900 tensor(0.9034, grad_fn=<AddBackward0>)
# 910 tensor(0.8665, grad_fn=<AddBackward0>)
# 920 tensor(0.8859, grad_fn=<AddBackward0>)
# 930 tensor(0.8537, grad_fn=<AddBackward0>)
# 940 tensor(0.8517, grad_fn=<AddBackward0>)
# 950 tensor(0.9126, grad_fn=<AddBackward0>)
# 960 tensor(0.9066, grad_fn=<AddBackward0>)
# 970 tensor(0.9633, grad_fn=<AddBackward0>)
# 980 tensor(0.9069, grad_fn=<AddBackward0>)
# 990 tensor(0.9068, grad_fn=<AddBackward0>)
# 1000 tensor(0.8722, grad_fn=<AddBackward0>)
# 1010 tensor(0.8909, grad_fn=<AddBackward0>)
# 1020 tensor(0.8737, grad_fn=<AddBackward0>)
# 1030 tensor(0.8894, grad_fn=<AddBackward0>)
# 1040 tensor(0.8970, grad_fn=<AddBackward0>)
# 1050 tensor(0.8721, grad_fn=<AddBackward0>)
# 1060 tensor(0.9057, grad_fn=<AddBackward0>)
# 1070 tensor(0.8781, grad_fn=<AddBackward0>)
# 1080 tensor(0.8982, grad_fn=<AddBackward0>)
# 1090 tensor(0.8371, grad_fn=<AddBackward0>)
# 1100 tensor(0.8988, grad_fn=<AddBackward0>)
# 1110 tensor(0.9474, grad_fn=<AddBackward0>)
# 1120 tensor(0.9208, grad_fn=<AddBackward0>)
# 1130 tensor(0.8324, grad_fn=<AddBackward0>)
# 1140 tensor(0.8526, grad_fn=<AddBackward0>)
# 1150 tensor(0.8657, grad_fn=<AddBackward0>)
# 1160 tensor(0.9046, grad_fn=<AddBackward0>)
# 1170 tensor(0.8571, grad_fn=<AddBackward0>)
# 1180 tensor(0.8931, grad_fn=<AddBackward0>)
# 1190 tensor(0.8523, grad_fn=<AddBackward0>)
# 1200 tensor(0.9027, grad_fn=<AddBackward0>)
# 1210 tensor(0.9192, grad_fn=<AddBackward0>)
# 1220 tensor(0.8734, grad_fn=<AddBackward0>)
# 1230 tensor(0.8669, grad_fn=<AddBackward0>)
# 1240 tensor(0.8348, grad_fn=<AddBackward0>)
# 1250 tensor(0.8411, grad_fn=<AddBackward0>)
# 1260 tensor(0.8998, grad_fn=<AddBackward0>)
# 1270 tensor(0.8632, grad_fn=<AddBackward0>)
# 1280 tensor(0.8290, grad_fn=<AddBackward0>)
# 1290 tensor(0.8295, grad_fn=<AddBackward0>)
# 1300 tensor(0.8296, grad_fn=<AddBackward0>)
# 1310 tensor(0.8613, grad_fn=<AddBackward0>)
# 1320 tensor(0.8678, grad_fn=<AddBackward0>)
# 1330 tensor(0.8771, grad_fn=<AddBackward0>)
# 1340 tensor(0.8305, grad_fn=<AddBackward0>)
# 1350 tensor(0.8138, grad_fn=<AddBackward0>)
# 1360 tensor(0.8538, grad_fn=<AddBackward0>)
# 1370 tensor(0.8222, grad_fn=<AddBackward0>)
# 1380 tensor(0.8899, grad_fn=<AddBackward0>)
# 1390 tensor(0.9030, grad_fn=<AddBackward0>)
# 1400 tensor(0.8896, grad_fn=<AddBackward0>)
# 1410 tensor(0.8454, grad_fn=<AddBackward0>)
# 1420 tensor(0.8550, grad_fn=<AddBackward0>)
# 1430 tensor(0.8528, grad_fn=<AddBackward0>)
# 1440 tensor(0.8720, grad_fn=<AddBackward0>)
# 1450 tensor(0.8273, grad_fn=<AddBackward0>)
# 1460 tensor(0.9258, grad_fn=<AddBackward0>)
# 1470 tensor(0.9138, grad_fn=<AddBackward0>)
# 1480 tensor(0.8273, grad_fn=<AddBackward0>)
# 1490 tensor(0.8277, grad_fn=<AddBackward0>)
# 1500 tensor(0.8412, grad_fn=<AddBackward0>)
# 1510 tensor(0.8759, grad_fn=<AddBackward0>)
# 1520 tensor(0.7779, grad_fn=<AddBackward0>)
# 1530 tensor(0.8248, grad_fn=<AddBackward0>)
# 1540 tensor(0.8201, grad_fn=<AddBackward0>)
# 1550 tensor(0.8032, grad_fn=<AddBackward0>)
# 1560 tensor(0.8006, grad_fn=<AddBackward0>)
# 1570 tensor(0.7877, grad_fn=<AddBackward0>)
# 1580 tensor(0.8746, grad_fn=<AddBackward0>)
# 1590 tensor(0.8924, grad_fn=<AddBackward0>)
# 1600 tensor(0.8740, grad_fn=<AddBackward0>)
# 1610 tensor(0.8371, grad_fn=<AddBackward0>)
# 1620 tensor(0.8033, grad_fn=<AddBackward0>)
# 1630 tensor(0.8464, grad_fn=<AddBackward0>)
# 1640 tensor(0.8477, grad_fn=<AddBackward0>)
# 1650 tensor(0.8537, grad_fn=<AddBackward0>)
# 1660 tensor(0.8528, grad_fn=<AddBackward0>)
# 1670 tensor(0.8325, grad_fn=<AddBackward0>)
# 1680 tensor(0.8350, grad_fn=<AddBackward0>)
# 1690 tensor(0.8440, grad_fn=<AddBackward0>)
# 1700 tensor(0.7994, grad_fn=<AddBackward0>)
# 1710 tensor(0.8135, grad_fn=<AddBackward0>)
# 1720 tensor(0.8263, grad_fn=<AddBackward0>)
# 1730 tensor(0.8595, grad_fn=<AddBackward0>)
# 1740 tensor(0.8447, grad_fn=<AddBackward0>)
# 1750 tensor(0.8217, grad_fn=<AddBackward0>)
# 1760 tensor(0.8171, grad_fn=<AddBackward0>)
# 1770 tensor(0.8233, grad_fn=<AddBackward0>)
# 1780 tensor(0.8576, grad_fn=<AddBackward0>)
# 1790 tensor(0.8784, grad_fn=<AddBackward0>)
# 1800 tensor(0.8305, grad_fn=<AddBackward0>)
# 1810 tensor(0.8576, grad_fn=<AddBackward0>)
# 1820 tensor(0.8097, grad_fn=<AddBackward0>)
# 1830 tensor(0.8483, grad_fn=<AddBackward0>)
# 1840 tensor(0.8275, grad_fn=<AddBackward0>)
# 1850 tensor(0.8292, grad_fn=<AddBackward0>)
# 1860 tensor(0.8590, grad_fn=<AddBackward0>)
# 1870 tensor(0.8041, grad_fn=<AddBackward0>)
# 1880 tensor(0.7995, grad_fn=<AddBackward0>)
# 1890 tensor(0.8594, grad_fn=<AddBackward0>)
# 1900 tensor(0.8734, grad_fn=<AddBackward0>)
# 1910 tensor(0.8331, grad_fn=<AddBackward0>)
# 1920 tensor(0.8214, grad_fn=<AddBackward0>)
# 1930 tensor(0.8362, grad_fn=<AddBackward0>)
# 1940 tensor(0.8214, grad_fn=<AddBackward0>)
# 1950 tensor(0.8137, grad_fn=<AddBackward0>)
# 1960 tensor(0.8250, grad_fn=<AddBackward0>)
# 1970 tensor(0.8922, grad_fn=<AddBackward0>)
# 1980 tensor(0.8388, grad_fn=<AddBackward0>)
# 1990 tensor(0.8996, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 2 is bigger than -0.27162966 then go to left, else go to right
#     LEFT:
#     WHEN feature 1 is bigger than 1.0849112 then go to left, else go to right
#         LEFT:
#         WHEN feature 3 is bigger than -0.14605048 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 1
#         RIGHT:
#         WHEN feature 1 is bigger than 0.33071077 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 2
#     RIGHT:
#     WHEN feature 2 is bigger than 0.50275564 then go to left, else go to right
#         LEFT:
#         WHEN feature 2 is bigger than 0.030551188 then go to left, else go to right
#             LEFT:
#             RETURN 2
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 2 is bigger than 0.032548286 then go to left, else go to right
#             LEFT:
#             RETURN 2
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.7333333333333333
# f1_score:
#  0.5833333333333334
# confusion_matrix:
#  [[5 0 0]
#  [0 0 4]
#  [0 0 6]]
# =============================================================
# (135, 4) (135,)
# (15, 4) (15,)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 64, 'l2_weight': 0.1}
# Num Label: [44 44 47]
# Label Weight: [1.06818182 1.06818182 1.        ]
# 0 tensor(1.0982, grad_fn=<AddBackward0>)
# 10 tensor(1.0992, grad_fn=<AddBackward0>)
# 20 tensor(1.0710, grad_fn=<AddBackward0>)
# 30 tensor(1.0774, grad_fn=<AddBackward0>)
# 40 tensor(1.0672, grad_fn=<AddBackward0>)
# 50 tensor(1.0598, grad_fn=<AddBackward0>)
# 60 tensor(1.0498, grad_fn=<AddBackward0>)
# 70 tensor(1.0615, grad_fn=<AddBackward0>)
# 80 tensor(1.0482, grad_fn=<AddBackward0>)
# 90 tensor(1.0470, grad_fn=<AddBackward0>)
# 100 tensor(1.0600, grad_fn=<AddBackward0>)
# 110 tensor(1.0425, grad_fn=<AddBackward0>)
# 120 tensor(1.0438, grad_fn=<AddBackward0>)
# 130 tensor(1.0486, grad_fn=<AddBackward0>)
# 140 tensor(1.0506, grad_fn=<AddBackward0>)
# 150 tensor(1.0440, grad_fn=<AddBackward0>)
# 160 tensor(1.0390, grad_fn=<AddBackward0>)
# 170 tensor(1.0429, grad_fn=<AddBackward0>)
# 180 tensor(1.0411, grad_fn=<AddBackward0>)
# 190 tensor(1.0492, grad_fn=<AddBackward0>)
# 200 tensor(1.0381, grad_fn=<AddBackward0>)
# 210 tensor(0.9963, grad_fn=<AddBackward0>)
# 220 tensor(1.0506, grad_fn=<AddBackward0>)
# 230 tensor(1.0214, grad_fn=<AddBackward0>)
# 240 tensor(1.0209, grad_fn=<AddBackward0>)
# 250 tensor(1.0167, grad_fn=<AddBackward0>)
# 260 tensor(1.0671, grad_fn=<AddBackward0>)
# 270 tensor(1.0105, grad_fn=<AddBackward0>)
# 280 tensor(1.0045, grad_fn=<AddBackward0>)
# 290 tensor(0.9532, grad_fn=<AddBackward0>)
# 300 tensor(1.0128, grad_fn=<AddBackward0>)
# 310 tensor(0.9806, grad_fn=<AddBackward0>)
# 320 tensor(1.0187, grad_fn=<AddBackward0>)
# 330 tensor(0.9880, grad_fn=<AddBackward0>)
# 340 tensor(1.0235, grad_fn=<AddBackward0>)
# 350 tensor(1.0010, grad_fn=<AddBackward0>)
# 360 tensor(0.9915, grad_fn=<AddBackward0>)
# 370 tensor(0.9935, grad_fn=<AddBackward0>)
# 380 tensor(0.9790, grad_fn=<AddBackward0>)
# 390 tensor(0.9900, grad_fn=<AddBackward0>)
# 400 tensor(1.0053, grad_fn=<AddBackward0>)
# 410 tensor(1.0056, grad_fn=<AddBackward0>)
# 420 tensor(0.9731, grad_fn=<AddBackward0>)
# 430 tensor(0.9770, grad_fn=<AddBackward0>)
# 440 tensor(1.0215, grad_fn=<AddBackward0>)
# 450 tensor(0.9994, grad_fn=<AddBackward0>)
# 460 tensor(1.0028, grad_fn=<AddBackward0>)
# 470 tensor(0.9593, grad_fn=<AddBackward0>)
# 480 tensor(0.9746, grad_fn=<AddBackward0>)
# 490 tensor(0.9593, grad_fn=<AddBackward0>)
# 500 tensor(0.9696, grad_fn=<AddBackward0>)
# 510 tensor(1.0009, grad_fn=<AddBackward0>)
# 520 tensor(0.9494, grad_fn=<AddBackward0>)
# 530 tensor(0.9527, grad_fn=<AddBackward0>)
# 540 tensor(0.9485, grad_fn=<AddBackward0>)
# 550 tensor(0.9593, grad_fn=<AddBackward0>)
# 560 tensor(0.9597, grad_fn=<AddBackward0>)
# 570 tensor(0.9310, grad_fn=<AddBackward0>)
# 580 tensor(0.9554, grad_fn=<AddBackward0>)
# 590 tensor(0.9697, grad_fn=<AddBackward0>)
# 600 tensor(0.9177, grad_fn=<AddBackward0>)
# 610 tensor(0.9687, grad_fn=<AddBackward0>)
# 620 tensor(0.9410, grad_fn=<AddBackward0>)
# 630 tensor(0.9296, grad_fn=<AddBackward0>)
# 640 tensor(0.9161, grad_fn=<AddBackward0>)
# 650 tensor(0.9270, grad_fn=<AddBackward0>)
# 660 tensor(0.9277, grad_fn=<AddBackward0>)
# 670 tensor(0.9647, grad_fn=<AddBackward0>)
# 680 tensor(0.9134, grad_fn=<AddBackward0>)
# 690 tensor(0.8770, grad_fn=<AddBackward0>)
# 700 tensor(0.9134, grad_fn=<AddBackward0>)
# 710 tensor(0.9786, grad_fn=<AddBackward0>)
# 720 tensor(0.9108, grad_fn=<AddBackward0>)
# 730 tensor(0.9327, grad_fn=<AddBackward0>)
# 740 tensor(0.9298, grad_fn=<AddBackward0>)
# 750 tensor(0.9388, grad_fn=<AddBackward0>)
# 760 tensor(0.9048, grad_fn=<AddBackward0>)
# 770 tensor(0.8676, grad_fn=<AddBackward0>)
# 780 tensor(0.8769, grad_fn=<AddBackward0>)
# 790 tensor(0.9564, grad_fn=<AddBackward0>)
# 800 tensor(0.9480, grad_fn=<AddBackward0>)
# 810 tensor(0.8875, grad_fn=<AddBackward0>)
# 820 tensor(0.8649, grad_fn=<AddBackward0>)
# 830 tensor(0.9297, grad_fn=<AddBackward0>)
# 840 tensor(0.9281, grad_fn=<AddBackward0>)
# 850 tensor(0.9412, grad_fn=<AddBackward0>)
# 860 tensor(0.9044, grad_fn=<AddBackward0>)
# 870 tensor(0.8937, grad_fn=<AddBackward0>)
# 880 tensor(0.8992, grad_fn=<AddBackward0>)
# 890 tensor(0.8779, grad_fn=<AddBackward0>)
# 900 tensor(0.8995, grad_fn=<AddBackward0>)
# 910 tensor(0.8268, grad_fn=<AddBackward0>)
# 920 tensor(0.9202, grad_fn=<AddBackward0>)
# 930 tensor(0.9023, grad_fn=<AddBackward0>)
# 940 tensor(0.9065, grad_fn=<AddBackward0>)
# 950 tensor(0.9025, grad_fn=<AddBackward0>)
# 960 tensor(0.9369, grad_fn=<AddBackward0>)
# 970 tensor(0.8844, grad_fn=<AddBackward0>)
# 980 tensor(0.9311, grad_fn=<AddBackward0>)
# 990 tensor(0.8779, grad_fn=<AddBackward0>)
# 1000 tensor(0.9005, grad_fn=<AddBackward0>)
# 1010 tensor(0.8887, grad_fn=<AddBackward0>)
# 1020 tensor(0.8540, grad_fn=<AddBackward0>)
# 1030 tensor(0.8431, grad_fn=<AddBackward0>)
# 1040 tensor(0.8831, grad_fn=<AddBackward0>)
# 1050 tensor(0.8496, grad_fn=<AddBackward0>)
# 1060 tensor(0.8681, grad_fn=<AddBackward0>)
# 1070 tensor(0.8825, grad_fn=<AddBackward0>)
# 1080 tensor(0.9515, grad_fn=<AddBackward0>)
# 1090 tensor(0.8456, grad_fn=<AddBackward0>)
# 1100 tensor(0.9334, grad_fn=<AddBackward0>)
# 1110 tensor(0.8583, grad_fn=<AddBackward0>)
# 1120 tensor(0.9181, grad_fn=<AddBackward0>)
# 1130 tensor(0.9110, grad_fn=<AddBackward0>)
# 1140 tensor(0.9434, grad_fn=<AddBackward0>)
# 1150 tensor(0.8790, grad_fn=<AddBackward0>)
# 1160 tensor(0.8727, grad_fn=<AddBackward0>)
# 1170 tensor(0.9096, grad_fn=<AddBackward0>)
# 1180 tensor(0.8903, grad_fn=<AddBackward0>)
# 1190 tensor(0.8280, grad_fn=<AddBackward0>)
# 1200 tensor(0.9926, grad_fn=<AddBackward0>)
# 1210 tensor(1.0043, grad_fn=<AddBackward0>)
# 1220 tensor(0.9195, grad_fn=<AddBackward0>)
# 1230 tensor(0.9581, grad_fn=<AddBackward0>)
# 1240 tensor(1.0573, grad_fn=<AddBackward0>)
# 1250 tensor(0.9113, grad_fn=<AddBackward0>)
# 1260 tensor(0.9644, grad_fn=<AddBackward0>)
# 1270 tensor(1.0011, grad_fn=<AddBackward0>)
# 1280 tensor(1.1265, grad_fn=<AddBackward0>)
# 1290 tensor(0.9559, grad_fn=<AddBackward0>)
# 1300 tensor(0.9855, grad_fn=<AddBackward0>)
# 1310 tensor(1.0803, grad_fn=<AddBackward0>)
# 1320 tensor(1.0250, grad_fn=<AddBackward0>)
# 1330 tensor(1.0314, grad_fn=<AddBackward0>)
# 1340 tensor(1.0140, grad_fn=<AddBackward0>)
# 1350 tensor(0.9962, grad_fn=<AddBackward0>)
# 1360 tensor(1.1344, grad_fn=<AddBackward0>)
# 1370 tensor(0.9701, grad_fn=<AddBackward0>)
# 1380 tensor(1.1089, grad_fn=<AddBackward0>)
# 1390 tensor(0.9675, grad_fn=<AddBackward0>)
# 1400 tensor(0.9499, grad_fn=<AddBackward0>)
# 1410 tensor(1.0012, grad_fn=<AddBackward0>)
# 1420 tensor(0.9332, grad_fn=<AddBackward0>)
# 1430 tensor(1.0473, grad_fn=<AddBackward0>)
# 1440 tensor(1.0358, grad_fn=<AddBackward0>)
# 1450 tensor(1.0399, grad_fn=<AddBackward0>)
# 1460 tensor(0.8795, grad_fn=<AddBackward0>)
# 1470 tensor(0.9336, grad_fn=<AddBackward0>)
# 1480 tensor(1.0442, grad_fn=<AddBackward0>)
# 1490 tensor(0.9675, grad_fn=<AddBackward0>)
# 1500 tensor(1.0071, grad_fn=<AddBackward0>)
# 1510 tensor(1.0302, grad_fn=<AddBackward0>)
# 1520 tensor(0.9376, grad_fn=<AddBackward0>)
# 1530 tensor(1.0631, grad_fn=<AddBackward0>)
# 1540 tensor(1.0315, grad_fn=<AddBackward0>)
# 1550 tensor(0.9526, grad_fn=<AddBackward0>)
# 1560 tensor(1.0664, grad_fn=<AddBackward0>)
# 1570 tensor(0.9668, grad_fn=<AddBackward0>)
# 1580 tensor(1.0469, grad_fn=<AddBackward0>)
# 1590 tensor(1.0650, grad_fn=<AddBackward0>)
# 1600 tensor(1.0267, grad_fn=<AddBackward0>)
# 1610 tensor(1.0357, grad_fn=<AddBackward0>)
# 1620 tensor(0.9127, grad_fn=<AddBackward0>)
# 1630 tensor(0.8637, grad_fn=<AddBackward0>)
# 1640 tensor(0.8721, grad_fn=<AddBackward0>)
# 1650 tensor(1.0026, grad_fn=<AddBackward0>)
# 1660 tensor(1.0267, grad_fn=<AddBackward0>)
# 1670 tensor(0.9721, grad_fn=<AddBackward0>)
# 1680 tensor(0.8912, grad_fn=<AddBackward0>)
# 1690 tensor(0.9858, grad_fn=<AddBackward0>)
# 1700 tensor(0.8891, grad_fn=<AddBackward0>)
# 1710 tensor(0.9966, grad_fn=<AddBackward0>)
# 1720 tensor(0.9707, grad_fn=<AddBackward0>)
# 1730 tensor(1.0394, grad_fn=<AddBackward0>)
# 1740 tensor(0.9836, grad_fn=<AddBackward0>)
# 1750 tensor(0.9380, grad_fn=<AddBackward0>)
# 1760 tensor(0.8613, grad_fn=<AddBackward0>)
# 1770 tensor(1.0555, grad_fn=<AddBackward0>)
# 1780 tensor(0.9663, grad_fn=<AddBackward0>)
# 1790 tensor(1.0230, grad_fn=<AddBackward0>)
# 1800 tensor(0.9546, grad_fn=<AddBackward0>)
# 1810 tensor(1.0023, grad_fn=<AddBackward0>)
# 1820 tensor(0.8461, grad_fn=<AddBackward0>)
# 1830 tensor(1.0162, grad_fn=<AddBackward0>)
# 1840 tensor(0.8170, grad_fn=<AddBackward0>)
# 1850 tensor(0.9074, grad_fn=<AddBackward0>)
# 1860 tensor(0.8808, grad_fn=<AddBackward0>)
# 1870 tensor(1.0328, grad_fn=<AddBackward0>)
# 1880 tensor(0.9622, grad_fn=<AddBackward0>)
# 1890 tensor(0.9842, grad_fn=<AddBackward0>)
# 1900 tensor(0.9052, grad_fn=<AddBackward0>)
# 1910 tensor(0.9161, grad_fn=<AddBackward0>)
# 1920 tensor(1.0056, grad_fn=<AddBackward0>)
# 1930 tensor(1.0199, grad_fn=<AddBackward0>)
# 1940 tensor(0.9801, grad_fn=<AddBackward0>)
# 1950 tensor(0.8926, grad_fn=<AddBackward0>)
# 1960 tensor(0.8685, grad_fn=<AddBackward0>)
# 1970 tensor(0.9216, grad_fn=<AddBackward0>)
# 1980 tensor(0.9966, grad_fn=<AddBackward0>)
# 1990 tensor(1.0029, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 1 is bigger than 0.21879448 then go to left, else go to right
#     LEFT:
#     WHEN feature 3 is bigger than 0.42049122 then go to left, else go to right
#         LEFT:
#         WHEN feature 1 is bigger than -0.43184334 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 2
#         RIGHT:
#         WHEN feature 2 is bigger than 0.07024636 then go to left, else go to right
#             LEFT:
#             RETURN 2
#             RIGHT:
#             RETURN 0
#     RIGHT:
#     WHEN feature 3 is bigger than 0.25894937 then go to left, else go to right
#         LEFT:
#         WHEN feature 1 is bigger than -0.088206485 then go to left, else go to right
#             LEFT:
#             RETURN 2
#             RIGHT:
#             RETURN 1
#         RIGHT:
#         WHEN feature 1 is bigger than -0.33356303 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 2
# accuracy:
#  0.8
# f1_score:
#  0.8087912087912089
# confusion_matrix:
#  [[4 2 0]
#  [0 5 1]
#  [0 0 3]]
# =============================================================
# (135, 4) (135,)
# (15, 4) (15,)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 64, 'l2_weight': 0.1}
# Num Label: [47 47 41]
# Label Weight: [1.         1.         1.14634146]
# 0 tensor(1.1790, grad_fn=<AddBackward0>)
# 10 tensor(1.1902, grad_fn=<AddBackward0>)
# 20 tensor(1.1679, grad_fn=<AddBackward0>)
# 30 tensor(1.1756, grad_fn=<AddBackward0>)
# 40 tensor(1.1629, grad_fn=<AddBackward0>)
# 50 tensor(1.1642, grad_fn=<AddBackward0>)
# 60 tensor(1.1599, grad_fn=<AddBackward0>)
# 70 tensor(1.1635, grad_fn=<AddBackward0>)
# 80 tensor(1.1469, grad_fn=<AddBackward0>)
# 90 tensor(1.1524, grad_fn=<AddBackward0>)
# 100 tensor(1.1466, grad_fn=<AddBackward0>)
# 110 tensor(1.1565, grad_fn=<AddBackward0>)
# 120 tensor(1.1561, grad_fn=<AddBackward0>)
# 130 tensor(1.1267, grad_fn=<AddBackward0>)
# 140 tensor(1.1325, grad_fn=<AddBackward0>)
# 150 tensor(1.1383, grad_fn=<AddBackward0>)
# 160 tensor(1.1264, grad_fn=<AddBackward0>)
# 170 tensor(1.1112, grad_fn=<AddBackward0>)
# 180 tensor(1.0734, grad_fn=<AddBackward0>)
# 190 tensor(1.0988, grad_fn=<AddBackward0>)
# 200 tensor(1.0659, grad_fn=<AddBackward0>)
# 210 tensor(1.0786, grad_fn=<AddBackward0>)
# 220 tensor(1.0692, grad_fn=<AddBackward0>)
# 230 tensor(1.0559, grad_fn=<AddBackward0>)
# 240 tensor(1.0975, grad_fn=<AddBackward0>)
# 250 tensor(1.0520, grad_fn=<AddBackward0>)
# 260 tensor(1.0480, grad_fn=<AddBackward0>)
# 270 tensor(1.0339, grad_fn=<AddBackward0>)
# 280 tensor(1.0648, grad_fn=<AddBackward0>)
# 290 tensor(1.0410, grad_fn=<AddBackward0>)
# 300 tensor(1.0058, grad_fn=<AddBackward0>)
# 310 tensor(1.0303, grad_fn=<AddBackward0>)
# 320 tensor(1.0024, grad_fn=<AddBackward0>)
# 330 tensor(1.0040, grad_fn=<AddBackward0>)
# 340 tensor(0.9889, grad_fn=<AddBackward0>)
# 350 tensor(0.9796, grad_fn=<AddBackward0>)
# 360 tensor(1.0046, grad_fn=<AddBackward0>)
# 370 tensor(0.9482, grad_fn=<AddBackward0>)
# 380 tensor(0.9901, grad_fn=<AddBackward0>)
# 390 tensor(0.9831, grad_fn=<AddBackward0>)
# 400 tensor(0.9807, grad_fn=<AddBackward0>)
# 410 tensor(1.0001, grad_fn=<AddBackward0>)
# 420 tensor(1.0076, grad_fn=<AddBackward0>)
# 430 tensor(1.0314, grad_fn=<AddBackward0>)
# 440 tensor(1.0330, grad_fn=<AddBackward0>)
# 450 tensor(1.0295, grad_fn=<AddBackward0>)
# 460 tensor(0.9771, grad_fn=<AddBackward0>)
# 470 tensor(1.0203, grad_fn=<AddBackward0>)
# 480 tensor(0.9849, grad_fn=<AddBackward0>)
# 490 tensor(0.9667, grad_fn=<AddBackward0>)
# 500 tensor(1.0176, grad_fn=<AddBackward0>)
# 510 tensor(0.9118, grad_fn=<AddBackward0>)
# 520 tensor(0.9694, grad_fn=<AddBackward0>)
# 530 tensor(0.9721, grad_fn=<AddBackward0>)
# 540 tensor(0.9604, grad_fn=<AddBackward0>)
# 550 tensor(0.9025, grad_fn=<AddBackward0>)
# 560 tensor(0.9292, grad_fn=<AddBackward0>)
# 570 tensor(0.9691, grad_fn=<AddBackward0>)
# 580 tensor(0.9196, grad_fn=<AddBackward0>)
# 590 tensor(0.9657, grad_fn=<AddBackward0>)
# 600 tensor(0.8962, grad_fn=<AddBackward0>)
# 610 tensor(0.9561, grad_fn=<AddBackward0>)
# 620 tensor(0.9274, grad_fn=<AddBackward0>)
# 630 tensor(0.8604, grad_fn=<AddBackward0>)
# 640 tensor(0.9486, grad_fn=<AddBackward0>)
# 650 tensor(0.9420, grad_fn=<AddBackward0>)
# 660 tensor(0.9500, grad_fn=<AddBackward0>)
# 670 tensor(0.8676, grad_fn=<AddBackward0>)
# 680 tensor(0.9933, grad_fn=<AddBackward0>)
# 690 tensor(0.8785, grad_fn=<AddBackward0>)
# 700 tensor(0.9114, grad_fn=<AddBackward0>)
# 710 tensor(0.9596, grad_fn=<AddBackward0>)
# 720 tensor(0.9439, grad_fn=<AddBackward0>)
# 730 tensor(0.9464, grad_fn=<AddBackward0>)
# 740 tensor(0.9945, grad_fn=<AddBackward0>)
# 750 tensor(0.8740, grad_fn=<AddBackward0>)
# 760 tensor(0.9232, grad_fn=<AddBackward0>)
# 770 tensor(0.9377, grad_fn=<AddBackward0>)
# 780 tensor(0.9517, grad_fn=<AddBackward0>)
# 790 tensor(0.8859, grad_fn=<AddBackward0>)
# 800 tensor(0.8420, grad_fn=<AddBackward0>)
# 810 tensor(0.9285, grad_fn=<AddBackward0>)
# 820 tensor(0.9728, grad_fn=<AddBackward0>)
# 830 tensor(0.8570, grad_fn=<AddBackward0>)
# 840 tensor(0.9490, grad_fn=<AddBackward0>)
# 850 tensor(0.9104, grad_fn=<AddBackward0>)
# 860 tensor(0.8607, grad_fn=<AddBackward0>)
# 870 tensor(0.8869, grad_fn=<AddBackward0>)
# 880 tensor(0.8881, grad_fn=<AddBackward0>)
# 890 tensor(0.9143, grad_fn=<AddBackward0>)
# 900 tensor(0.9514, grad_fn=<AddBackward0>)
# 910 tensor(0.8702, grad_fn=<AddBackward0>)
# 920 tensor(0.8918, grad_fn=<AddBackward0>)
# 930 tensor(0.9204, grad_fn=<AddBackward0>)
# 940 tensor(0.8659, grad_fn=<AddBackward0>)
# 950 tensor(0.8640, grad_fn=<AddBackward0>)
# 960 tensor(0.9427, grad_fn=<AddBackward0>)
# 970 tensor(0.9421, grad_fn=<AddBackward0>)
# 980 tensor(0.9591, grad_fn=<AddBackward0>)
# 990 tensor(0.8552, grad_fn=<AddBackward0>)
# 1000 tensor(0.9386, grad_fn=<AddBackward0>)
# 1010 tensor(0.8142, grad_fn=<AddBackward0>)
# 1020 tensor(0.9048, grad_fn=<AddBackward0>)
# 1030 tensor(0.9046, grad_fn=<AddBackward0>)
# 1040 tensor(0.8115, grad_fn=<AddBackward0>)
# 1050 tensor(0.9322, grad_fn=<AddBackward0>)
# 1060 tensor(0.8804, grad_fn=<AddBackward0>)
# 1070 tensor(0.8867, grad_fn=<AddBackward0>)
# 1080 tensor(0.8709, grad_fn=<AddBackward0>)
# 1090 tensor(0.8433, grad_fn=<AddBackward0>)
# 1100 tensor(0.8395, grad_fn=<AddBackward0>)
# 1110 tensor(0.9010, grad_fn=<AddBackward0>)
# 1120 tensor(0.8439, grad_fn=<AddBackward0>)
# 1130 tensor(0.8791, grad_fn=<AddBackward0>)
# 1140 tensor(0.8789, grad_fn=<AddBackward0>)
# 1150 tensor(0.9006, grad_fn=<AddBackward0>)
# 1160 tensor(0.8606, grad_fn=<AddBackward0>)
# 1170 tensor(0.9022, grad_fn=<AddBackward0>)
# 1180 tensor(0.9052, grad_fn=<AddBackward0>)
# 1190 tensor(0.8967, grad_fn=<AddBackward0>)
# 1200 tensor(0.8660, grad_fn=<AddBackward0>)
# 1210 tensor(0.8796, grad_fn=<AddBackward0>)
# 1220 tensor(0.8852, grad_fn=<AddBackward0>)
# 1230 tensor(0.8002, grad_fn=<AddBackward0>)
# 1240 tensor(0.8466, grad_fn=<AddBackward0>)
# 1250 tensor(0.8120, grad_fn=<AddBackward0>)
# 1260 tensor(0.8421, grad_fn=<AddBackward0>)
# 1270 tensor(0.7989, grad_fn=<AddBackward0>)
# 1280 tensor(0.9516, grad_fn=<AddBackward0>)
# 1290 tensor(0.9402, grad_fn=<AddBackward0>)
# 1300 tensor(0.9158, grad_fn=<AddBackward0>)
# 1310 tensor(0.8880, grad_fn=<AddBackward0>)
# 1320 tensor(0.8383, grad_fn=<AddBackward0>)
# 1330 tensor(0.8995, grad_fn=<AddBackward0>)
# 1340 tensor(0.8427, grad_fn=<AddBackward0>)
# 1350 tensor(0.8053, grad_fn=<AddBackward0>)
# 1360 tensor(0.9716, grad_fn=<AddBackward0>)
# 1370 tensor(0.7873, grad_fn=<AddBackward0>)
# 1380 tensor(0.8100, grad_fn=<AddBackward0>)
# 1390 tensor(0.8434, grad_fn=<AddBackward0>)
# 1400 tensor(0.8614, grad_fn=<AddBackward0>)
# 1410 tensor(0.8757, grad_fn=<AddBackward0>)
# 1420 tensor(0.8095, grad_fn=<AddBackward0>)
# 1430 tensor(0.9080, grad_fn=<AddBackward0>)
# 1440 tensor(0.8882, grad_fn=<AddBackward0>)
# 1450 tensor(0.8661, grad_fn=<AddBackward0>)
# 1460 tensor(0.9060, grad_fn=<AddBackward0>)
# 1470 tensor(0.9382, grad_fn=<AddBackward0>)
# 1480 tensor(0.8577, grad_fn=<AddBackward0>)
# 1490 tensor(0.8728, grad_fn=<AddBackward0>)
# 1500 tensor(0.8941, grad_fn=<AddBackward0>)
# 1510 tensor(0.9242, grad_fn=<AddBackward0>)
# 1520 tensor(0.7833, grad_fn=<AddBackward0>)
# 1530 tensor(0.7998, grad_fn=<AddBackward0>)
# 1540 tensor(0.8236, grad_fn=<AddBackward0>)
# 1550 tensor(0.8004, grad_fn=<AddBackward0>)
# 1560 tensor(0.8272, grad_fn=<AddBackward0>)
# 1570 tensor(0.9325, grad_fn=<AddBackward0>)
# 1580 tensor(0.8814, grad_fn=<AddBackward0>)
# 1590 tensor(0.9222, grad_fn=<AddBackward0>)
# 1600 tensor(0.8237, grad_fn=<AddBackward0>)
# 1610 tensor(0.8249, grad_fn=<AddBackward0>)
# 1620 tensor(0.8263, grad_fn=<AddBackward0>)
# 1630 tensor(0.8748, grad_fn=<AddBackward0>)
# 1640 tensor(0.9352, grad_fn=<AddBackward0>)
# 1650 tensor(0.8908, grad_fn=<AddBackward0>)
# 1660 tensor(0.8538, grad_fn=<AddBackward0>)
# 1670 tensor(0.8365, grad_fn=<AddBackward0>)
# 1680 tensor(0.8845, grad_fn=<AddBackward0>)
# 1690 tensor(0.8066, grad_fn=<AddBackward0>)
# 1700 tensor(0.8344, grad_fn=<AddBackward0>)
# 1710 tensor(0.8386, grad_fn=<AddBackward0>)
# 1720 tensor(0.8166, grad_fn=<AddBackward0>)
# 1730 tensor(0.9034, grad_fn=<AddBackward0>)
# 1740 tensor(0.8150, grad_fn=<AddBackward0>)
# 1750 tensor(0.8305, grad_fn=<AddBackward0>)
# 1760 tensor(0.8870, grad_fn=<AddBackward0>)
# 1770 tensor(0.7847, grad_fn=<AddBackward0>)
# 1780 tensor(0.8079, grad_fn=<AddBackward0>)
# 1790 tensor(0.8266, grad_fn=<AddBackward0>)
# 1800 tensor(0.8190, grad_fn=<AddBackward0>)
# 1810 tensor(0.9008, grad_fn=<AddBackward0>)
# 1820 tensor(0.9075, grad_fn=<AddBackward0>)
# 1830 tensor(0.8525, grad_fn=<AddBackward0>)
# 1840 tensor(0.9440, grad_fn=<AddBackward0>)
# 1850 tensor(0.8760, grad_fn=<AddBackward0>)
# 1860 tensor(0.8494, grad_fn=<AddBackward0>)
# 1870 tensor(0.8766, grad_fn=<AddBackward0>)
# 1880 tensor(0.8210, grad_fn=<AddBackward0>)
# 1890 tensor(0.9281, grad_fn=<AddBackward0>)
# 1900 tensor(0.7731, grad_fn=<AddBackward0>)
# 1910 tensor(0.7699, grad_fn=<AddBackward0>)
# 1920 tensor(0.8607, grad_fn=<AddBackward0>)
# 1930 tensor(0.7705, grad_fn=<AddBackward0>)
# 1940 tensor(0.7711, grad_fn=<AddBackward0>)
# 1950 tensor(0.8859, grad_fn=<AddBackward0>)
# 1960 tensor(0.8208, grad_fn=<AddBackward0>)
# 1970 tensor(0.8231, grad_fn=<AddBackward0>)
# 1980 tensor(0.8266, grad_fn=<AddBackward0>)
# 1990 tensor(0.8035, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 3 is bigger than 0.0956105 then go to left, else go to right
#     LEFT:
#     WHEN feature 2 is bigger than -0.35333398 then go to left, else go to right
#         LEFT:
#         WHEN feature 1 is bigger than 0.19241066 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 1
#         RIGHT:
#         WHEN feature 1 is bigger than 0.027441075 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 2
#     RIGHT:
#     WHEN feature 1 is bigger than 0.16965799 then go to left, else go to right
#         LEFT:
#         WHEN feature 1 is bigger than -0.009179628 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 2
#         RIGHT:
#         WHEN feature 1 is bigger than 0.075141676 then go to left, else go to right
#             LEFT:
#             RETURN 2
#             RIGHT:
#             RETURN 2
# accuracy:
#  0.5333333333333333
# f1_score:
#  0.6083916083916084
# confusion_matrix:
#  [[3 0 0]
#  [0 3 0]
#  [0 7 2]]
# =============================================================
# (135, 4) (135,)
# (15, 4) (15,)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 64, 'l2_weight': 0.1}
# Num Label: [44 46 45]
# Label Weight: [1.04545455 1.         1.02222222]
# 0 tensor(1.1225, grad_fn=<AddBackward0>)
# 10 tensor(1.1399, grad_fn=<AddBackward0>)
# 20 tensor(1.1145, grad_fn=<AddBackward0>)
# 30 tensor(1.0938, grad_fn=<AddBackward0>)
# 40 tensor(1.1047, grad_fn=<AddBackward0>)
# 50 tensor(1.1014, grad_fn=<AddBackward0>)
# 60 tensor(1.0984, grad_fn=<AddBackward0>)
# 70 tensor(1.1112, grad_fn=<AddBackward0>)
# 80 tensor(1.1271, grad_fn=<AddBackward0>)
# 90 tensor(1.1413, grad_fn=<AddBackward0>)
# 100 tensor(1.1161, grad_fn=<AddBackward0>)
# 110 tensor(1.1241, grad_fn=<AddBackward0>)
# 120 tensor(1.1267, grad_fn=<AddBackward0>)
# 130 tensor(1.1239, grad_fn=<AddBackward0>)
# 140 tensor(1.1243, grad_fn=<AddBackward0>)
# 150 tensor(1.1298, grad_fn=<AddBackward0>)
# 160 tensor(1.1194, grad_fn=<AddBackward0>)
# 170 tensor(1.1145, grad_fn=<AddBackward0>)
# 180 tensor(1.1062, grad_fn=<AddBackward0>)
# 190 tensor(1.1169, grad_fn=<AddBackward0>)
# 200 tensor(1.1039, grad_fn=<AddBackward0>)
# 210 tensor(1.0967, grad_fn=<AddBackward0>)
# 220 tensor(1.0946, grad_fn=<AddBackward0>)
# 230 tensor(1.0978, grad_fn=<AddBackward0>)
# 240 tensor(1.0843, grad_fn=<AddBackward0>)
# 250 tensor(1.1025, grad_fn=<AddBackward0>)
# 260 tensor(1.1036, grad_fn=<AddBackward0>)
# 270 tensor(1.0853, grad_fn=<AddBackward0>)
# 280 tensor(1.1142, grad_fn=<AddBackward0>)
# 290 tensor(1.0815, grad_fn=<AddBackward0>)
# 300 tensor(1.0929, grad_fn=<AddBackward0>)
# 310 tensor(1.0842, grad_fn=<AddBackward0>)
# 320 tensor(1.0904, grad_fn=<AddBackward0>)
# 330 tensor(1.0984, grad_fn=<AddBackward0>)
# 340 tensor(1.0956, grad_fn=<AddBackward0>)
# 350 tensor(1.0839, grad_fn=<AddBackward0>)
# 360 tensor(1.0866, grad_fn=<AddBackward0>)
# 370 tensor(1.0824, grad_fn=<AddBackward0>)
# 380 tensor(1.0928, grad_fn=<AddBackward0>)
# 390 tensor(1.0931, grad_fn=<AddBackward0>)
# 400 tensor(1.0860, grad_fn=<AddBackward0>)
# 410 tensor(1.0888, grad_fn=<AddBackward0>)
# 420 tensor(1.0860, grad_fn=<AddBackward0>)
# 430 tensor(1.1155, grad_fn=<AddBackward0>)
# 440 tensor(1.1158, grad_fn=<AddBackward0>)
# 450 tensor(1.0658, grad_fn=<AddBackward0>)
# 460 tensor(1.0689, grad_fn=<AddBackward0>)
# 470 tensor(1.0573, grad_fn=<AddBackward0>)
# 480 tensor(1.0640, grad_fn=<AddBackward0>)
# 490 tensor(1.0531, grad_fn=<AddBackward0>)
# 500 tensor(1.0623, grad_fn=<AddBackward0>)
# 510 tensor(1.0812, grad_fn=<AddBackward0>)
# 520 tensor(1.0800, grad_fn=<AddBackward0>)
# 530 tensor(1.1199, grad_fn=<AddBackward0>)
# 540 tensor(1.1102, grad_fn=<AddBackward0>)
# 550 tensor(1.1203, grad_fn=<AddBackward0>)
# 560 tensor(1.1381, grad_fn=<AddBackward0>)
# 570 tensor(1.1188, grad_fn=<AddBackward0>)
# 580 tensor(1.1209, grad_fn=<AddBackward0>)
# 590 tensor(1.1188, grad_fn=<AddBackward0>)
# 600 tensor(1.0990, grad_fn=<AddBackward0>)
# 610 tensor(1.1399, grad_fn=<AddBackward0>)
# 620 tensor(1.1344, grad_fn=<AddBackward0>)
# 630 tensor(1.1270, grad_fn=<AddBackward0>)
# 640 tensor(1.1096, grad_fn=<AddBackward0>)
# 650 tensor(1.1357, grad_fn=<AddBackward0>)
# 660 tensor(1.1387, grad_fn=<AddBackward0>)
# 670 tensor(1.1212, grad_fn=<AddBackward0>)
# 680 tensor(1.1009, grad_fn=<AddBackward0>)
# 690 tensor(1.1591, grad_fn=<AddBackward0>)
# 700 tensor(1.1175, grad_fn=<AddBackward0>)
# 710 tensor(1.1265, grad_fn=<AddBackward0>)
# 720 tensor(1.1325, grad_fn=<AddBackward0>)
# 730 tensor(1.1103, grad_fn=<AddBackward0>)
# 740 tensor(1.1495, grad_fn=<AddBackward0>)
# 750 tensor(1.1384, grad_fn=<AddBackward0>)
# 760 tensor(1.1210, grad_fn=<AddBackward0>)
# 770 tensor(1.1254, grad_fn=<AddBackward0>)
# 780 tensor(1.1289, grad_fn=<AddBackward0>)
# 790 tensor(1.1294, grad_fn=<AddBackward0>)
# 800 tensor(1.1315, grad_fn=<AddBackward0>)
# 810 tensor(1.1257, grad_fn=<AddBackward0>)
# 820 tensor(1.1337, grad_fn=<AddBackward0>)
# 830 tensor(1.1300, grad_fn=<AddBackward0>)
# 840 tensor(1.1287, grad_fn=<AddBackward0>)
# 850 tensor(1.1310, grad_fn=<AddBackward0>)
# 860 tensor(1.1282, grad_fn=<AddBackward0>)
# 870 tensor(1.1238, grad_fn=<AddBackward0>)
# 880 tensor(1.1398, grad_fn=<AddBackward0>)
# 890 tensor(1.1230, grad_fn=<AddBackward0>)
# 900 tensor(1.1155, grad_fn=<AddBackward0>)
# 910 tensor(1.1449, grad_fn=<AddBackward0>)
# 920 tensor(1.0881, grad_fn=<AddBackward0>)
# 930 tensor(1.0998, grad_fn=<AddBackward0>)
# 940 tensor(1.0904, grad_fn=<AddBackward0>)
# 950 tensor(1.0901, grad_fn=<AddBackward0>)
# 960 tensor(1.1018, grad_fn=<AddBackward0>)
# 970 tensor(1.0850, grad_fn=<AddBackward0>)
# 980 tensor(1.0892, grad_fn=<AddBackward0>)
# 990 tensor(1.0926, grad_fn=<AddBackward0>)
# 1000 tensor(1.0806, grad_fn=<AddBackward0>)
# 1010 tensor(1.0790, grad_fn=<AddBackward0>)
# 1020 tensor(1.0711, grad_fn=<AddBackward0>)
# 1030 tensor(1.0612, grad_fn=<AddBackward0>)
# 1040 tensor(1.1002, grad_fn=<AddBackward0>)
# 1050 tensor(1.0615, grad_fn=<AddBackward0>)
# 1060 tensor(1.0647, grad_fn=<AddBackward0>)
# 1070 tensor(1.0822, grad_fn=<AddBackward0>)
# 1080 tensor(1.0578, grad_fn=<AddBackward0>)
# 1090 tensor(1.0740, grad_fn=<AddBackward0>)
# 1100 tensor(1.0719, grad_fn=<AddBackward0>)
# 1110 tensor(1.0480, grad_fn=<AddBackward0>)
# 1120 tensor(1.0616, grad_fn=<AddBackward0>)
# 1130 tensor(1.0368, grad_fn=<AddBackward0>)
# 1140 tensor(1.0648, grad_fn=<AddBackward0>)
# 1150 tensor(1.0409, grad_fn=<AddBackward0>)
# 1160 tensor(1.0661, grad_fn=<AddBackward0>)
# 1170 tensor(1.0539, grad_fn=<AddBackward0>)
# 1180 tensor(1.0616, grad_fn=<AddBackward0>)
# 1190 tensor(1.0493, grad_fn=<AddBackward0>)
# 1200 tensor(1.0589, grad_fn=<AddBackward0>)
# 1210 tensor(1.0498, grad_fn=<AddBackward0>)
# 1220 tensor(1.0396, grad_fn=<AddBackward0>)
# 1230 tensor(1.0637, grad_fn=<AddBackward0>)
# 1240 tensor(1.0437, grad_fn=<AddBackward0>)
# 1250 tensor(1.0401, grad_fn=<AddBackward0>)
# 1260 tensor(1.0612, grad_fn=<AddBackward0>)
# 1270 tensor(1.0230, grad_fn=<AddBackward0>)
# 1280 tensor(1.0397, grad_fn=<AddBackward0>)
# 1290 tensor(1.0892, grad_fn=<AddBackward0>)
# 1300 tensor(1.0532, grad_fn=<AddBackward0>)
# 1310 tensor(1.0574, grad_fn=<AddBackward0>)
# 1320 tensor(1.0557, grad_fn=<AddBackward0>)
# 1330 tensor(1.0381, grad_fn=<AddBackward0>)
# 1340 tensor(1.0347, grad_fn=<AddBackward0>)
# 1350 tensor(1.0463, grad_fn=<AddBackward0>)
# 1360 tensor(1.0712, grad_fn=<AddBackward0>)
# 1370 tensor(1.0502, grad_fn=<AddBackward0>)
# 1380 tensor(1.0430, grad_fn=<AddBackward0>)
# 1390 tensor(1.0970, grad_fn=<AddBackward0>)
# 1400 tensor(1.1445, grad_fn=<AddBackward0>)
# 1410 tensor(1.1234, grad_fn=<AddBackward0>)
# 1420 tensor(1.1234, grad_fn=<AddBackward0>)
# 1430 tensor(1.1316, grad_fn=<AddBackward0>)
# 1440 tensor(1.1485, grad_fn=<AddBackward0>)
# 1450 tensor(1.1467, grad_fn=<AddBackward0>)
# 1460 tensor(1.0974, grad_fn=<AddBackward0>)
# 1470 tensor(1.1880, grad_fn=<AddBackward0>)
# 1480 tensor(1.1212, grad_fn=<AddBackward0>)
# 1490 tensor(1.1106, grad_fn=<AddBackward0>)
# 1500 tensor(1.1277, grad_fn=<AddBackward0>)
# 1510 tensor(1.1012, grad_fn=<AddBackward0>)
# 1520 tensor(1.0684, grad_fn=<AddBackward0>)
# 1530 tensor(1.0768, grad_fn=<AddBackward0>)
# 1540 tensor(1.0738, grad_fn=<AddBackward0>)
# 1550 tensor(1.1066, grad_fn=<AddBackward0>)
# 1560 tensor(1.1052, grad_fn=<AddBackward0>)
# 1570 tensor(1.1082, grad_fn=<AddBackward0>)
# 1580 tensor(1.0789, grad_fn=<AddBackward0>)
# 1590 tensor(1.1112, grad_fn=<AddBackward0>)
# 1600 tensor(1.0895, grad_fn=<AddBackward0>)
# 1610 tensor(1.0673, grad_fn=<AddBackward0>)
# 1620 tensor(1.0721, grad_fn=<AddBackward0>)
# 1630 tensor(1.0414, grad_fn=<AddBackward0>)
# 1640 tensor(1.0825, grad_fn=<AddBackward0>)
# 1650 tensor(1.0593, grad_fn=<AddBackward0>)
# 1660 tensor(1.0882, grad_fn=<AddBackward0>)
# 1670 tensor(1.0547, grad_fn=<AddBackward0>)
# 1680 tensor(1.0929, grad_fn=<AddBackward0>)
# 1690 tensor(1.0989, grad_fn=<AddBackward0>)
# 1700 tensor(1.0817, grad_fn=<AddBackward0>)
# 1710 tensor(1.0798, grad_fn=<AddBackward0>)
# 1720 tensor(1.0754, grad_fn=<AddBackward0>)
# 1730 tensor(0.9953, grad_fn=<AddBackward0>)
# 1740 tensor(1.0700, grad_fn=<AddBackward0>)
# 1750 tensor(1.0566, grad_fn=<AddBackward0>)
# 1760 tensor(1.0058, grad_fn=<AddBackward0>)
# 1770 tensor(1.0346, grad_fn=<AddBackward0>)
# 1780 tensor(1.0456, grad_fn=<AddBackward0>)
# 1790 tensor(1.0494, grad_fn=<AddBackward0>)
# 1800 tensor(1.0096, grad_fn=<AddBackward0>)
# 1810 tensor(1.0522, grad_fn=<AddBackward0>)
# 1820 tensor(1.0434, grad_fn=<AddBackward0>)
# 1830 tensor(1.0457, grad_fn=<AddBackward0>)
# 1840 tensor(1.0678, grad_fn=<AddBackward0>)
# 1850 tensor(1.0016, grad_fn=<AddBackward0>)
# 1860 tensor(1.0060, grad_fn=<AddBackward0>)
# 1870 tensor(1.0746, grad_fn=<AddBackward0>)
# 1880 tensor(1.0174, grad_fn=<AddBackward0>)
# 1890 tensor(1.0209, grad_fn=<AddBackward0>)
# 1900 tensor(0.9859, grad_fn=<AddBackward0>)
# 1910 tensor(1.0306, grad_fn=<AddBackward0>)
# 1920 tensor(1.0052, grad_fn=<AddBackward0>)
# 1930 tensor(1.0177, grad_fn=<AddBackward0>)
# 1940 tensor(1.0204, grad_fn=<AddBackward0>)
# 1950 tensor(0.9768, grad_fn=<AddBackward0>)
# 1960 tensor(0.9645, grad_fn=<AddBackward0>)
# 1970 tensor(0.9680, grad_fn=<AddBackward0>)
# 1980 tensor(0.9945, grad_fn=<AddBackward0>)
# 1990 tensor(0.9563, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 0 is bigger than -8.496322 then go to left, else go to right
#     LEFT:
#     WHEN feature 0 is bigger than 0.7785434 then go to left, else go to right
#         LEFT:
#         WHEN feature 3 is bigger than -0.0016914718 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 2
#         RIGHT:
#         WHEN feature 1 is bigger than -0.03632807 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 2
#     RIGHT:
#     WHEN feature 1 is bigger than -0.7670213 then go to left, else go to right
#         LEFT:
#         WHEN feature 1 is bigger than 0.18699716 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 2
#         RIGHT:
#         WHEN feature 1 is bigger than 0.4189877 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
# accuracy:
#  0.7333333333333333
# f1_score:
#  0.7157287157287157
# confusion_matrix:
#  [[5 0 1]
#  [0 2 2]
#  [0 1 4]]
# =============================================================
# (135, 4) (135,)
# (15, 4) (15,)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 64, 'l2_weight': 0.1}
# Num Label: [44 46 45]
# Label Weight: [1.04545455 1.         1.02222222]
# 0 tensor(1.1475, grad_fn=<AddBackward0>)
# 10 tensor(1.1215, grad_fn=<AddBackward0>)
# 20 tensor(1.1032, grad_fn=<AddBackward0>)
# 30 tensor(1.1152, grad_fn=<AddBackward0>)
# 40 tensor(1.0930, grad_fn=<AddBackward0>)
# 50 tensor(1.1016, grad_fn=<AddBackward0>)
# 60 tensor(1.1354, grad_fn=<AddBackward0>)
# 70 tensor(1.0847, grad_fn=<AddBackward0>)
# 80 tensor(1.0636, grad_fn=<AddBackward0>)
# 90 tensor(1.1325, grad_fn=<AddBackward0>)
# 100 tensor(1.1317, grad_fn=<AddBackward0>)
# 110 tensor(1.1166, grad_fn=<AddBackward0>)
# 120 tensor(1.1383, grad_fn=<AddBackward0>)
# 130 tensor(1.1350, grad_fn=<AddBackward0>)
# 140 tensor(1.1270, grad_fn=<AddBackward0>)
# 150 tensor(1.1175, grad_fn=<AddBackward0>)
# 160 tensor(1.1198, grad_fn=<AddBackward0>)
# 170 tensor(1.1191, grad_fn=<AddBackward0>)
# 180 tensor(1.0962, grad_fn=<AddBackward0>)
# 190 tensor(1.0797, grad_fn=<AddBackward0>)
# 200 tensor(1.0966, grad_fn=<AddBackward0>)
# 210 tensor(1.0809, grad_fn=<AddBackward0>)
# 220 tensor(1.0925, grad_fn=<AddBackward0>)
# 230 tensor(1.0704, grad_fn=<AddBackward0>)
# 240 tensor(1.0847, grad_fn=<AddBackward0>)
# 250 tensor(1.1093, grad_fn=<AddBackward0>)
# 260 tensor(1.1142, grad_fn=<AddBackward0>)
# 270 tensor(1.0813, grad_fn=<AddBackward0>)
# 280 tensor(1.0771, grad_fn=<AddBackward0>)
# 290 tensor(1.1068, grad_fn=<AddBackward0>)
# 300 tensor(1.0815, grad_fn=<AddBackward0>)
# 310 tensor(1.0828, grad_fn=<AddBackward0>)
# 320 tensor(1.1175, grad_fn=<AddBackward0>)
# 330 tensor(1.0982, grad_fn=<AddBackward0>)
# 340 tensor(1.0649, grad_fn=<AddBackward0>)
# 350 tensor(1.0754, grad_fn=<AddBackward0>)
# 360 tensor(1.0759, grad_fn=<AddBackward0>)
# 370 tensor(1.0582, grad_fn=<AddBackward0>)
# 380 tensor(1.0663, grad_fn=<AddBackward0>)
# 390 tensor(1.0649, grad_fn=<AddBackward0>)
# 400 tensor(1.0595, grad_fn=<AddBackward0>)
# 410 tensor(1.1501, grad_fn=<AddBackward0>)
# 420 tensor(1.1354, grad_fn=<AddBackward0>)
# 430 tensor(1.1340, grad_fn=<AddBackward0>)
# 440 tensor(1.1609, grad_fn=<AddBackward0>)
# 450 tensor(1.1238, grad_fn=<AddBackward0>)
# 460 tensor(1.1173, grad_fn=<AddBackward0>)
# 470 tensor(1.1054, grad_fn=<AddBackward0>)
# 480 tensor(1.1015, grad_fn=<AddBackward0>)
# 490 tensor(1.0906, grad_fn=<AddBackward0>)
# 500 tensor(1.0673, grad_fn=<AddBackward0>)
# 510 tensor(1.0755, grad_fn=<AddBackward0>)
# 520 tensor(1.0552, grad_fn=<AddBackward0>)
# 530 tensor(1.0451, grad_fn=<AddBackward0>)
# 540 tensor(1.0437, grad_fn=<AddBackward0>)
# 550 tensor(1.0994, grad_fn=<AddBackward0>)
# 560 tensor(1.1042, grad_fn=<AddBackward0>)
# 570 tensor(1.0755, grad_fn=<AddBackward0>)
# 580 tensor(1.0875, grad_fn=<AddBackward0>)
# 590 tensor(1.0841, grad_fn=<AddBackward0>)
# 600 tensor(1.0226, grad_fn=<AddBackward0>)
# 610 tensor(1.0584, grad_fn=<AddBackward0>)
# 620 tensor(1.0582, grad_fn=<AddBackward0>)
# 630 tensor(1.0573, grad_fn=<AddBackward0>)
# 640 tensor(1.0496, grad_fn=<AddBackward0>)
# 650 tensor(1.0448, grad_fn=<AddBackward0>)
# 660 tensor(1.0121, grad_fn=<AddBackward0>)
# 670 tensor(1.0306, grad_fn=<AddBackward0>)
# 680 tensor(1.0435, grad_fn=<AddBackward0>)
# 690 tensor(1.0298, grad_fn=<AddBackward0>)
# 700 tensor(1.0236, grad_fn=<AddBackward0>)
# 710 tensor(1.0329, grad_fn=<AddBackward0>)
# 720 tensor(1.0274, grad_fn=<AddBackward0>)
# 730 tensor(0.9990, grad_fn=<AddBackward0>)
# 740 tensor(1.0391, grad_fn=<AddBackward0>)
# 750 tensor(0.9992, grad_fn=<AddBackward0>)
# 760 tensor(1.0261, grad_fn=<AddBackward0>)
# 770 tensor(0.9770, grad_fn=<AddBackward0>)
# 780 tensor(0.9617, grad_fn=<AddBackward0>)
# 790 tensor(1.0126, grad_fn=<AddBackward0>)
# 800 tensor(0.9759, grad_fn=<AddBackward0>)
# 810 tensor(1.0084, grad_fn=<AddBackward0>)
# 820 tensor(0.9866, grad_fn=<AddBackward0>)
# 830 tensor(0.9664, grad_fn=<AddBackward0>)
# 840 tensor(0.9925, grad_fn=<AddBackward0>)
# 850 tensor(0.9860, grad_fn=<AddBackward0>)
# 860 tensor(0.9955, grad_fn=<AddBackward0>)
# 870 tensor(0.9442, grad_fn=<AddBackward0>)
# 880 tensor(0.9721, grad_fn=<AddBackward0>)
# 890 tensor(0.9996, grad_fn=<AddBackward0>)
# 900 tensor(0.9788, grad_fn=<AddBackward0>)
# 910 tensor(0.9692, grad_fn=<AddBackward0>)
# 920 tensor(0.9809, grad_fn=<AddBackward0>)
# 930 tensor(0.9723, grad_fn=<AddBackward0>)
# 940 tensor(0.9886, grad_fn=<AddBackward0>)
# 950 tensor(0.9825, grad_fn=<AddBackward0>)
# 960 tensor(0.9619, grad_fn=<AddBackward0>)
# 970 tensor(0.9677, grad_fn=<AddBackward0>)
# 980 tensor(0.9671, grad_fn=<AddBackward0>)
# 990 tensor(0.9490, grad_fn=<AddBackward0>)
# 1000 tensor(0.9500, grad_fn=<AddBackward0>)
# 1010 tensor(0.9604, grad_fn=<AddBackward0>)
# 1020 tensor(0.9852, grad_fn=<AddBackward0>)
# 1030 tensor(0.9785, grad_fn=<AddBackward0>)
# 1040 tensor(1.0070, grad_fn=<AddBackward0>)
# 1050 tensor(0.9816, grad_fn=<AddBackward0>)
# 1060 tensor(1.0151, grad_fn=<AddBackward0>)
# 1070 tensor(0.9776, grad_fn=<AddBackward0>)
# 1080 tensor(0.9696, grad_fn=<AddBackward0>)
# 1090 tensor(0.9504, grad_fn=<AddBackward0>)
# 1100 tensor(0.9556, grad_fn=<AddBackward0>)
# 1110 tensor(0.9607, grad_fn=<AddBackward0>)
# 1120 tensor(0.9499, grad_fn=<AddBackward0>)
# 1130 tensor(0.9599, grad_fn=<AddBackward0>)
# 1140 tensor(0.9096, grad_fn=<AddBackward0>)
# 1150 tensor(0.9772, grad_fn=<AddBackward0>)
# 1160 tensor(0.9516, grad_fn=<AddBackward0>)
# 1170 tensor(0.9544, grad_fn=<AddBackward0>)
# 1180 tensor(0.9142, grad_fn=<AddBackward0>)
# 1190 tensor(0.9850, grad_fn=<AddBackward0>)
# 1200 tensor(0.9292, grad_fn=<AddBackward0>)
# 1210 tensor(0.9745, grad_fn=<AddBackward0>)
# 1220 tensor(0.9491, grad_fn=<AddBackward0>)
# 1230 tensor(1.0129, grad_fn=<AddBackward0>)
# 1240 tensor(0.9395, grad_fn=<AddBackward0>)
# 1250 tensor(0.9727, grad_fn=<AddBackward0>)
# 1260 tensor(0.9562, grad_fn=<AddBackward0>)
# 1270 tensor(0.9346, grad_fn=<AddBackward0>)
# 1280 tensor(0.9938, grad_fn=<AddBackward0>)
# 1290 tensor(0.9844, grad_fn=<AddBackward0>)
# ...
# 970 tensor(0.9931, grad_fn=<AddBackward0>)
# 980 tensor(0.8999, grad_fn=<AddBackward0>)
# 990 tensor(0.9810, grad_fn=<AddBackward0>)
# 1000 tensor(0.9424, grad_fn=<AddBackward0>)
# 1010 tensor(0.9314, grad_fn=<AddBackward0>)
# 1020 tensor(0.8976, grad_fn=<AddBackward0>)
# 1030 tensor(0.9278, grad_fn=<AddBackward0>)
# 1040 tensor(0.9517, grad_fn=<AddBackward0>)
# 1050 tensor(0.9464, grad_fn=<AddBackward0>)
# 1060 tensor(0.9953, grad_fn=<AddBackward0>)
# 1070 tensor(0.9827, grad_fn=<AddBackward0>)
# 1080 tensor(0.9856, grad_fn=<AddBackward0>)
# 1090 tensor(0.9367, grad_fn=<AddBackward0>)
# 1100 tensor(0.9221, grad_fn=<AddBackward0>)
# 1110 tensor(0.9242, grad_fn=<AddBackward0>)
# 1120 tensor(0.9582, grad_fn=<AddBackward0>)
# 1130 tensor(0.9598, grad_fn=<AddBackward0>)
# 1140 tensor(0.8695, grad_fn=<AddBackward0>)
# 1150 tensor(0.8728, grad_fn=<AddBackward0>)
# 1160 tensor(0.9476, grad_fn=<AddBackward0>)
# 1170 tensor(0.9271, grad_fn=<AddBackward0>)
# 1180 tensor(0.9665, grad_fn=<AddBackward0>)
# 1190 tensor(0.9291, grad_fn=<AddBackward0>)
# 1200 tensor(0.9334, grad_fn=<AddBackward0>)
# 1210 tensor(0.9212, grad_fn=<AddBackward0>)
# 1220 tensor(0.8936, grad_fn=<AddBackward0>)
# 1230 tensor(0.9356, grad_fn=<AddBackward0>)
# 1240 tensor(0.8586, grad_fn=<AddBackward0>)
# 1250 tensor(0.9432, grad_fn=<AddBackward0>)
# 1260 tensor(0.9353, grad_fn=<AddBackward0>)
# 1270 tensor(0.8757, grad_fn=<AddBackward0>)
# 1280 tensor(0.9250, grad_fn=<AddBackward0>)
# 1290 tensor(0.8864, grad_fn=<AddBackward0>)
# 1300 tensor(0.9346, grad_fn=<AddBackward0>)
# 1310 tensor(0.9662, grad_fn=<AddBackward0>)
# 1320 tensor(0.9296, grad_fn=<AddBackward0>)
# 1330 tensor(0.8888, grad_fn=<AddBackward0>)
# 1340 tensor(0.9768, grad_fn=<AddBackward0>)
# 1350 tensor(0.8717, grad_fn=<AddBackward0>)
# 1360 tensor(0.9312, grad_fn=<AddBackward0>)
# 1370 tensor(0.9073, grad_fn=<AddBackward0>)
# 1380 tensor(0.9019, grad_fn=<AddBackward0>)
# 1390 tensor(0.8940, grad_fn=<AddBackward0>)
# 1400 tensor(0.8817, grad_fn=<AddBackward0>)
# 1410 tensor(0.9280, grad_fn=<AddBackward0>)
# 1420 tensor(0.9378, grad_fn=<AddBackward0>)
# 1430 tensor(1.0141, grad_fn=<AddBackward0>)
# 1440 tensor(0.9162, grad_fn=<AddBackward0>)
# 1450 tensor(0.9417, grad_fn=<AddBackward0>)
# 1460 tensor(0.9136, grad_fn=<AddBackward0>)
# 1470 tensor(0.9046, grad_fn=<AddBackward0>)
# 1480 tensor(0.9026, grad_fn=<AddBackward0>)
# 1490 tensor(0.9757, grad_fn=<AddBackward0>)
# 1500 tensor(0.9513, grad_fn=<AddBackward0>)
# 1510 tensor(0.8862, grad_fn=<AddBackward0>)
# 1520 tensor(0.9269, grad_fn=<AddBackward0>)
# 1530 tensor(0.9163, grad_fn=<AddBackward0>)
# 1540 tensor(0.9119, grad_fn=<AddBackward0>)
# 1550 tensor(0.9176, grad_fn=<AddBackward0>)
# 1560 tensor(0.9541, grad_fn=<AddBackward0>)
# 1570 tensor(0.9404, grad_fn=<AddBackward0>)
# 1580 tensor(0.9332, grad_fn=<AddBackward0>)
# 1590 tensor(0.9483, grad_fn=<AddBackward0>)
# 1600 tensor(0.9703, grad_fn=<AddBackward0>)
# 1610 tensor(0.9417, grad_fn=<AddBackward0>)
# 1620 tensor(0.8732, grad_fn=<AddBackward0>)
# 1630 tensor(0.8797, grad_fn=<AddBackward0>)
# 1640 tensor(0.8840, grad_fn=<AddBackward0>)
# 1650 tensor(0.8347, grad_fn=<AddBackward0>)
# 1660 tensor(0.9103, grad_fn=<AddBackward0>)
# 1670 tensor(0.9217, grad_fn=<AddBackward0>)
# 1680 tensor(0.8915, grad_fn=<AddBackward0>)
# 1690 tensor(0.9494, grad_fn=<AddBackward0>)
# 1700 tensor(0.9566, grad_fn=<AddBackward0>)
# 1710 tensor(0.8795, grad_fn=<AddBackward0>)
# 1720 tensor(0.8835, grad_fn=<AddBackward0>)
# 1730 tensor(0.9607, grad_fn=<AddBackward0>)
# 1740 tensor(0.9411, grad_fn=<AddBackward0>)
# 1750 tensor(1.0023, grad_fn=<AddBackward0>)
# 1760 tensor(0.8489, grad_fn=<AddBackward0>)
# 1770 tensor(0.9185, grad_fn=<AddBackward0>)
# 1780 tensor(0.8589, grad_fn=<AddBackward0>)
# 1790 tensor(0.9292, grad_fn=<AddBackward0>)
# 1800 tensor(0.8550, grad_fn=<AddBackward0>)
# 1810 tensor(0.8781, grad_fn=<AddBackward0>)
# 1820 tensor(0.8683, grad_fn=<AddBackward0>)
# 1830 tensor(0.8842, grad_fn=<AddBackward0>)
# 1840 tensor(0.9084, grad_fn=<AddBackward0>)
# 1850 tensor(0.8755, grad_fn=<AddBackward0>)
# 1860 tensor(0.9191, grad_fn=<AddBackward0>)
# 1870 tensor(0.8875, grad_fn=<AddBackward0>)
# 1880 tensor(0.9058, grad_fn=<AddBackward0>)
# 1890 tensor(0.8698, grad_fn=<AddBackward0>)
# 1900 tensor(1.0650, grad_fn=<AddBackward0>)
# 1910 tensor(1.0660, grad_fn=<AddBackward0>)
# 1920 tensor(0.9014, grad_fn=<AddBackward0>)
# 1930 tensor(0.8996, grad_fn=<AddBackward0>)
# 1940 tensor(0.9185, grad_fn=<AddBackward0>)
# 1950 tensor(0.9867, grad_fn=<AddBackward0>)
# 1960 tensor(1.0032, grad_fn=<AddBackward0>)
# 1970 tensor(0.9373, grad_fn=<AddBackward0>)
# 1980 tensor(0.7979, grad_fn=<AddBackward0>)
# 1990 tensor(0.8687, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 3 is bigger than -0.23263213 then go to left, else go to right
#     LEFT:
#     WHEN feature 1 is bigger than 0.4131285 then go to left, else go to right
#         LEFT:
#         WHEN feature 1 is bigger than 0.11333617 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 2
#         RIGHT:
#         WHEN feature 1 is bigger than 0.66298795 then go to left, else go to right
#             LEFT:
#             RETURN 2
#             RIGHT:
#             RETURN 1
#     RIGHT:
#     WHEN feature 2 is bigger than 0.3971993 then go to left, else go to right
#         LEFT:
#         WHEN feature 2 is bigger than 0.02385559 then go to left, else go to right
#             LEFT:
#             RETURN 2
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 0 is bigger than -0.03135906 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.4
# f1_score:
#  0.3696969696969697
# confusion_matrix:
#  [[5 0 0]
#  [0 1 0]
#  [1 8 0]]
# =============================================================
# (135, 4) (135,)
# (15, 4) (15,)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 64, 'l2_weight': 0.1}
# Num Label: [45 45 45]
# Label Weight: [1. 1. 1.]
# 0 tensor(1.0587, grad_fn=<AddBackward0>)
# 10 tensor(1.0557, grad_fn=<AddBackward0>)
# 20 tensor(1.0565, grad_fn=<AddBackward0>)
# 30 tensor(1.0587, grad_fn=<AddBackward0>)
# 40 tensor(1.0474, grad_fn=<AddBackward0>)
# 50 tensor(1.0474, grad_fn=<AddBackward0>)
# 60 tensor(1.0430, grad_fn=<AddBackward0>)
# 70 tensor(1.0409, grad_fn=<AddBackward0>)
# 80 tensor(1.0425, grad_fn=<AddBackward0>)
# 90 tensor(1.0402, grad_fn=<AddBackward0>)
# 100 tensor(1.0334, grad_fn=<AddBackward0>)
# 110 tensor(1.0232, grad_fn=<AddBackward0>)
# 120 tensor(1.0264, grad_fn=<AddBackward0>)
# 130 tensor(1.0189, grad_fn=<AddBackward0>)
# 140 tensor(1.0146, grad_fn=<AddBackward0>)
# 150 tensor(1.0055, grad_fn=<AddBackward0>)
# 160 tensor(1.0070, grad_fn=<AddBackward0>)
# 170 tensor(1.0066, grad_fn=<AddBackward0>)
# 180 tensor(0.9978, grad_fn=<AddBackward0>)
# 190 tensor(0.9874, grad_fn=<AddBackward0>)
# 200 tensor(0.9866, grad_fn=<AddBackward0>)
# 210 tensor(0.9984, grad_fn=<AddBackward0>)
# 220 tensor(0.9719, grad_fn=<AddBackward0>)
# 230 tensor(0.9809, grad_fn=<AddBackward0>)
# 240 tensor(0.9680, grad_fn=<AddBackward0>)
# 250 tensor(0.9634, grad_fn=<AddBackward0>)
# 260 tensor(0.9787, grad_fn=<AddBackward0>)
# 270 tensor(0.9633, grad_fn=<AddBackward0>)
# 280 tensor(0.9775, grad_fn=<AddBackward0>)
# 290 tensor(0.9522, grad_fn=<AddBackward0>)
# 300 tensor(0.9780, grad_fn=<AddBackward0>)
# 310 tensor(0.9588, grad_fn=<AddBackward0>)
# 320 tensor(0.9450, grad_fn=<AddBackward0>)
# 330 tensor(0.9570, grad_fn=<AddBackward0>)
# 340 tensor(0.9540, grad_fn=<AddBackward0>)
# 350 tensor(0.9522, grad_fn=<AddBackward0>)
# 360 tensor(0.9699, grad_fn=<AddBackward0>)
# 370 tensor(0.9707, grad_fn=<AddBackward0>)
# 380 tensor(0.9508, grad_fn=<AddBackward0>)
# 390 tensor(0.9297, grad_fn=<AddBackward0>)
# 400 tensor(0.9349, grad_fn=<AddBackward0>)
# 410 tensor(0.9303, grad_fn=<AddBackward0>)
# 420 tensor(0.9468, grad_fn=<AddBackward0>)
# 430 tensor(0.9215, grad_fn=<AddBackward0>)
# 440 tensor(0.8914, grad_fn=<AddBackward0>)
# 450 tensor(0.9494, grad_fn=<AddBackward0>)
# 460 tensor(0.9277, grad_fn=<AddBackward0>)
# 470 tensor(0.8837, grad_fn=<AddBackward0>)
# 480 tensor(0.9223, grad_fn=<AddBackward0>)
# 490 tensor(0.9307, grad_fn=<AddBackward0>)
# 500 tensor(0.8953, grad_fn=<AddBackward0>)
# 510 tensor(0.9059, grad_fn=<AddBackward0>)
# 520 tensor(0.9318, grad_fn=<AddBackward0>)
# 530 tensor(0.8779, grad_fn=<AddBackward0>)
# 540 tensor(0.9112, grad_fn=<AddBackward0>)
# 550 tensor(0.9090, grad_fn=<AddBackward0>)
# 560 tensor(0.9031, grad_fn=<AddBackward0>)
# 570 tensor(0.9230, grad_fn=<AddBackward0>)
# 580 tensor(0.8940, grad_fn=<AddBackward0>)
# 590 tensor(0.8891, grad_fn=<AddBackward0>)
# 600 tensor(0.9169, grad_fn=<AddBackward0>)
# 610 tensor(0.9086, grad_fn=<AddBackward0>)
# 620 tensor(0.8884, grad_fn=<AddBackward0>)
# 630 tensor(0.9004, grad_fn=<AddBackward0>)
# 640 tensor(0.8692, grad_fn=<AddBackward0>)
# 650 tensor(0.9013, grad_fn=<AddBackward0>)
# 660 tensor(0.8662, grad_fn=<AddBackward0>)
# 670 tensor(0.8804, grad_fn=<AddBackward0>)
# 680 tensor(0.8871, grad_fn=<AddBackward0>)
# 690 tensor(0.8815, grad_fn=<AddBackward0>)
# 700 tensor(0.8948, grad_fn=<AddBackward0>)
# 710 tensor(0.9278, grad_fn=<AddBackward0>)
# 720 tensor(0.9178, grad_fn=<AddBackward0>)
# 730 tensor(0.8755, grad_fn=<AddBackward0>)
# 740 tensor(0.9161, grad_fn=<AddBackward0>)
# 750 tensor(0.8440, grad_fn=<AddBackward0>)
# 760 tensor(0.8402, grad_fn=<AddBackward0>)
# 770 tensor(0.8887, grad_fn=<AddBackward0>)
# 780 tensor(0.8489, grad_fn=<AddBackward0>)
# 790 tensor(0.8450, grad_fn=<AddBackward0>)
# 800 tensor(0.8740, grad_fn=<AddBackward0>)
# 810 tensor(0.8643, grad_fn=<AddBackward0>)
# 820 tensor(0.8539, grad_fn=<AddBackward0>)
# 830 tensor(0.8609, grad_fn=<AddBackward0>)
# 840 tensor(0.8554, grad_fn=<AddBackward0>)
# 850 tensor(0.8699, grad_fn=<AddBackward0>)
# 860 tensor(0.8196, grad_fn=<AddBackward0>)
# 870 tensor(0.8491, grad_fn=<AddBackward0>)
# 880 tensor(0.8266, grad_fn=<AddBackward0>)
# 890 tensor(0.8802, grad_fn=<AddBackward0>)
# 900 tensor(0.8685, grad_fn=<AddBackward0>)
# 910 tensor(0.8366, grad_fn=<AddBackward0>)
# 920 tensor(0.8400, grad_fn=<AddBackward0>)
# 930 tensor(0.8633, grad_fn=<AddBackward0>)
# 940 tensor(0.8406, grad_fn=<AddBackward0>)
# 950 tensor(0.8605, grad_fn=<AddBackward0>)
# 960 tensor(0.8407, grad_fn=<AddBackward0>)
# 970 tensor(0.8279, grad_fn=<AddBackward0>)
# 980 tensor(0.8302, grad_fn=<AddBackward0>)
# 990 tensor(0.8344, grad_fn=<AddBackward0>)
# 1000 tensor(0.8034, grad_fn=<AddBackward0>)
# 1010 tensor(0.8182, grad_fn=<AddBackward0>)
# 1020 tensor(0.8557, grad_fn=<AddBackward0>)
# 1030 tensor(0.8647, grad_fn=<AddBackward0>)
# 1040 tensor(0.8542, grad_fn=<AddBackward0>)
# 1050 tensor(0.8382, grad_fn=<AddBackward0>)
# 1060 tensor(0.8037, grad_fn=<AddBackward0>)
# 1070 tensor(0.8319, grad_fn=<AddBackward0>)
# 1080 tensor(0.8244, grad_fn=<AddBackward0>)
# 1090 tensor(0.8231, grad_fn=<AddBackward0>)
# 1100 tensor(0.8327, grad_fn=<AddBackward0>)
# 1110 tensor(0.7484, grad_fn=<AddBackward0>)
# 1120 tensor(0.7565, grad_fn=<AddBackward0>)
# 1130 tensor(0.8546, grad_fn=<AddBackward0>)
# 1140 tensor(0.7532, grad_fn=<AddBackward0>)
# 1150 tensor(0.8158, grad_fn=<AddBackward0>)
# 1160 tensor(0.7647, grad_fn=<AddBackward0>)
# 1170 tensor(0.7702, grad_fn=<AddBackward0>)
# 1180 tensor(0.8158, grad_fn=<AddBackward0>)
# 1190 tensor(0.8102, grad_fn=<AddBackward0>)
# 1200 tensor(0.7735, grad_fn=<AddBackward0>)
# 1210 tensor(0.8084, grad_fn=<AddBackward0>)
# 1220 tensor(0.8039, grad_fn=<AddBackward0>)
# 1230 tensor(0.7363, grad_fn=<AddBackward0>)
# 1240 tensor(0.7432, grad_fn=<AddBackward0>)
# 1250 tensor(0.7309, grad_fn=<AddBackward0>)
# 1260 tensor(0.7491, grad_fn=<AddBackward0>)
# 1270 tensor(0.7440, grad_fn=<AddBackward0>)
# 1280 tensor(0.7912, grad_fn=<AddBackward0>)
# 1290 tensor(0.7891, grad_fn=<AddBackward0>)
# 1300 tensor(0.7675, grad_fn=<AddBackward0>)
# 1310 tensor(0.7671, grad_fn=<AddBackward0>)
# 1320 tensor(0.7085, grad_fn=<AddBackward0>)
# 1330 tensor(0.7437, grad_fn=<AddBackward0>)
# 1340 tensor(0.7788, grad_fn=<AddBackward0>)
# 1350 tensor(0.7684, grad_fn=<AddBackward0>)
# 1360 tensor(0.7654, grad_fn=<AddBackward0>)
# 1370 tensor(0.7949, grad_fn=<AddBackward0>)
# 1380 tensor(0.7522, grad_fn=<AddBackward0>)
# 1390 tensor(0.7261, grad_fn=<AddBackward0>)
# 1400 tensor(0.7615, grad_fn=<AddBackward0>)
# 1410 tensor(0.7503, grad_fn=<AddBackward0>)
# 1420 tensor(0.7703, grad_fn=<AddBackward0>)
# 1430 tensor(0.7893, grad_fn=<AddBackward0>)
# 1440 tensor(0.7457, grad_fn=<AddBackward0>)
# 1450 tensor(0.6734, grad_fn=<AddBackward0>)
# 1460 tensor(0.7230, grad_fn=<AddBackward0>)
# 1470 tensor(0.7577, grad_fn=<AddBackward0>)
# 1480 tensor(0.7253, grad_fn=<AddBackward0>)
# 1490 tensor(0.7217, grad_fn=<AddBackward0>)
# 1500 tensor(0.7287, grad_fn=<AddBackward0>)
# 1510 tensor(0.7783, grad_fn=<AddBackward0>)
# 1520 tensor(0.6813, grad_fn=<AddBackward0>)
# 1530 tensor(0.7277, grad_fn=<AddBackward0>)
# 1540 tensor(0.6317, grad_fn=<AddBackward0>)
# 1550 tensor(0.7206, grad_fn=<AddBackward0>)
# 1560 tensor(0.7265, grad_fn=<AddBackward0>)
# 1570 tensor(0.7420, grad_fn=<AddBackward0>)
# 1580 tensor(0.7432, grad_fn=<AddBackward0>)
# 1590 tensor(0.7963, grad_fn=<AddBackward0>)
# 1600 tensor(0.7301, grad_fn=<AddBackward0>)
# 1610 tensor(0.6928, grad_fn=<AddBackward0>)
# 1620 tensor(0.7927, grad_fn=<AddBackward0>)
# 1630 tensor(0.7750, grad_fn=<AddBackward0>)
# 1640 tensor(0.7153, grad_fn=<AddBackward0>)
# 1650 tensor(0.7117, grad_fn=<AddBackward0>)
# 1660 tensor(0.7753, grad_fn=<AddBackward0>)
# 1670 tensor(0.6954, grad_fn=<AddBackward0>)
# 1680 tensor(0.7319, grad_fn=<AddBackward0>)
# 1690 tensor(0.6612, grad_fn=<AddBackward0>)
# 1700 tensor(0.7658, grad_fn=<AddBackward0>)
# 1710 tensor(0.6601, grad_fn=<AddBackward0>)
# 1720 tensor(0.6841, grad_fn=<AddBackward0>)
# 1730 tensor(0.7194, grad_fn=<AddBackward0>)
# 1740 tensor(0.7100, grad_fn=<AddBackward0>)
# 1750 tensor(0.7561, grad_fn=<AddBackward0>)
# 1760 tensor(0.7085, grad_fn=<AddBackward0>)
# 1770 tensor(0.7244, grad_fn=<AddBackward0>)
# 1780 tensor(0.6369, grad_fn=<AddBackward0>)
# 1790 tensor(0.6712, grad_fn=<AddBackward0>)
# 1800 tensor(0.6664, grad_fn=<AddBackward0>)
# 1810 tensor(0.7257, grad_fn=<AddBackward0>)
# 1820 tensor(0.6753, grad_fn=<AddBackward0>)
# 1830 tensor(0.7068, grad_fn=<AddBackward0>)
# 1840 tensor(0.7604, grad_fn=<AddBackward0>)
# 1850 tensor(0.6847, grad_fn=<AddBackward0>)
# 1860 tensor(0.7674, grad_fn=<AddBackward0>)
# 1870 tensor(0.7548, grad_fn=<AddBackward0>)
# 1880 tensor(0.7049, grad_fn=<AddBackward0>)
# 1890 tensor(0.6752, grad_fn=<AddBackward0>)
# 1900 tensor(0.6847, grad_fn=<AddBackward0>)
# 1910 tensor(0.7490, grad_fn=<AddBackward0>)
# 1920 tensor(0.7361, grad_fn=<AddBackward0>)
# 1930 tensor(0.7921, grad_fn=<AddBackward0>)
# 1940 tensor(0.6227, grad_fn=<AddBackward0>)
# 1950 tensor(0.6120, grad_fn=<AddBackward0>)
# 1960 tensor(0.7507, grad_fn=<AddBackward0>)
# 1970 tensor(0.6788, grad_fn=<AddBackward0>)
# 1980 tensor(0.7521, grad_fn=<AddBackward0>)
# 1990 tensor(0.6742, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 2 is bigger than -0.40208644 then go to left, else go to right
#     LEFT:
#     WHEN feature 3 is bigger than 0.32766026 then go to left, else go to right
#         LEFT:
#         WHEN feature 3 is bigger than -0.13273147 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 2
#         RIGHT:
#         WHEN feature 1 is bigger than 0.22189465 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 2
#     RIGHT:
#     WHEN feature 1 is bigger than 0.03639078 then go to left, else go to right
#         LEFT:
#         WHEN feature 3 is bigger than -0.018297898 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 3 is bigger than 0.03760791 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.7333333333333333
# f1_score:
#  0.712121212121212
# confusion_matrix:
#  [[5 0 0]
#  [0 4 1]
#  [1 2 2]]

# %%
print("accuracy:\n", np.array(all_results['accuracy']).mean())
print("f1_score:\n", np.array(all_results['f1_score']).mean())
print("confusion_matrix:\n", np.array(all_results['confusion_matrix']).mean(0))
# Out:
# accuracy:
#  0.6
# f1_score:
#  0.5746547896547897
# confusion_matrix:
#  [[3.9 0.6 0.5]
#  [0.1 2.2 2.7]
#  [0.3 1.8 2.9]]

# %% [markdown]
# # Pima Indians Diabetes Database

# %%
# !wget https://raw.githubusercontent.com/jbrownlee/Datasets/refs/heads/master/pima-indians-diabetes.csv
# Out:
# --2024-10-26 12:08:43--  https://raw.githubusercontent.com/jbrownlee/Datasets/refs/heads/master/pima-indians-diabetes.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23278 (23K) [text/plain]
# Saving to: ‘pima-indians-diabetes.csv.3’
#
# pima-indians-diabet 100%[===================>]  22.73K  --.-KB/s    in 0.006s
#
# 2024-10-26 12:08:44 (3.49 MB/s) - ‘pima-indians-diabetes.csv.3’ saved [23278/23278]

# %%
def load_pima_diabetes_data(filepath):
  data = pd.read_csv(filepath)
  data.columns = [
      "Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin",
      "BMI", "DiabetesPedigreeFunction", "Age", "Outcome"
  ]

  return data

# %%
df = load_pima_diabetes_data("/content/pima-indians-diabetes.csv").to_numpy()

# %%
pima_dataset = load_pima_diabetes_data("/content/pima-indians-diabetes.csv")
pima_dataset = pima_dataset.to_numpy()
np.random.shuffle(pima_dataset)

x_all = pima_dataset[:,0:-1]
y_all = pima_dataset[:,-1:]

# %%
all_results, all_model = k_fold(x_all, y_all, num_k = 10, use_mlp = False, normalize = True, batch_size = 256,
                                l2_weight=0, label_weight_power = 1.5, focus_on_cont=True)
# Out:
# =============================================================
# (691, 8) (691, 1)
# (76, 8) (76, 1)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 256, 'l2_weight': 0, 'label_weight_power': 1.5, 'focus_on_cont': True}
# Num Label: [450 241]
# Label Weight: [1.        2.5514861]
# 0 tensor(1.0698, grad_fn=<AddBackward0>)
# 10 tensor(1.0499, grad_fn=<AddBackward0>)
# 20 tensor(0.9922, grad_fn=<AddBackward0>)
# 30 tensor(1.0673, grad_fn=<AddBackward0>)
# 40 tensor(1.0447, grad_fn=<AddBackward0>)
# 50 tensor(1.0306, grad_fn=<AddBackward0>)
# 60 tensor(1.1007, grad_fn=<AddBackward0>)
# 70 tensor(1.0619, grad_fn=<AddBackward0>)
# 80 tensor(1.0759, grad_fn=<AddBackward0>)
# 90 tensor(1.0599, grad_fn=<AddBackward0>)
# 100 tensor(1.0384, grad_fn=<AddBackward0>)
# 110 tensor(1.0500, grad_fn=<AddBackward0>)
# 120 tensor(1.0783, grad_fn=<AddBackward0>)
# 130 tensor(1.0914, grad_fn=<AddBackward0>)
# 140 tensor(1.0380, grad_fn=<AddBackward0>)
# 150 tensor(1.0693, grad_fn=<AddBackward0>)
# 160 tensor(1.0747, grad_fn=<AddBackward0>)
# 170 tensor(1.0352, grad_fn=<AddBackward0>)
# 180 tensor(0.9967, grad_fn=<AddBackward0>)
# 190 tensor(1.0614, grad_fn=<AddBackward0>)
# 200 tensor(1.0534, grad_fn=<AddBackward0>)
# 210 tensor(1.0277, grad_fn=<AddBackward0>)
# 220 tensor(1.0574, grad_fn=<AddBackward0>)
# 230 tensor(1.1181, grad_fn=<AddBackward0>)
# 240 tensor(1.1148, grad_fn=<AddBackward0>)
# 250 tensor(1.0436, grad_fn=<AddBackward0>)
# 260 tensor(1.0659, grad_fn=<AddBackward0>)
# 270 tensor(1.0542, grad_fn=<AddBackward0>)
# 280 tensor(1.0424, grad_fn=<AddBackward0>)
# 290 tensor(1.0523, grad_fn=<AddBackward0>)
# 300 tensor(1.0997, grad_fn=<AddBackward0>)
# 310 tensor(1.0430, grad_fn=<AddBackward0>)
# 320 tensor(1.0896, grad_fn=<AddBackward0>)
# 330 tensor(1.0286, grad_fn=<AddBackward0>)
# 340 tensor(1.0324, grad_fn=<AddBackward0>)
# 350 tensor(1.0515, grad_fn=<AddBackward0>)
# 360 tensor(1.0832, grad_fn=<AddBackward0>)
# 370 tensor(1.0181, grad_fn=<AddBackward0>)
# 380 tensor(1.1027, grad_fn=<AddBackward0>)
# 390 tensor(1.0808, grad_fn=<AddBackward0>)
# 400 tensor(1.1128, grad_fn=<AddBackward0>)
# 410 tensor(1.0784, grad_fn=<AddBackward0>)
# 420 tensor(1.1618, grad_fn=<AddBackward0>)
# 430 tensor(1.0194, grad_fn=<AddBackward0>)
# 440 tensor(1.0626, grad_fn=<AddBackward0>)
# 450 tensor(1.0503, grad_fn=<AddBackward0>)
# 460 tensor(0.9992, grad_fn=<AddBackward0>)
# 470 tensor(1.0270, grad_fn=<AddBackward0>)
# 480 tensor(1.0722, grad_fn=<AddBackward0>)
# 490 tensor(1.0985, grad_fn=<AddBackward0>)
# 500 tensor(1.0991, grad_fn=<AddBackward0>)
# 510 tensor(1.0791, grad_fn=<AddBackward0>)
# 520 tensor(1.0962, grad_fn=<AddBackward0>)
# 530 tensor(1.0232, grad_fn=<AddBackward0>)
# 540 tensor(1.1289, grad_fn=<AddBackward0>)
# 550 tensor(1.0865, grad_fn=<AddBackward0>)
# 560 tensor(1.0692, grad_fn=<AddBackward0>)
# 570 tensor(1.1327, grad_fn=<AddBackward0>)
# 580 tensor(1.0721, grad_fn=<AddBackward0>)
# 590 tensor(1.0840, grad_fn=<AddBackward0>)
# 600 tensor(1.0574, grad_fn=<AddBackward0>)
# 610 tensor(1.1289, grad_fn=<AddBackward0>)
# 620 tensor(1.0862, grad_fn=<AddBackward0>)
# 630 tensor(1.0113, grad_fn=<AddBackward0>)
# 640 tensor(1.0817, grad_fn=<AddBackward0>)
# 650 tensor(1.0722, grad_fn=<AddBackward0>)
# 660 tensor(1.0778, grad_fn=<AddBackward0>)
# 670 tensor(1.0404, grad_fn=<AddBackward0>)
# 680 tensor(1.0707, grad_fn=<AddBackward0>)
# 690 tensor(1.0807, grad_fn=<AddBackward0>)
# 700 tensor(1.0299, grad_fn=<AddBackward0>)
# 710 tensor(1.1244, grad_fn=<AddBackward0>)
# 720 tensor(1.0742, grad_fn=<AddBackward0>)
# 730 tensor(1.0431, grad_fn=<AddBackward0>)
# 740 tensor(1.0772, grad_fn=<AddBackward0>)
# 750 tensor(1.0526, grad_fn=<AddBackward0>)
# 760 tensor(1.0113, grad_fn=<AddBackward0>)
# 770 tensor(1.0585, grad_fn=<AddBackward0>)
# 780 tensor(1.1595, grad_fn=<AddBackward0>)
# 790 tensor(0.9964, grad_fn=<AddBackward0>)
# 800 tensor(1.0817, grad_fn=<AddBackward0>)
# 810 tensor(1.0881, grad_fn=<AddBackward0>)
# 820 tensor(1.0804, grad_fn=<AddBackward0>)
# 830 tensor(1.0716, grad_fn=<AddBackward0>)
# 840 tensor(1.0329, grad_fn=<AddBackward0>)
# 850 tensor(1.0627, grad_fn=<AddBackward0>)
# 860 tensor(1.0664, grad_fn=<AddBackward0>)
# 870 tensor(1.0489, grad_fn=<AddBackward0>)
# 880 tensor(1.1169, grad_fn=<AddBackward0>)
# 890 tensor(1.0366, grad_fn=<AddBackward0>)
# 900 tensor(1.1154, grad_fn=<AddBackward0>)
# 910 tensor(1.0396, grad_fn=<AddBackward0>)
# 920 tensor(1.0408, grad_fn=<AddBackward0>)
# 930 tensor(1.0428, grad_fn=<AddBackward0>)
# 940 tensor(1.0307, grad_fn=<AddBackward0>)
# 950 tensor(1.0534, grad_fn=<AddBackward0>)
# 960 tensor(1.0629, grad_fn=<AddBackward0>)
# 970 tensor(1.1254, grad_fn=<AddBackward0>)
# 980 tensor(1.1291, grad_fn=<AddBackward0>)
# 990 tensor(1.0210, grad_fn=<AddBackward0>)
# 1000 tensor(1.0452, grad_fn=<AddBackward0>)
# 1010 tensor(1.0640, grad_fn=<AddBackward0>)
# 1020 tensor(1.0160, grad_fn=<AddBackward0>)
# 1030 tensor(1.0059, grad_fn=<AddBackward0>)
# 1040 tensor(1.0553, grad_fn=<AddBackward0>)
# 1050 tensor(1.0587, grad_fn=<AddBackward0>)
# 1060 tensor(1.0291, grad_fn=<AddBackward0>)
# 1070 tensor(1.0572, grad_fn=<AddBackward0>)
# 1080 tensor(1.1325, grad_fn=<AddBackward0>)
# 1090 tensor(1.0378, grad_fn=<AddBackward0>)
# 1100 tensor(1.0726, grad_fn=<AddBackward0>)
# 1110 tensor(0.9934, grad_fn=<AddBackward0>)
# 1120 tensor(1.0608, grad_fn=<AddBackward0>)
# 1130 tensor(1.0160, grad_fn=<AddBackward0>)
# 1140 tensor(1.0930, grad_fn=<AddBackward0>)
# 1150 tensor(1.0895, grad_fn=<AddBackward0>)
# 1160 tensor(1.0117, grad_fn=<AddBackward0>)
# 1170 tensor(1.1033, grad_fn=<AddBackward0>)
# 1180 tensor(1.0365, grad_fn=<AddBackward0>)
# 1190 tensor(1.0910, grad_fn=<AddBackward0>)
# 1200 tensor(1.1208, grad_fn=<AddBackward0>)
# 1210 tensor(1.0437, grad_fn=<AddBackward0>)
# 1220 tensor(1.0759, grad_fn=<AddBackward0>)
# 1230 tensor(1.0627, grad_fn=<AddBackward0>)
# 1240 tensor(1.0274, grad_fn=<AddBackward0>)
# 1250 tensor(1.0699, grad_fn=<AddBackward0>)
# 1260 tensor(1.0403, grad_fn=<AddBackward0>)
# 1270 tensor(1.0786, grad_fn=<AddBackward0>)
# 1280 tensor(1.0871, grad_fn=<AddBackward0>)
# 1290 tensor(1.0794, grad_fn=<AddBackward0>)
# 1300 tensor(1.0320, grad_fn=<AddBackward0>)
# 1310 tensor(1.1093, grad_fn=<AddBackward0>)
# 1320 tensor(1.0933, grad_fn=<AddBackward0>)
# 1330 tensor(1.0699, grad_fn=<AddBackward0>)
# 1340 tensor(1.0577, grad_fn=<AddBackward0>)
# 1350 tensor(1.0571, grad_fn=<AddBackward0>)
# 1360 tensor(1.0596, grad_fn=<AddBackward0>)
# 1370 tensor(1.0444, grad_fn=<AddBackward0>)
# 1380 tensor(1.0420, grad_fn=<AddBackward0>)
# 1390 tensor(1.1003, grad_fn=<AddBackward0>)
# 1400 tensor(1.0567, grad_fn=<AddBackward0>)
# 1410 tensor(1.0814, grad_fn=<AddBackward0>)
# 1420 tensor(1.0845, grad_fn=<AddBackward0>)
# 1430 tensor(1.0736, grad_fn=<AddBackward0>)
# 1440 tensor(1.0461, grad_fn=<AddBackward0>)
# 1450 tensor(1.1145, grad_fn=<AddBackward0>)
# 1460 tensor(1.1028, grad_fn=<AddBackward0>)
# 1470 tensor(1.0939, grad_fn=<AddBackward0>)
# 1480 tensor(1.0284, grad_fn=<AddBackward0>)
# 1490 tensor(1.0998, grad_fn=<AddBackward0>)
# 1500 tensor(1.0698, grad_fn=<AddBackward0>)
# 1510 tensor(1.0676, grad_fn=<AddBackward0>)
# 1520 tensor(1.1707, grad_fn=<AddBackward0>)
# 1530 tensor(1.0530, grad_fn=<AddBackward0>)
# 1540 tensor(1.0458, grad_fn=<AddBackward0>)
# 1550 tensor(1.0709, grad_fn=<AddBackward0>)
# 1560 tensor(1.0530, grad_fn=<AddBackward0>)
# 1570 tensor(1.0657, grad_fn=<AddBackward0>)
# 1580 tensor(1.0338, grad_fn=<AddBackward0>)
# 1590 tensor(1.0529, grad_fn=<AddBackward0>)
# 1600 tensor(1.0571, grad_fn=<AddBackward0>)
# 1610 tensor(1.0457, grad_fn=<AddBackward0>)
# 1620 tensor(1.0146, grad_fn=<AddBackward0>)
# 1630 tensor(1.0816, grad_fn=<AddBackward0>)
# 1640 tensor(1.0992, grad_fn=<AddBackward0>)
# 1650 tensor(1.0818, grad_fn=<AddBackward0>)
# 1660 tensor(1.0764, grad_fn=<AddBackward0>)
# 1670 tensor(1.1041, grad_fn=<AddBackward0>)
# 1680 tensor(1.0577, grad_fn=<AddBackward0>)
# 1690 tensor(1.0496, grad_fn=<AddBackward0>)
# 1700 tensor(1.0041, grad_fn=<AddBackward0>)
# 1710 tensor(1.0923, grad_fn=<AddBackward0>)
# 1720 tensor(1.0658, grad_fn=<AddBackward0>)
# 1730 tensor(0.9861, grad_fn=<AddBackward0>)
# 1740 tensor(0.9825, grad_fn=<AddBackward0>)
# 1750 tensor(1.0587, grad_fn=<AddBackward0>)
# 1760 tensor(1.0885, grad_fn=<AddBackward0>)
# 1770 tensor(1.0750, grad_fn=<AddBackward0>)
# 1780 tensor(1.0387, grad_fn=<AddBackward0>)
# 1790 tensor(1.0568, grad_fn=<AddBackward0>)
# 1800 tensor(1.0156, grad_fn=<AddBackward0>)
# 1810 tensor(1.0345, grad_fn=<AddBackward0>)
# 1820 tensor(1.0752, grad_fn=<AddBackward0>)
# 1830 tensor(1.0847, grad_fn=<AddBackward0>)
# 1840 tensor(1.0391, grad_fn=<AddBackward0>)
# 1850 tensor(1.0603, grad_fn=<AddBackward0>)
# 1860 tensor(1.0514, grad_fn=<AddBackward0>)
# 1870 tensor(1.0516, grad_fn=<AddBackward0>)
# 1880 tensor(1.0543, grad_fn=<AddBackward0>)
# 1890 tensor(1.0439, grad_fn=<AddBackward0>)
# 1900 tensor(1.0335, grad_fn=<AddBackward0>)
# 1910 tensor(1.0735, grad_fn=<AddBackward0>)
# 1920 tensor(1.0607, grad_fn=<AddBackward0>)
# 1930 tensor(1.0582, grad_fn=<AddBackward0>)
# 1940 tensor(1.0907, grad_fn=<AddBackward0>)
# 1950 tensor(1.0741, grad_fn=<AddBackward0>)
# 1960 tensor(1.0537, grad_fn=<AddBackward0>)
# 1970 tensor(1.1005, grad_fn=<AddBackward0>)
# 1980 tensor(1.0786, grad_fn=<AddBackward0>)
# 1990 tensor(1.0708, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 7 is bigger than 1.2879696 then go to left, else go to right
#     LEFT:
#     WHEN feature 3 is bigger than -1.304034 then go to left, else go to right
#         LEFT:
#         WHEN feature 7 is bigger than 12.450459 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 3 is bigger than -3.1429648 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
#     RIGHT:
#     WHEN feature 7 is bigger than -0.22136866 then go to left, else go to right
#         LEFT:
#         WHEN feature 4 is bigger than -1.649468 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 4 is bigger than -0.39932212 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.6578947368421053
# f1_score:
#  0.3968253968253968
# confusion_matrix:
#  [[50  0]
#  [26  0]]
# =============================================================
# (691, 8) (691, 1)
# (76, 8) (76, 1)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 256, 'l2_weight': 0, 'label_weight_power': 1.5, 'focus_on_cont': True}
# Num Label: [453 238]
# Label Weight: [1.         2.62592228]
# 0 tensor(1.0924, grad_fn=<AddBackward0>)
# 10 tensor(1.1008, grad_fn=<AddBackward0>)
# 20 tensor(1.1344, grad_fn=<AddBackward0>)
# 30 tensor(1.0709, grad_fn=<AddBackward0>)
# 40 tensor(1.0974, grad_fn=<AddBackward0>)
# 50 tensor(1.1106, grad_fn=<AddBackward0>)
# 60 tensor(1.1085, grad_fn=<AddBackward0>)
# 70 tensor(1.1186, grad_fn=<AddBackward0>)
# 80 tensor(1.0590, grad_fn=<AddBackward0>)
# 90 tensor(1.0464, grad_fn=<AddBackward0>)
# 100 tensor(1.0742, grad_fn=<AddBackward0>)
# 110 tensor(1.0430, grad_fn=<AddBackward0>)
# 120 tensor(1.1005, grad_fn=<AddBackward0>)
# 130 tensor(1.0908, grad_fn=<AddBackward0>)
# 140 tensor(1.1194, grad_fn=<AddBackward0>)
# 150 tensor(1.0861, grad_fn=<AddBackward0>)
# 160 tensor(1.0584, grad_fn=<AddBackward0>)
# 170 tensor(1.1204, grad_fn=<AddBackward0>)
# 180 tensor(1.0400, grad_fn=<AddBackward0>)
# 190 tensor(1.1081, grad_fn=<AddBackward0>)
# 200 tensor(1.1022, grad_fn=<AddBackward0>)
# 210 tensor(1.0201, grad_fn=<AddBackward0>)
# 220 tensor(1.0715, grad_fn=<AddBackward0>)
# 230 tensor(1.0890, grad_fn=<AddBackward0>)
# 240 tensor(1.0322, grad_fn=<AddBackward0>)
# 250 tensor(1.0862, grad_fn=<AddBackward0>)
# 260 tensor(1.0787, grad_fn=<AddBackward0>)
# 270 tensor(1.0345, grad_fn=<AddBackward0>)
# 280 tensor(1.0506, grad_fn=<AddBackward0>)
# 290 tensor(1.0999, grad_fn=<AddBackward0>)
# 300 tensor(1.0473, grad_fn=<AddBackward0>)
# 310 tensor(1.0627, grad_fn=<AddBackward0>)
# 320 tensor(1.0519, grad_fn=<AddBackward0>)
# 330 tensor(1.1489, grad_fn=<AddBackward0>)
# 340 tensor(1.0917, grad_fn=<AddBackward0>)
# 350 tensor(1.0806, grad_fn=<AddBackward0>)
# 360 tensor(1.0763, grad_fn=<AddBackward0>)
# 370 tensor(1.0462, grad_fn=<AddBackward0>)
# 380 tensor(1.1084, grad_fn=<AddBackward0>)
# 390 tensor(1.0855, grad_fn=<AddBackward0>)
# 400 tensor(1.0616, grad_fn=<AddBackward0>)
# 410 tensor(1.0278, grad_fn=<AddBackward0>)
# 420 tensor(1.0725, grad_fn=<AddBackward0>)
# 430 tensor(1.0502, grad_fn=<AddBackward0>)
# 440 tensor(1.0711, grad_fn=<AddBackward0>)
# 450 tensor(1.1134, grad_fn=<AddBackward0>)
# 460 tensor(1.0122, grad_fn=<AddBackward0>)
# 470 tensor(1.0445, grad_fn=<AddBackward0>)
# 480 tensor(1.1040, grad_fn=<AddBackward0>)
# 490 tensor(1.0621, grad_fn=<AddBackward0>)
# 500 tensor(1.0691, grad_fn=<AddBackward0>)
# 510 tensor(1.0705, grad_fn=<AddBackward0>)
# 520 tensor(1.0279, grad_fn=<AddBackward0>)
# 530 tensor(1.0530, grad_fn=<AddBackward0>)
# 540 tensor(1.0947, grad_fn=<AddBackward0>)
# 550 tensor(1.0677, grad_fn=<AddBackward0>)
# 560 tensor(1.0279, grad_fn=<AddBackward0>)
# 570 tensor(1.0701, grad_fn=<AddBackward0>)
# 580 tensor(1.1028, grad_fn=<AddBackward0>)
# 590 tensor(1.0861, grad_fn=<AddBackward0>)
# 600 tensor(1.0476, grad_fn=<AddBackward0>)
# 610 tensor(1.0953, grad_fn=<AddBackward0>)
# 620 tensor(1.1075, grad_fn=<AddBackward0>)
# 630 tensor(1.0348, grad_fn=<AddBackward0>)
# 640 tensor(1.0462, grad_fn=<AddBackward0>)
# 650 tensor(1.0194, grad_fn=<AddBackward0>)
# 660 tensor(1.0717, grad_fn=<AddBackward0>)
# 670 tensor(1.0402, grad_fn=<AddBackward0>)
# 680 tensor(1.0856, grad_fn=<AddBackward0>)
# 690 tensor(1.0792, grad_fn=<AddBackward0>)
# 700 tensor(1.0749, grad_fn=<AddBackward0>)
# 710 tensor(1.0452, grad_fn=<AddBackward0>)
# 720 tensor(1.0876, grad_fn=<AddBackward0>)
# 730 tensor(1.0232, grad_fn=<AddBackward0>)
# 740 tensor(1.0533, grad_fn=<AddBackward0>)
# 750 tensor(1.0187, grad_fn=<AddBackward0>)
# 760 tensor(1.0900, grad_fn=<AddBackward0>)
# 770 tensor(1.0696, grad_fn=<AddBackward0>)
# 780 tensor(1.0862, grad_fn=<AddBackward0>)
# 790 tensor(1.0437, grad_fn=<AddBackward0>)
# 800 tensor(1.1279, grad_fn=<AddBackward0>)
# 810 tensor(1.0752, grad_fn=<AddBackward0>)
# 820 tensor(1.0450, grad_fn=<AddBackward0>)
# 830 tensor(1.0378, grad_fn=<AddBackward0>)
# 840 tensor(1.0611, grad_fn=<AddBackward0>)
# 850 tensor(1.0310, grad_fn=<AddBackward0>)
# 860 tensor(1.1400, grad_fn=<AddBackward0>)
# 870 tensor(1.0802, grad_fn=<AddBackward0>)
# 880 tensor(1.1227, grad_fn=<AddBackward0>)
# 890 tensor(1.2063, grad_fn=<AddBackward0>)
# 900 tensor(1.0118, grad_fn=<AddBackward0>)
# 910 tensor(1.0593, grad_fn=<AddBackward0>)
# 920 tensor(1.0625, grad_fn=<AddBackward0>)
# 930 tensor(1.0364, grad_fn=<AddBackward0>)
# 940 tensor(1.0525, grad_fn=<AddBackward0>)
# 950 tensor(1.0695, grad_fn=<AddBackward0>)
# 960 tensor(1.0531, grad_fn=<AddBackward0>)
# 970 tensor(1.1000, grad_fn=<AddBackward0>)
# 980 tensor(1.0589, grad_fn=<AddBackward0>)
# 990 tensor(1.1032, grad_fn=<AddBackward0>)
# 1000 tensor(1.0098, grad_fn=<AddBackward0>)
# 1010 tensor(1.0714, grad_fn=<AddBackward0>)
# 1020 tensor(1.0912, grad_fn=<AddBackward0>)
# 1030 tensor(1.0782, grad_fn=<AddBackward0>)
# 1040 tensor(1.0304, grad_fn=<AddBackward0>)
# 1050 tensor(1.1523, grad_fn=<AddBackward0>)
# 1060 tensor(1.0951, grad_fn=<AddBackward0>)
# 1070 tensor(1.0576, grad_fn=<AddBackward0>)
# 1080 tensor(1.0884, grad_fn=<AddBackward0>)
# 1090 tensor(1.0234, grad_fn=<AddBackward0>)
# 1100 tensor(1.0670, grad_fn=<AddBackward0>)
# 1110 tensor(1.0808, grad_fn=<AddBackward0>)
# 1120 tensor(1.0778, grad_fn=<AddBackward0>)
# 1130 tensor(1.0413, grad_fn=<AddBackward0>)
# 1140 tensor(1.0936, grad_fn=<AddBackward0>)
# 1150 tensor(1.0843, grad_fn=<AddBackward0>)
# 1160 tensor(1.0773, grad_fn=<AddBackward0>)
# 1170 tensor(1.1609, grad_fn=<AddBackward0>)
# 1180 tensor(1.1528, grad_fn=<AddBackward0>)
# 1190 tensor(1.0597, grad_fn=<AddBackward0>)
# 1200 tensor(1.1024, grad_fn=<AddBackward0>)
# 1210 tensor(1.0643, grad_fn=<AddBackward0>)
# 1220 tensor(1.1246, grad_fn=<AddBackward0>)
# 1230 tensor(1.0632, grad_fn=<AddBackward0>)
# 1240 tensor(1.0585, grad_fn=<AddBackward0>)
# 1250 tensor(1.1006, grad_fn=<AddBackward0>)
# 1260 tensor(1.0921, grad_fn=<AddBackward0>)
# 1270 tensor(1.0719, grad_fn=<AddBackward0>)
# 1280 tensor(1.0640, grad_fn=<AddBackward0>)
# 1290 tensor(1.1034, grad_fn=<AddBackward0>)
# 1300 tensor(1.0704, grad_fn=<AddBackward0>)
# 1310 tensor(1.0820, grad_fn=<AddBackward0>)
# 1320 tensor(1.0491, grad_fn=<AddBackward0>)
# 1330 tensor(1.1303, grad_fn=<AddBackward0>)
# 1340 tensor(1.0231, grad_fn=<AddBackward0>)
# 1350 tensor(1.1043, grad_fn=<AddBackward0>)
# 1360 tensor(1.0743, grad_fn=<AddBackward0>)
# 1370 tensor(1.0649, grad_fn=<AddBackward0>)
# 1380 tensor(1.1078, grad_fn=<AddBackward0>)
# 1390 tensor(1.0629, grad_fn=<AddBackward0>)
# 1400 tensor(1.0734, grad_fn=<AddBackward0>)
# 1410 tensor(1.0857, grad_fn=<AddBackward0>)
# 1420 tensor(1.1257, grad_fn=<AddBackward0>)
# 1430 tensor(1.0893, grad_fn=<AddBackward0>)
# 1440 tensor(1.0577, grad_fn=<AddBackward0>)
# 1450 tensor(1.0774, grad_fn=<AddBackward0>)
# 1460 tensor(1.0310, grad_fn=<AddBackward0>)
# 1470 tensor(1.0660, grad_fn=<AddBackward0>)
# 1480 tensor(1.0854, grad_fn=<AddBackward0>)
# 1490 tensor(1.0577, grad_fn=<AddBackward0>)
# 1500 tensor(1.0387, grad_fn=<AddBackward0>)
# 1510 tensor(1.1084, grad_fn=<AddBackward0>)
# 1520 tensor(1.1306, grad_fn=<AddBackward0>)
# 1530 tensor(1.0787, grad_fn=<AddBackward0>)
# 1540 tensor(1.1382, grad_fn=<AddBackward0>)
# 1550 tensor(1.0905, grad_fn=<AddBackward0>)
# 1560 tensor(1.0302, grad_fn=<AddBackward0>)
# 1570 tensor(1.1257, grad_fn=<AddBackward0>)
# 1580 tensor(1.1293, grad_fn=<AddBackward0>)
# 1590 tensor(1.0731, grad_fn=<AddBackward0>)
# 1600 tensor(1.0746, grad_fn=<AddBackward0>)
# 1610 tensor(1.0267, grad_fn=<AddBackward0>)
# 1620 tensor(1.1193, grad_fn=<AddBackward0>)
# 1630 tensor(1.0434, grad_fn=<AddBackward0>)
# 1640 tensor(0.9869, grad_fn=<AddBackward0>)
# 1650 tensor(1.0932, grad_fn=<AddBackward0>)
# 1660 tensor(1.0283, grad_fn=<AddBackward0>)
# 1670 tensor(1.0769, grad_fn=<AddBackward0>)
# 1680 tensor(1.1075, grad_fn=<AddBackward0>)
# 1690 tensor(1.0773, grad_fn=<AddBackward0>)
# 1700 tensor(1.0943, grad_fn=<AddBackward0>)
# 1710 tensor(1.0666, grad_fn=<AddBackward0>)
# 1720 tensor(1.0514, grad_fn=<AddBackward0>)
# 1730 tensor(1.0695, grad_fn=<AddBackward0>)
# 1740 tensor(1.0867, grad_fn=<AddBackward0>)
# 1750 tensor(1.1036, grad_fn=<AddBackward0>)
# 1760 tensor(1.1162, grad_fn=<AddBackward0>)
# 1770 tensor(1.0712, grad_fn=<AddBackward0>)
# 1780 tensor(1.0235, grad_fn=<AddBackward0>)
# 1790 tensor(1.1292, grad_fn=<AddBackward0>)
# 1800 tensor(1.0980, grad_fn=<AddBackward0>)
# 1810 tensor(0.9872, grad_fn=<AddBackward0>)
# 1820 tensor(1.0656, grad_fn=<AddBackward0>)
# 1830 tensor(1.0364, grad_fn=<AddBackward0>)
# 1840 tensor(1.0754, grad_fn=<AddBackward0>)
# 1850 tensor(1.0588, grad_fn=<AddBackward0>)
# 1860 tensor(1.0945, grad_fn=<AddBackward0>)
# 1870 tensor(1.0557, grad_fn=<AddBackward0>)
# 1880 tensor(1.0566, grad_fn=<AddBackward0>)
# 1890 tensor(1.0817, grad_fn=<AddBackward0>)
# 1900 tensor(1.0962, grad_fn=<AddBackward0>)
# 1910 tensor(1.0680, grad_fn=<AddBackward0>)
# 1920 tensor(1.0900, grad_fn=<AddBackward0>)
# 1930 tensor(1.0842, grad_fn=<AddBackward0>)
# 1940 tensor(1.0958, grad_fn=<AddBackward0>)
# 1950 tensor(1.0707, grad_fn=<AddBackward0>)
# 1960 tensor(1.1305, grad_fn=<AddBackward0>)
# 1970 tensor(1.1098, grad_fn=<AddBackward0>)
# 1980 tensor(1.0838, grad_fn=<AddBackward0>)
# 1990 tensor(1.0455, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 2 is bigger than -3.9356365 then go to left, else go to right
#     LEFT:
#     WHEN feature 2 is bigger than -3.539494 then go to left, else go to right
#         LEFT:
#         WHEN feature 1 is bigger than 1.3517795 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 5 is bigger than 1.2685357 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 0
#     RIGHT:
#     WHEN feature 0 is bigger than -1.7279379 then go to left, else go to right
#         LEFT:
#         WHEN feature 0 is bigger than -2.0081792 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 6 is bigger than 0.51654005 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.618421052631579
# f1_score:
#  0.3821138211382114
# confusion_matrix:
#  [[47  0]
#  [29  0]]
# =============================================================
# (691, 8) (691, 1)
# (76, 8) (76, 1)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 256, 'l2_weight': 0, 'label_weight_power': 1.5, 'focus_on_cont': True}
# Num Label: [455 236]
# Label Weight: [1.         2.67700443]
# 0 tensor(1.1068, grad_fn=<AddBackward0>)
# 10 tensor(1.1201, grad_fn=<AddBackward0>)
# 20 tensor(1.0904, grad_fn=<AddBackward0>)
# 30 tensor(1.1059, grad_fn=<AddBackward0>)
# 40 tensor(1.0728, grad_fn=<AddBackward0>)
# 50 tensor(1.0726, grad_fn=<AddBackward0>)
# 60 tensor(1.1065, grad_fn=<AddBackward0>)
# 70 tensor(1.0378, grad_fn=<AddBackward0>)
# 80 tensor(1.0775, grad_fn=<AddBackward0>)
# 90 tensor(1.0701, grad_fn=<AddBackward0>)
# 100 tensor(1.0857, grad_fn=<AddBackward0>)
# 110 tensor(1.0314, grad_fn=<AddBackward0>)
# 120 tensor(1.0485, grad_fn=<AddBackward0>)
# 130 tensor(1.0982, grad_fn=<AddBackward0>)
# 140 tensor(1.0115, grad_fn=<AddBackward0>)
# 150 tensor(0.9918, grad_fn=<AddBackward0>)
# 160 tensor(1.0278, grad_fn=<AddBackward0>)
# 170 tensor(1.1414, grad_fn=<AddBackward0>)
# 180 tensor(1.0872, grad_fn=<AddBackward0>)
# 190 tensor(1.0498, grad_fn=<AddBackward0>)
# 200 tensor(1.0734, grad_fn=<AddBackward0>)
# 210 tensor(1.1180, grad_fn=<AddBackward0>)
# 220 tensor(1.0579, grad_fn=<AddBackward0>)
# 230 tensor(1.0253, grad_fn=<AddBackward0>)
# 240 tensor(1.0938, grad_fn=<AddBackward0>)
# 250 tensor(1.0770, grad_fn=<AddBackward0>)
# 260 tensor(1.0933, grad_fn=<AddBackward0>)
# 270 tensor(1.0401, grad_fn=<AddBackward0>)
# 280 tensor(1.0603, grad_fn=<AddBackward0>)
# 290 tensor(1.1027, grad_fn=<AddBackward0>)
# 300 tensor(1.1018, grad_fn=<AddBackward0>)
# 310 tensor(1.1308, grad_fn=<AddBackward0>)
# 320 tensor(1.0673, grad_fn=<AddBackward0>)
# 330 tensor(1.1419, grad_fn=<AddBackward0>)
# 340 tensor(1.1110, grad_fn=<AddBackward0>)
# 350 tensor(1.0854, grad_fn=<AddBackward0>)
# 360 tensor(1.0794, grad_fn=<AddBackward0>)
# 370 tensor(1.0933, grad_fn=<AddBackward0>)
# 380 tensor(1.0544, grad_fn=<AddBackward0>)
# 390 tensor(1.1212, grad_fn=<AddBackward0>)
# 400 tensor(1.1404, grad_fn=<AddBackward0>)
# 410 tensor(1.0876, grad_fn=<AddBackward0>)
# 420 tensor(1.1287, grad_fn=<AddBackward0>)
# 430 tensor(1.0681, grad_fn=<AddBackward0>)
# 440 tensor(1.0764, grad_fn=<AddBackward0>)
# 450 tensor(1.0467, grad_fn=<AddBackward0>)
# 460 tensor(1.0930, grad_fn=<AddBackward0>)
# 470 tensor(1.0925, grad_fn=<AddBackward0>)
# 480 tensor(1.0701, grad_fn=<AddBackward0>)
# 490 tensor(1.0429, grad_fn=<AddBackward0>)
# 500 tensor(1.0548, grad_fn=<AddBackward0>)
# 510 tensor(1.1214, grad_fn=<AddBackward0>)
# 520 tensor(1.1162, grad_fn=<AddBackward0>)
# 530 tensor(1.1279, grad_fn=<AddBackward0>)
# 540 tensor(1.0888, grad_fn=<AddBackward0>)
# 550 tensor(1.0900, grad_fn=<AddBackward0>)
# 560 tensor(1.0757, grad_fn=<AddBackward0>)
# 570 tensor(1.0275, grad_fn=<AddBackward0>)
# 580 tensor(1.0917, grad_fn=<AddBackward0>)
# 590 tensor(1.1453, grad_fn=<AddBackward0>)
# 600 tensor(1.0674, grad_fn=<AddBackward0>)
# 610 tensor(1.0957, grad_fn=<AddBackward0>)
# 620 tensor(1.0670, grad_fn=<AddBackward0>)
# 630 tensor(1.0827, grad_fn=<AddBackward0>)
# 640 tensor(1.1329, grad_fn=<AddBackward0>)
# 650 tensor(1.1378, grad_fn=<AddBackward0>)
# 660 tensor(1.0565, grad_fn=<AddBackward0>)
# 670 tensor(1.0518, grad_fn=<AddBackward0>)
# 680 tensor(1.1030, grad_fn=<AddBackward0>)
# 690 tensor(1.0777, grad_fn=<AddBackward0>)
# 700 tensor(1.0408, grad_fn=<AddBackward0>)
# 710 tensor(1.0841, grad_fn=<AddBackward0>)
# 720 tensor(1.1237, grad_fn=<AddBackward0>)
# 730 tensor(1.0753, grad_fn=<AddBackward0>)
# 740 tensor(1.0625, grad_fn=<AddBackward0>)
# 750 tensor(1.0808, grad_fn=<AddBackward0>)
# 760 tensor(1.0821, grad_fn=<AddBackward0>)
# 770 tensor(1.1291, grad_fn=<AddBackward0>)
# 780 tensor(1.0911, grad_fn=<AddBackward0>)
# 790 tensor(1.0342, grad_fn=<AddBackward0>)
# 800 tensor(1.0697, grad_fn=<AddBackward0>)
# 810 tensor(1.0617, grad_fn=<AddBackward0>)
# 820 tensor(1.1021, grad_fn=<AddBackward0>)
# 830 tensor(1.0203, grad_fn=<AddBackward0>)
# 840 tensor(1.0614, grad_fn=<AddBackward0>)
# 850 tensor(1.0846, grad_fn=<AddBackward0>)
# 860 tensor(1.0999, grad_fn=<AddBackward0>)
# 870 tensor(1.0533, grad_fn=<AddBackward0>)
# 880 tensor(1.0708, grad_fn=<AddBackward0>)
# 890 tensor(1.0846, grad_fn=<AddBackward0>)
# 900 tensor(1.0559, grad_fn=<AddBackward0>)
# 910 tensor(1.1088, grad_fn=<AddBackward0>)
# 920 tensor(1.0865, grad_fn=<AddBackward0>)
# 930 tensor(1.0977, grad_fn=<AddBackward0>)
# 940 tensor(1.1288, grad_fn=<AddBackward0>)
# 950 tensor(1.0450, grad_fn=<AddBackward0>)
# 960 tensor(1.0109, grad_fn=<AddBackward0>)
# 970 tensor(1.0755, grad_fn=<AddBackward0>)
# 980 tensor(1.0345, grad_fn=<AddBackward0>)
# 990 tensor(1.0812, grad_fn=<AddBackward0>)
# 1000 tensor(1.0356, grad_fn=<AddBackward0>)
# 1010 tensor(1.0682, grad_fn=<AddBackward0>)
# 1020 tensor(1.0699, grad_fn=<AddBackward0>)
# 1030 tensor(1.0585, grad_fn=<AddBackward0>)
# 1040 tensor(1.1213, grad_fn=<AddBackward0>)
# 1050 tensor(1.1229, grad_fn=<AddBackward0>)
# 1060 tensor(1.0856, grad_fn=<AddBackward0>)
# 1070 tensor(1.0622, grad_fn=<AddBackward0>)
# 1080 tensor(1.0925, grad_fn=<AddBackward0>)
# 1090 tensor(1.1233, grad_fn=<AddBackward0>)
# 1100 tensor(1.0941, grad_fn=<AddBackward0>)
# 1110 tensor(1.0752, grad_fn=<AddBackward0>)
# 1120 tensor(1.0272, grad_fn=<AddBackward0>)
# 1130 tensor(1.0904, grad_fn=<AddBackward0>)
# 1140 tensor(1.1107, grad_fn=<AddBackward0>)
# 1150 tensor(1.0640, grad_fn=<AddBackward0>)
# 1160 tensor(1.1163, grad_fn=<AddBackward0>)
# 1170 tensor(1.0999, grad_fn=<AddBackward0>)
# 1180 tensor(1.0581, grad_fn=<AddBackward0>)
# 1190 tensor(1.0988, grad_fn=<AddBackward0>)
# 1200 tensor(1.0550, grad_fn=<AddBackward0>)
# 1210 tensor(1.1467, grad_fn=<AddBackward0>)
# 1220 tensor(1.0699, grad_fn=<AddBackward0>)
# 1230 tensor(1.0829, grad_fn=<AddBackward0>)
# 1240 tensor(1.0915, grad_fn=<AddBackward0>)
# 1250 tensor(1.0599, grad_fn=<AddBackward0>)
# 1260 tensor(1.0907, grad_fn=<AddBackward0>)
# 1270 tensor(1.0596, grad_fn=<AddBackward0>)
# 1280 tensor(1.0820, grad_fn=<AddBackward0>)
# 1290 tensor(1.1171, grad_fn=<AddBackward0>)
# 1300 tensor(1.0976, grad_fn=<AddBackward0>)
# 1310 tensor(1.0570, grad_fn=<AddBackward0>)
# 1320 tensor(1.1068, grad_fn=<AddBackward0>)
# 1330 tensor(1.0677, grad_fn=<AddBackward0>)
# 1340 tensor(1.0653, grad_fn=<AddBackward0>)
# 1350 tensor(1.0051, grad_fn=<AddBackward0>)
# 1360 tensor(1.0341, grad_fn=<AddBackward0>)
# 1370 tensor(1.0827, grad_fn=<AddBackward0>)
# 1380 tensor(1.0573, grad_fn=<AddBackward0>)
# 1390 tensor(1.1171, grad_fn=<AddBackward0>)
# 1400 tensor(1.0786, grad_fn=<AddBackward0>)
# 1410 tensor(1.0681, grad_fn=<AddBackward0>)
# 1420 tensor(1.0575, grad_fn=<AddBackward0>)
# 1430 tensor(1.0775, grad_fn=<AddBackward0>)
# 1440 tensor(1.1004, grad_fn=<AddBackward0>)
# 1450 tensor(1.0278, grad_fn=<AddBackward0>)
# 1460 tensor(1.0861, grad_fn=<AddBackward0>)
# 1470 tensor(1.0996, grad_fn=<AddBackward0>)
# 1480 tensor(1.0893, grad_fn=<AddBackward0>)
# 1490 tensor(1.0876, grad_fn=<AddBackward0>)
# 1500 tensor(1.1337, grad_fn=<AddBackward0>)
# 1510 tensor(1.0652, grad_fn=<AddBackward0>)
# 1520 tensor(1.0370, grad_fn=<AddBackward0>)
# 1530 tensor(1.1019, grad_fn=<AddBackward0>)
# 1540 tensor(1.0751, grad_fn=<AddBackward0>)
# 1550 tensor(1.1178, grad_fn=<AddBackward0>)
# 1560 tensor(1.0493, grad_fn=<AddBackward0>)
# 1570 tensor(1.0786, grad_fn=<AddBackward0>)
# 1580 tensor(1.1076, grad_fn=<AddBackward0>)
# 1590 tensor(1.0773, grad_fn=<AddBackward0>)
# 1600 tensor(1.1072, grad_fn=<AddBackward0>)
# 1610 tensor(1.0632, grad_fn=<AddBackward0>)
# 1620 tensor(1.0711, grad_fn=<AddBackward0>)
# 1630 tensor(1.0864, grad_fn=<AddBackward0>)
# 1640 tensor(1.0735, grad_fn=<AddBackward0>)
# 1650 tensor(1.1191, grad_fn=<AddBackward0>)
# 1660 tensor(1.0673, grad_fn=<AddBackward0>)
# 1670 tensor(1.1152, grad_fn=<AddBackward0>)
# 1680 tensor(1.1229, grad_fn=<AddBackward0>)
# 1690 tensor(1.0831, grad_fn=<AddBackward0>)
# 1700 tensor(1.1464, grad_fn=<AddBackward0>)
# 1710 tensor(1.1180, grad_fn=<AddBackward0>)
# 1720 tensor(1.0755, grad_fn=<AddBackward0>)
# 1730 tensor(1.0525, grad_fn=<AddBackward0>)
# 1740 tensor(1.1222, grad_fn=<AddBackward0>)
# 1750 tensor(1.0480, grad_fn=<AddBackward0>)
# 1760 tensor(1.0649, grad_fn=<AddBackward0>)
# 1770 tensor(1.0716, grad_fn=<AddBackward0>)
# 1780 tensor(1.0917, grad_fn=<AddBackward0>)
# 1790 tensor(1.0552, grad_fn=<AddBackward0>)
# 1800 tensor(1.0807, grad_fn=<AddBackward0>)
# 1810 tensor(1.0516, grad_fn=<AddBackward0>)
# 1820 tensor(1.0684, grad_fn=<AddBackward0>)
# 1830 tensor(1.1147, grad_fn=<AddBackward0>)
# 1840 tensor(1.1428, grad_fn=<AddBackward0>)
# 1850 tensor(1.1146, grad_fn=<AddBackward0>)
# 1860 tensor(1.1612, grad_fn=<AddBackward0>)
# 1870 tensor(1.1435, grad_fn=<AddBackward0>)
# 1880 tensor(1.0858, grad_fn=<AddBackward0>)
# 1890 tensor(1.1007, grad_fn=<AddBackward0>)
# 1900 tensor(1.0835, grad_fn=<AddBackward0>)
# 1910 tensor(1.0516, grad_fn=<AddBackward0>)
# 1920 tensor(1.0738, grad_fn=<AddBackward0>)
# 1930 tensor(1.0782, grad_fn=<AddBackward0>)
# 1940 tensor(1.0932, grad_fn=<AddBackward0>)
# 1950 tensor(1.1197, grad_fn=<AddBackward0>)
# 1960 tensor(1.0803, grad_fn=<AddBackward0>)
# 1970 tensor(1.1074, grad_fn=<AddBackward0>)
# 1980 tensor(1.1089, grad_fn=<AddBackward0>)
# 1990 tensor(1.1179, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 1 is bigger than -0.33015087 then go to left, else go to right
#     LEFT:
#     WHEN feature 1 is bigger than 0.7990546 then go to left, else go to right
#         LEFT:
#         WHEN feature 3 is bigger than 0.39050743 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 4 is bigger than -0.49125656 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 0
#     RIGHT:
#     WHEN feature 0 is bigger than 0.28969663 then go to left, else go to right
#         LEFT:
#         WHEN feature 1 is bigger than 0.8807359 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 0 is bigger than -0.79090023 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.5557479224376731
# f1_score:
#  0.5012305168170632
# confusion_matrix:
#  [[37  8]
#  [24  7]]
# =============================================================
# (691, 8) (691, 1)
# (76, 8) (76, 1)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 256, 'l2_weight': 0, 'label_weight_power': 1.5, 'focus_on_cont': True}
# Num Label: [457 234]
# Label Weight: [1.         2.72929522]
# 0 tensor(1.0543, grad_fn=<AddBackward0>)
# 10 tensor(1.1345, grad_fn=<AddBackward0>)
# 20 tensor(1.0993, grad_fn=<AddBackward0>)
# 30 tensor(1.1022, grad_fn=<AddBackward0>)
# 40 tensor(1.1091, grad_fn=<AddBackward0>)
# 50 tensor(1.0906, grad_fn=<AddBackward0>)
# 60 tensor(1.1166, grad_fn=<AddBackward0>)
# 70 tensor(1.1139, grad_fn=<AddBackward0>)
# 80 tensor(1.1182, grad_fn=<AddBackward0>)
# 90 tensor(1.0704, grad_fn=<AddBackward0>)
# 100 tensor(1.1150, grad_fn=<AddBackward0>)
# 110 tensor(1.0927, grad_fn=<AddBackward0>)
# 120 tensor(1.1089, grad_fn=<AddBackward0>)
# 130 tensor(1.0586, grad_fn=<AddBackward0>)
# 140 tensor(1.0928, grad_fn=<AddBackward0>)
# 150 tensor(1.0605, grad_fn=<AddBackward0>)
# 160 tensor(1.0770, grad_fn=<AddBackward0>)
# 170 tensor(1.0824, grad_fn=<AddBackward0>)
# 180 tensor(1.0704, grad_fn=<AddBackward0>)
# 190 tensor(1.1080, grad_fn=<AddBackward0>)
# 200 tensor(1.1093, grad_fn=<AddBackward0>)
# 210 tensor(1.1062, grad_fn=<AddBackward0>)
# 220 tensor(1.0855, grad_fn=<AddBackward0>)
# 230 tensor(1.1205, grad_fn=<AddBackward0>)
# 240 tensor(1.0455, grad_fn=<AddBackward0>)
# 250 tensor(1.0328, grad_fn=<AddBackward0>)
# 260 tensor(1.1067, grad_fn=<AddBackward0>)
# 270 tensor(1.1369, grad_fn=<AddBackward0>)
# 280 tensor(1.1303, grad_fn=<AddBackward0>)
# 290 tensor(1.0825, grad_fn=<AddBackward0>)
# 300 tensor(1.0717, grad_fn=<AddBackward0>)
# 310 tensor(1.1186, grad_fn=<AddBackward0>)
# 320 tensor(1.0550, grad_fn=<AddBackward0>)
# 330 tensor(1.0590, grad_fn=<AddBackward0>)
# 340 tensor(1.1131, grad_fn=<AddBackward0>)
# 350 tensor(1.2016, grad_fn=<AddBackward0>)
# 360 tensor(1.0806, grad_fn=<AddBackward0>)
# 370 tensor(1.1117, grad_fn=<AddBackward0>)
# 380 tensor(1.0528, grad_fn=<AddBackward0>)
# 390 tensor(1.0781, grad_fn=<AddBackward0>)
# 400 tensor(1.0696, grad_fn=<AddBackward0>)
# 410 tensor(1.0544, grad_fn=<AddBackward0>)
# 420 tensor(1.0403, grad_fn=<AddBackward0>)
# 430 tensor(1.0705, grad_fn=<AddBackward0>)
# 440 tensor(1.1013, grad_fn=<AddBackward0>)
# 450 tensor(1.0492, grad_fn=<AddBackward0>)
# 460 tensor(1.1387, grad_fn=<AddBackward0>)
# 470 tensor(1.0841, grad_fn=<AddBackward0>)
# 480 tensor(1.1170, grad_fn=<AddBackward0>)
# 490 tensor(1.1237, grad_fn=<AddBackward0>)
# 500 tensor(1.0997, grad_fn=<AddBackward0>)
# 510 tensor(1.1285, grad_fn=<AddBackward0>)
# 520 tensor(1.0871, grad_fn=<AddBackward0>)
# 530 tensor(1.1271, grad_fn=<AddBackward0>)
# 540 tensor(1.0935, grad_fn=<AddBackward0>)
# 550 tensor(1.1108, grad_fn=<AddBackward0>)
# 560 tensor(1.0602, grad_fn=<AddBackward0>)
# 570 tensor(1.1372, grad_fn=<AddBackward0>)
# 580 tensor(1.0772, grad_fn=<AddBackward0>)
# 590 tensor(1.0841, grad_fn=<AddBackward0>)
# 600 tensor(1.0330, grad_fn=<AddBackward0>)
# 610 tensor(1.1324, grad_fn=<AddBackward0>)
# 620 tensor(1.0954, grad_fn=<AddBackward0>)
# 630 tensor(1.1103, grad_fn=<AddBackward0>)
# 640 tensor(1.1097, grad_fn=<AddBackward0>)
# 650 tensor(1.0621, grad_fn=<AddBackward0>)
# 660 tensor(1.1009, grad_fn=<AddBackward0>)
# 670 tensor(1.0689, grad_fn=<AddBackward0>)
# 680 tensor(1.0515, grad_fn=<AddBackward0>)
# 690 tensor(1.0822, grad_fn=<AddBackward0>)
# 700 tensor(1.1070, grad_fn=<AddBackward0>)
# 710 tensor(1.0994, grad_fn=<AddBackward0>)
# 720 tensor(1.1217, grad_fn=<AddBackward0>)
# 730 tensor(1.1165, grad_fn=<AddBackward0>)
# 740 tensor(1.1390, grad_fn=<AddBackward0>)
# 750 tensor(1.0650, grad_fn=<AddBackward0>)
# 760 tensor(1.0797, grad_fn=<AddBackward0>)
# 770 tensor(1.1084, grad_fn=<AddBackward0>)
# 780 tensor(1.1374, grad_fn=<AddBackward0>)
# 790 tensor(1.1269, grad_fn=<AddBackward0>)
# 800 tensor(1.1239, grad_fn=<AddBackward0>)
# 810 tensor(1.1064, grad_fn=<AddBackward0>)
# 820 tensor(1.0658, grad_fn=<AddBackward0>)
# 830 tensor(1.0767, grad_fn=<AddBackward0>)
# 840 tensor(1.0376, grad_fn=<AddBackward0>)
# 850 tensor(1.0769, grad_fn=<AddBackward0>)
# 860 tensor(1.0576, grad_fn=<AddBackward0>)
# 870 tensor(1.1217, grad_fn=<AddBackward0>)
# 880 tensor(1.1137, grad_fn=<AddBackward0>)
# 890 tensor(1.0741, grad_fn=<AddBackward0>)
# 900 tensor(1.1132, grad_fn=<AddBackward0>)
# 910 tensor(1.1045, grad_fn=<AddBackward0>)
# 920 tensor(1.0781, grad_fn=<AddBackward0>)
# 930 tensor(1.0415, grad_fn=<AddBackward0>)
# 940 tensor(1.0938, grad_fn=<AddBackward0>)
# 950 tensor(1.0988, grad_fn=<AddBackward0>)
# 960 tensor(1.1087, grad_fn=<AddBackward0>)
# 970 tensor(1.1081, grad_fn=<AddBackward0>)
# 980 tensor(1.0450, grad_fn=<AddBackward0>)
# 990 tensor(1.1516, grad_fn=<AddBackward0>)
# 1000 tensor(1.1220, grad_fn=<AddBackward0>)
# 1010 tensor(1.0850, grad_fn=<AddBackward0>)
# 1020 tensor(1.0759, grad_fn=<AddBackward0>)
# 1030 tensor(1.1290, grad_fn=<AddBackward0>)
# 1040 tensor(1.0422, grad_fn=<AddBackward0>)
# 1050 tensor(1.0503, grad_fn=<AddBackward0>)
# 1060 tensor(1.0843, grad_fn=<AddBackward0>)
# 1070 tensor(1.0732, grad_fn=<AddBackward0>)
# 1080 tensor(1.0748, grad_fn=<AddBackward0>)
# 1090 tensor(1.0471, grad_fn=<AddBackward0>)
# 1100 tensor(1.0548, grad_fn=<AddBackward0>)
# 1110 tensor(1.1551, grad_fn=<AddBackward0>)
# 1120 tensor(1.1190, grad_fn=<AddBackward0>)
# 1130 tensor(1.0650, grad_fn=<AddBackward0>)
# 1140 tensor(1.1189, grad_fn=<AddBackward0>)
# 1150 tensor(1.0520, grad_fn=<AddBackward0>)
# 1160 tensor(1.0947, grad_fn=<AddBackward0>)
# 1170 tensor(1.1619, grad_fn=<AddBackward0>)
# 1180 tensor(1.0764, grad_fn=<AddBackward0>)
# 1190 tensor(1.1289, grad_fn=<AddBackward0>)
# 1200 tensor(1.1426, grad_fn=<AddBackward0>)
# 1210 tensor(1.1338, grad_fn=<AddBackward0>)
# 1220 tensor(1.0927, grad_fn=<AddBackward0>)
# 1230 tensor(1.0437, grad_fn=<AddBackward0>)
# 1240 tensor(1.1082, grad_fn=<AddBackward0>)
# 1250 tensor(1.1119, grad_fn=<AddBackward0>)
# 1260 tensor(1.0983, grad_fn=<AddBackward0>)
# 1270 tensor(1.1602, grad_fn=<AddBackward0>)
# 1280 tensor(1.1160, grad_fn=<AddBackward0>)
# 1290 tensor(1.1416, grad_fn=<AddBackward0>)
# 1300 tensor(1.1246, grad_fn=<AddBackward0>)
# 1310 tensor(1.0973, grad_fn=<AddBackward0>)
# 1320 tensor(1.0793, grad_fn=<AddBackward0>)
# 1330 tensor(1.0661, grad_fn=<AddBackward0>)
# 1340 tensor(1.0189, grad_fn=<AddBackward0>)
# 1350 tensor(1.0977, grad_fn=<AddBackward0>)
# 1360 tensor(1.1757, grad_fn=<AddBackward0>)
# 1370 tensor(1.1396, grad_fn=<AddBackward0>)
# 1380 tensor(1.0012, grad_fn=<AddBackward0>)
# 1390 tensor(1.1006, grad_fn=<AddBackward0>)
# 1400 tensor(1.0936, grad_fn=<AddBackward0>)
# 1410 tensor(1.0631, grad_fn=<AddBackward0>)
# 1420 tensor(1.1423, grad_fn=<AddBackward0>)
# 1430 tensor(1.0694, grad_fn=<AddBackward0>)
# 1440 tensor(1.0908, grad_fn=<AddBackward0>)
# 1450 tensor(1.0943, grad_fn=<AddBackward0>)
# 1460 tensor(1.0711, grad_fn=<AddBackward0>)
# 1470 tensor(1.0591, grad_fn=<AddBackward0>)
# 1480 tensor(1.1202, grad_fn=<AddBackward0>)
# 1490 tensor(1.1336, grad_fn=<AddBackward0>)
# 1500 tensor(1.0919, grad_fn=<AddBackward0>)
# 1510 tensor(1.0988, grad_fn=<AddBackward0>)
# 1520 tensor(1.0572, grad_fn=<AddBackward0>)
# 1530 tensor(1.0770, grad_fn=<AddBackward0>)
# 1540 tensor(1.1064, grad_fn=<AddBackward0>)
# 1550 tensor(1.0771, grad_fn=<AddBackward0>)
# 1560 tensor(1.0402, grad_fn=<AddBackward0>)
# 1570 tensor(1.1011, grad_fn=<AddBackward0>)
# 1580 tensor(1.1173, grad_fn=<AddBackward0>)
# 1590 tensor(1.1933, grad_fn=<AddBackward0>)
# 1600 tensor(1.1094, grad_fn=<AddBackward0>)
# 1610 tensor(1.1319, grad_fn=<AddBackward0>)
# 1620 tensor(1.1061, grad_fn=<AddBackward0>)
# 1630 tensor(1.0699, grad_fn=<AddBackward0>)
# 1640 tensor(1.0652, grad_fn=<AddBackward0>)
# 1650 tensor(1.0968, grad_fn=<AddBackward0>)
# 1660 tensor(1.0958, grad_fn=<AddBackward0>)
# 1670 tensor(1.1092, grad_fn=<AddBackward0>)
# 1680 tensor(1.0394, grad_fn=<AddBackward0>)
# 1690 tensor(1.2011, grad_fn=<AddBackward0>)
# 1700 tensor(1.0400, grad_fn=<AddBackward0>)
# 1710 tensor(1.0673, grad_fn=<AddBackward0>)
# 1720 tensor(1.0937, grad_fn=<AddBackward0>)
# 1730 tensor(1.1405, grad_fn=<AddBackward0>)
# 1740 tensor(1.1617, grad_fn=<AddBackward0>)
# 1750 tensor(1.1228, grad_fn=<AddBackward0>)
# 1760 tensor(1.1363, grad_fn=<AddBackward0>)
# 1770 tensor(1.0706, grad_fn=<AddBackward0>)
# 1780 tensor(1.1451, grad_fn=<AddBackward0>)
# 1790 tensor(1.0773, grad_fn=<AddBackward0>)
# 1800 tensor(1.1138, grad_fn=<AddBackward0>)
# 1810 tensor(1.1057, grad_fn=<AddBackward0>)
# 1820 tensor(1.0744, grad_fn=<AddBackward0>)
# 1830 tensor(1.0544, grad_fn=<AddBackward0>)
# 1840 tensor(1.0944, grad_fn=<AddBackward0>)
# 1850 tensor(1.1090, grad_fn=<AddBackward0>)
# 1860 tensor(1.1213, grad_fn=<AddBackward0>)
# 1870 tensor(1.1470, grad_fn=<AddBackward0>)
# 1880 tensor(1.1871, grad_fn=<AddBackward0>)
# 1890 tensor(1.0671, grad_fn=<AddBackward0>)
# 1900 tensor(1.1007, grad_fn=<AddBackward0>)
# 1910 tensor(1.0728, grad_fn=<AddBackward0>)
# 1920 tensor(1.0473, grad_fn=<AddBackward0>)
# 1930 tensor(1.0923, grad_fn=<AddBackward0>)
# 1940 tensor(1.0699, grad_fn=<AddBackward0>)
# 1950 tensor(1.0972, grad_fn=<AddBackward0>)
# 1960 tensor(1.0931, grad_fn=<AddBackward0>)
# 1970 tensor(1.0774, grad_fn=<AddBackward0>)
# 1980 tensor(1.0979, grad_fn=<AddBackward0>)
# 1990 tensor(1.1239, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 5 is bigger than -0.4768283 then go to left, else go to right
#     LEFT:
#     WHEN feature 3 is bigger than -1.0088297 then go to left, else go to right
#         LEFT:
#         WHEN feature 7 is bigger than 0.41246703 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
#         RIGHT:
#         WHEN feature 7 is bigger than -1.5318244 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#     RIGHT:
#     WHEN feature 1 is bigger than 0.25722903 then go to left, else go to right
#         LEFT:
#         WHEN feature 4 is bigger than -0.3923401 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 2 is bigger than -1.3098613 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.5259695290858726
# f1_score:
#  0.4910714285714286
# confusion_matrix:
#  [[30 13]
#  [23 10]]
# =============================================================
# (691, 8) (691, 1)
# (76, 8) (76, 1)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 256, 'l2_weight': 0, 'label_weight_power': 1.5, 'focus_on_cont': True}
# Num Label: [452 239]
# Label Weight: [1.         2.60082302]
# 0 tensor(1.0316, grad_fn=<AddBackward0>)
# 10 tensor(1.0827, grad_fn=<AddBackward0>)
# 20 tensor(1.0627, grad_fn=<AddBackward0>)
# 30 tensor(1.0719, grad_fn=<AddBackward0>)
# 40 tensor(1.0836, grad_fn=<AddBackward0>)
# 50 tensor(1.1010, grad_fn=<AddBackward0>)
# 60 tensor(1.0449, grad_fn=<AddBackward0>)
# 70 tensor(1.0664, grad_fn=<AddBackward0>)
# 80 tensor(1.1121, grad_fn=<AddBackward0>)
# 90 tensor(1.0472, grad_fn=<AddBackward0>)
# 100 tensor(1.0498, grad_fn=<AddBackward0>)
# 110 tensor(1.0925, grad_fn=<AddBackward0>)
# 120 tensor(1.1040, grad_fn=<AddBackward0>)
# 130 tensor(1.1324, grad_fn=<AddBackward0>)
# 140 tensor(1.0656, grad_fn=<AddBackward0>)
# 150 tensor(1.0356, grad_fn=<AddBackward0>)
# 160 tensor(1.0380, grad_fn=<AddBackward0>)
# 170 tensor(1.0983, grad_fn=<AddBackward0>)
# 180 tensor(1.0307, grad_fn=<AddBackward0>)
# 190 tensor(1.0458, grad_fn=<AddBackward0>)
# 200 tensor(1.1027, grad_fn=<AddBackward0>)
# 210 tensor(1.0869, grad_fn=<AddBackward0>)
# 220 tensor(1.0775, grad_fn=<AddBackward0>)
# 230 tensor(1.0979, grad_fn=<AddBackward0>)
# 240 tensor(1.0723, grad_fn=<AddBackward0>)
# 250 tensor(1.0568, grad_fn=<AddBackward0>)
# 260 tensor(1.0011, grad_fn=<AddBackward0>)
# 270 tensor(1.0565, grad_fn=<AddBackward0>)
# 280 tensor(1.1123, grad_fn=<AddBackward0>)
# 290 tensor(1.0681, grad_fn=<AddBackward0>)
# 300 tensor(1.0296, grad_fn=<AddBackward0>)
# 310 tensor(1.0978, grad_fn=<AddBackward0>)
# 320 tensor(1.0750, grad_fn=<AddBackward0>)
# 330 tensor(1.0386, grad_fn=<AddBackward0>)
# 340 tensor(1.0276, grad_fn=<AddBackward0>)
# 350 tensor(1.0523, grad_fn=<AddBackward0>)
# 360 tensor(1.0989, grad_fn=<AddBackward0>)
# 370 tensor(1.0616, grad_fn=<AddBackward0>)
# 380 tensor(1.0565, grad_fn=<AddBackward0>)
# 390 tensor(1.0949, grad_fn=<AddBackward0>)
# 400 tensor(1.0866, grad_fn=<AddBackward0>)
# 410 tensor(1.0801, grad_fn=<AddBackward0>)
# 420 tensor(1.1046, grad_fn=<AddBackward0>)
# 430 tensor(1.0997, grad_fn=<AddBackward0>)
# 440 tensor(1.1310, grad_fn=<AddBackward0>)
# 450 tensor(1.0905, grad_fn=<AddBackward0>)
# 460 tensor(1.1210, grad_fn=<AddBackward0>)
# 470 tensor(1.0182, grad_fn=<AddBackward0>)
# 480 tensor(1.1227, grad_fn=<AddBackward0>)
# 490 tensor(1.0448, grad_fn=<AddBackward0>)
# 500 tensor(1.1153, grad_fn=<AddBackward0>)
# 510 tensor(1.0309, grad_fn=<AddBackward0>)
# 520 tensor(1.0650, grad_fn=<AddBackward0>)
# 530 tensor(1.1279, grad_fn=<AddBackward0>)
# 540 tensor(1.1297, grad_fn=<AddBackward0>)
# 550 tensor(1.0810, grad_fn=<AddBackward0>)
# 560 tensor(1.0109, grad_fn=<AddBackward0>)
# 570 tensor(1.0820, grad_fn=<AddBackward0>)
# 580 tensor(1.1045, grad_fn=<AddBackward0>)
# 590 tensor(1.0850, grad_fn=<AddBackward0>)
# 600 tensor(1.1133, grad_fn=<AddBackward0>)
# 610 tensor(1.1209, grad_fn=<AddBackward0>)
# 620 tensor(1.0246, grad_fn=<AddBackward0>)
# 630 tensor(1.0675, grad_fn=<AddBackward0>)
# 640 tensor(1.0765, grad_fn=<AddBackward0>)
# 650 tensor(1.0964, grad_fn=<AddBackward0>)
# 660 tensor(1.0694, grad_fn=<AddBackward0>)
# 670 tensor(1.0502, grad_fn=<AddBackward0>)
# 680 tensor(1.0826, grad_fn=<AddBackward0>)
# 690 tensor(1.0528, grad_fn=<AddBackward0>)
# 700 tensor(1.0335, grad_fn=<AddBackward0>)
# 710 tensor(1.0352, grad_fn=<AddBackward0>)
# 720 tensor(1.1007, grad_fn=<AddBackward0>)
# 730 tensor(1.0939, grad_fn=<AddBackward0>)
# 740 tensor(1.0467, grad_fn=<AddBackward0>)
# 750 tensor(1.0687, grad_fn=<AddBackward0>)
# 760 tensor(1.1209, grad_fn=<AddBackward0>)
# 770 tensor(1.0671, grad_fn=<AddBackward0>)
# 780 tensor(1.0734, grad_fn=<AddBackward0>)
# 790 tensor(1.0956, grad_fn=<AddBackward0>)
# 800 tensor(1.0924, grad_fn=<AddBackward0>)
# 810 tensor(1.0119, grad_fn=<AddBackward0>)
# 820 tensor(1.0448, grad_fn=<AddBackward0>)
# 830 tensor(1.0366, grad_fn=<AddBackward0>)
# 840 tensor(1.0306, grad_fn=<AddBackward0>)
# 850 tensor(1.1020, grad_fn=<AddBackward0>)
# 860 tensor(1.0360, grad_fn=<AddBackward0>)
# 870 tensor(1.0809, grad_fn=<AddBackward0>)
# 880 tensor(1.1341, grad_fn=<AddBackward0>)
# 890 tensor(1.0440, grad_fn=<AddBackward0>)
# 900 tensor(1.0206, grad_fn=<AddBackward0>)
# 910 tensor(1.0775, grad_fn=<AddBackward0>)
# 920 tensor(1.1067, grad_fn=<AddBackward0>)
# 930 tensor(1.0755, grad_fn=<AddBackward0>)
# 940 tensor(1.0530, grad_fn=<AddBackward0>)
# 950 tensor(1.0342, grad_fn=<AddBackward0>)
# 960 tensor(1.0757, grad_fn=<AddBackward0>)
# 970 tensor(1.0795, grad_fn=<AddBackward0>)
# 980 tensor(1.0926, grad_fn=<AddBackward0>)
# 990 tensor(1.0437, grad_fn=<AddBackward0>)
# 1000 tensor(1.0402, grad_fn=<AddBackward0>)
# 1010 tensor(1.1603, grad_fn=<AddBackward0>)
# 1020 tensor(1.1288, grad_fn=<AddBackward0>)
# 1030 tensor(1.0896, grad_fn=<AddBackward0>)
# 1040 tensor(1.0709, grad_fn=<AddBackward0>)
# 1050 tensor(1.1156, grad_fn=<AddBackward0>)
# 1060 tensor(1.0809, grad_fn=<AddBackward0>)
# 1070 tensor(1.0588, grad_fn=<AddBackward0>)
# 1080 tensor(1.0846, grad_fn=<AddBackward0>)
# 1090 tensor(1.0683, grad_fn=<AddBackward0>)
# 1100 tensor(1.0724, grad_fn=<AddBackward0>)
# 1110 tensor(1.0898, grad_fn=<AddBackward0>)
# 1120 tensor(1.0927, grad_fn=<AddBackward0>)
# 1130 tensor(1.1485, grad_fn=<AddBackward0>)
# 1140 tensor(1.0729, grad_fn=<AddBackward0>)
# 1150 tensor(1.0435, grad_fn=<AddBackward0>)
# 1160 tensor(1.0873, grad_fn=<AddBackward0>)
# 1170 tensor(1.0207, grad_fn=<AddBackward0>)
# 1180 tensor(1.0490, grad_fn=<AddBackward0>)
# 1190 tensor(1.0623, grad_fn=<AddBackward0>)
# 1200 tensor(1.0518, grad_fn=<AddBackward0>)
# 1210 tensor(1.0465, grad_fn=<AddBackward0>)
# 1220 tensor(1.0952, grad_fn=<AddBackward0>)
# 1230 tensor(1.0755, grad_fn=<AddBackward0>)
# 1240 tensor(1.0491, grad_fn=<AddBackward0>)
# 1250 tensor(1.0268, grad_fn=<AddBackward0>)
# ...
# 980 tensor(1.0723, grad_fn=<AddBackward0>)
# 990 tensor(1.0442, grad_fn=<AddBackward0>)
# 1000 tensor(1.0693, grad_fn=<AddBackward0>)
# 1010 tensor(1.0622, grad_fn=<AddBackward0>)
# 1020 tensor(1.1030, grad_fn=<AddBackward0>)
# 1030 tensor(1.0130, grad_fn=<AddBackward0>)
# 1040 tensor(1.0244, grad_fn=<AddBackward0>)
# 1050 tensor(1.0472, grad_fn=<AddBackward0>)
# 1060 tensor(1.0459, grad_fn=<AddBackward0>)
# 1070 tensor(1.0314, grad_fn=<AddBackward0>)
# 1080 tensor(1.0781, grad_fn=<AddBackward0>)
# 1090 tensor(0.9984, grad_fn=<AddBackward0>)
# 1100 tensor(1.0612, grad_fn=<AddBackward0>)
# 1110 tensor(1.0972, grad_fn=<AddBackward0>)
# 1120 tensor(1.0292, grad_fn=<AddBackward0>)
# 1130 tensor(1.0969, grad_fn=<AddBackward0>)
# 1140 tensor(1.0212, grad_fn=<AddBackward0>)
# 1150 tensor(1.0472, grad_fn=<AddBackward0>)
# 1160 tensor(1.0781, grad_fn=<AddBackward0>)
# 1170 tensor(1.0497, grad_fn=<AddBackward0>)
# 1180 tensor(1.0329, grad_fn=<AddBackward0>)
# 1190 tensor(1.0570, grad_fn=<AddBackward0>)
# 1200 tensor(1.0162, grad_fn=<AddBackward0>)
# 1210 tensor(1.0595, grad_fn=<AddBackward0>)
# 1220 tensor(1.0393, grad_fn=<AddBackward0>)
# 1230 tensor(1.0838, grad_fn=<AddBackward0>)
# 1240 tensor(1.0504, grad_fn=<AddBackward0>)
# 1250 tensor(0.9588, grad_fn=<AddBackward0>)
# 1260 tensor(1.0000, grad_fn=<AddBackward0>)
# 1270 tensor(1.0014, grad_fn=<AddBackward0>)
# 1280 tensor(1.0861, grad_fn=<AddBackward0>)
# 1290 tensor(1.0196, grad_fn=<AddBackward0>)
# 1300 tensor(1.0024, grad_fn=<AddBackward0>)
# 1310 tensor(1.0379, grad_fn=<AddBackward0>)
# 1320 tensor(1.0795, grad_fn=<AddBackward0>)
# 1330 tensor(0.9753, grad_fn=<AddBackward0>)
# 1340 tensor(1.0409, grad_fn=<AddBackward0>)
# 1350 tensor(1.0514, grad_fn=<AddBackward0>)
# 1360 tensor(1.0636, grad_fn=<AddBackward0>)
# 1370 tensor(1.0508, grad_fn=<AddBackward0>)
# 1380 tensor(1.0724, grad_fn=<AddBackward0>)
# 1390 tensor(1.0713, grad_fn=<AddBackward0>)
# 1400 tensor(1.0857, grad_fn=<AddBackward0>)
# 1410 tensor(1.1165, grad_fn=<AddBackward0>)
# 1420 tensor(1.0100, grad_fn=<AddBackward0>)
# 1430 tensor(1.1286, grad_fn=<AddBackward0>)
# 1440 tensor(1.0672, grad_fn=<AddBackward0>)
# 1450 tensor(1.0401, grad_fn=<AddBackward0>)
# 1460 tensor(1.0822, grad_fn=<AddBackward0>)
# 1470 tensor(1.0659, grad_fn=<AddBackward0>)
# 1480 tensor(1.0180, grad_fn=<AddBackward0>)
# 1490 tensor(1.0918, grad_fn=<AddBackward0>)
# 1500 tensor(1.0436, grad_fn=<AddBackward0>)
# 1510 tensor(1.0865, grad_fn=<AddBackward0>)
# 1520 tensor(1.0256, grad_fn=<AddBackward0>)
# 1530 tensor(1.0521, grad_fn=<AddBackward0>)
# 1540 tensor(1.0388, grad_fn=<AddBackward0>)
# 1550 tensor(1.0801, grad_fn=<AddBackward0>)
# 1560 tensor(1.0417, grad_fn=<AddBackward0>)
# 1570 tensor(1.0749, grad_fn=<AddBackward0>)
# 1580 tensor(1.0509, grad_fn=<AddBackward0>)
# 1590 tensor(1.0594, grad_fn=<AddBackward0>)
# 1600 tensor(1.0570, grad_fn=<AddBackward0>)
# 1610 tensor(1.0814, grad_fn=<AddBackward0>)
# 1620 tensor(1.0364, grad_fn=<AddBackward0>)
# 1630 tensor(1.0143, grad_fn=<AddBackward0>)
# 1640 tensor(1.0611, grad_fn=<AddBackward0>)
# 1650 tensor(1.0039, grad_fn=<AddBackward0>)
# 1660 tensor(1.0191, grad_fn=<AddBackward0>)
# 1670 tensor(1.0358, grad_fn=<AddBackward0>)
# 1680 tensor(1.0641, grad_fn=<AddBackward0>)
# 1690 tensor(1.0320, grad_fn=<AddBackward0>)
# 1700 tensor(1.0317, grad_fn=<AddBackward0>)
# 1710 tensor(1.0034, grad_fn=<AddBackward0>)
# 1720 tensor(1.0340, grad_fn=<AddBackward0>)
# 1730 tensor(1.0551, grad_fn=<AddBackward0>)
# 1740 tensor(1.0373, grad_fn=<AddBackward0>)
# 1750 tensor(1.0506, grad_fn=<AddBackward0>)
# 1760 tensor(1.0662, grad_fn=<AddBackward0>)
# 1770 tensor(1.0689, grad_fn=<AddBackward0>)
# 1780 tensor(1.0275, grad_fn=<AddBackward0>)
# 1790 tensor(1.0145, grad_fn=<AddBackward0>)
# 1800 tensor(1.0247, grad_fn=<AddBackward0>)
# 1810 tensor(1.0134, grad_fn=<AddBackward0>)
# 1820 tensor(0.9973, grad_fn=<AddBackward0>)
# 1830 tensor(1.0174, grad_fn=<AddBackward0>)
# 1840 tensor(1.0724, grad_fn=<AddBackward0>)
# 1850 tensor(1.0432, grad_fn=<AddBackward0>)
# 1860 tensor(1.0409, grad_fn=<AddBackward0>)
# 1870 tensor(1.0466, grad_fn=<AddBackward0>)
# 1880 tensor(1.0856, grad_fn=<AddBackward0>)
# 1890 tensor(1.0086, grad_fn=<AddBackward0>)
# 1900 tensor(1.0609, grad_fn=<AddBackward0>)
# 1910 tensor(1.0664, grad_fn=<AddBackward0>)
# 1920 tensor(1.0042, grad_fn=<AddBackward0>)
# 1930 tensor(1.0116, grad_fn=<AddBackward0>)
# 1940 tensor(1.0626, grad_fn=<AddBackward0>)
# 1950 tensor(1.0525, grad_fn=<AddBackward0>)
# 1960 tensor(1.0291, grad_fn=<AddBackward0>)
# 1970 tensor(1.0135, grad_fn=<AddBackward0>)
# 1980 tensor(1.0664, grad_fn=<AddBackward0>)
# 1990 tensor(1.0395, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 7 is bigger than 0.24244021 then go to left, else go to right
#     LEFT:
#     WHEN feature 2 is bigger than -1.4787744 then go to left, else go to right
#         LEFT:
#         WHEN feature 1 is bigger than 0.6722692 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 0 is bigger than -0.63409466 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
#     RIGHT:
#     WHEN feature 5 is bigger than -0.060513165 then go to left, else go to right
#         LEFT:
#         WHEN feature 5 is bigger than 0.60554063 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 1 is bigger than 0.27815425 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.6973684210526315
# f1_score:
#  0.4108527131782946
# confusion_matrix:
#  [[53  0]
#  [23  0]]
# =============================================================
# (691, 8) (691, 1)
# (76, 8) (76, 1)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 256, 'l2_weight': 0, 'label_weight_power': 1.5, 'focus_on_cont': True}
# Num Label: [448 243]
# Label Weight: [1.         2.50326952]
# 0 tensor(1.0429, grad_fn=<AddBackward0>)
# 10 tensor(1.0712, grad_fn=<AddBackward0>)
# 20 tensor(1.0794, grad_fn=<AddBackward0>)
# 30 tensor(1.0734, grad_fn=<AddBackward0>)
# 40 tensor(1.0615, grad_fn=<AddBackward0>)
# 50 tensor(1.0524, grad_fn=<AddBackward0>)
# 60 tensor(1.0877, grad_fn=<AddBackward0>)
# 70 tensor(1.0246, grad_fn=<AddBackward0>)
# 80 tensor(1.0532, grad_fn=<AddBackward0>)
# 90 tensor(1.0587, grad_fn=<AddBackward0>)
# 100 tensor(1.0556, grad_fn=<AddBackward0>)
# 110 tensor(1.0419, grad_fn=<AddBackward0>)
# 120 tensor(1.0908, grad_fn=<AddBackward0>)
# 130 tensor(1.0537, grad_fn=<AddBackward0>)
# 140 tensor(1.0305, grad_fn=<AddBackward0>)
# 150 tensor(1.0582, grad_fn=<AddBackward0>)
# 160 tensor(1.0523, grad_fn=<AddBackward0>)
# 170 tensor(0.9998, grad_fn=<AddBackward0>)
# 180 tensor(1.0277, grad_fn=<AddBackward0>)
# 190 tensor(1.0819, grad_fn=<AddBackward0>)
# 200 tensor(1.1079, grad_fn=<AddBackward0>)
# 210 tensor(1.0770, grad_fn=<AddBackward0>)
# 220 tensor(1.0281, grad_fn=<AddBackward0>)
# 230 tensor(1.0602, grad_fn=<AddBackward0>)
# 240 tensor(1.0417, grad_fn=<AddBackward0>)
# 250 tensor(1.0366, grad_fn=<AddBackward0>)
# 260 tensor(1.0451, grad_fn=<AddBackward0>)
# 270 tensor(1.0749, grad_fn=<AddBackward0>)
# 280 tensor(1.0496, grad_fn=<AddBackward0>)
# 290 tensor(1.0957, grad_fn=<AddBackward0>)
# 300 tensor(1.0703, grad_fn=<AddBackward0>)
# 310 tensor(1.1039, grad_fn=<AddBackward0>)
# 320 tensor(1.0372, grad_fn=<AddBackward0>)
# 330 tensor(1.1140, grad_fn=<AddBackward0>)
# 340 tensor(1.0557, grad_fn=<AddBackward0>)
# 350 tensor(1.1383, grad_fn=<AddBackward0>)
# 360 tensor(1.0411, grad_fn=<AddBackward0>)
# 370 tensor(1.0931, grad_fn=<AddBackward0>)
# 380 tensor(1.0568, grad_fn=<AddBackward0>)
# 390 tensor(1.0402, grad_fn=<AddBackward0>)
# 400 tensor(1.0477, grad_fn=<AddBackward0>)
# 410 tensor(1.0902, grad_fn=<AddBackward0>)
# 420 tensor(1.0668, grad_fn=<AddBackward0>)
# 430 tensor(1.0232, grad_fn=<AddBackward0>)
# 440 tensor(1.0525, grad_fn=<AddBackward0>)
# 450 tensor(1.0320, grad_fn=<AddBackward0>)
# 460 tensor(1.0779, grad_fn=<AddBackward0>)
# 470 tensor(1.0824, grad_fn=<AddBackward0>)
# 480 tensor(1.0805, grad_fn=<AddBackward0>)
# 490 tensor(1.0785, grad_fn=<AddBackward0>)
# 500 tensor(1.0445, grad_fn=<AddBackward0>)
# 510 tensor(1.0718, grad_fn=<AddBackward0>)
# 520 tensor(1.0075, grad_fn=<AddBackward0>)
# 530 tensor(0.9931, grad_fn=<AddBackward0>)
# 540 tensor(1.0639, grad_fn=<AddBackward0>)
# 550 tensor(1.0706, grad_fn=<AddBackward0>)
# 560 tensor(1.0464, grad_fn=<AddBackward0>)
# 570 tensor(1.0020, grad_fn=<AddBackward0>)
# 580 tensor(1.0764, grad_fn=<AddBackward0>)
# 590 tensor(1.0835, grad_fn=<AddBackward0>)
# 600 tensor(1.0586, grad_fn=<AddBackward0>)
# 610 tensor(1.0447, grad_fn=<AddBackward0>)
# 620 tensor(1.0334, grad_fn=<AddBackward0>)
# 630 tensor(1.0479, grad_fn=<AddBackward0>)
# 640 tensor(1.0031, grad_fn=<AddBackward0>)
# 650 tensor(1.0358, grad_fn=<AddBackward0>)
# 660 tensor(1.0678, grad_fn=<AddBackward0>)
# 670 tensor(1.0350, grad_fn=<AddBackward0>)
# 680 tensor(1.0406, grad_fn=<AddBackward0>)
# 690 tensor(1.0629, grad_fn=<AddBackward0>)
# 700 tensor(1.0915, grad_fn=<AddBackward0>)
# 710 tensor(0.9700, grad_fn=<AddBackward0>)
# 720 tensor(1.0613, grad_fn=<AddBackward0>)
# 730 tensor(1.0681, grad_fn=<AddBackward0>)
# 740 tensor(1.0793, grad_fn=<AddBackward0>)
# 750 tensor(1.0536, grad_fn=<AddBackward0>)
# 760 tensor(1.0874, grad_fn=<AddBackward0>)
# 770 tensor(1.0487, grad_fn=<AddBackward0>)
# 780 tensor(1.0512, grad_fn=<AddBackward0>)
# 790 tensor(1.0352, grad_fn=<AddBackward0>)
# 800 tensor(1.0835, grad_fn=<AddBackward0>)
# 810 tensor(1.1483, grad_fn=<AddBackward0>)
# 820 tensor(1.0961, grad_fn=<AddBackward0>)
# 830 tensor(1.0150, grad_fn=<AddBackward0>)
# 840 tensor(1.0652, grad_fn=<AddBackward0>)
# 850 tensor(1.0796, grad_fn=<AddBackward0>)
# 860 tensor(1.0997, grad_fn=<AddBackward0>)
# 870 tensor(1.0289, grad_fn=<AddBackward0>)
# 880 tensor(1.0247, grad_fn=<AddBackward0>)
# 890 tensor(1.0805, grad_fn=<AddBackward0>)
# 900 tensor(1.0605, grad_fn=<AddBackward0>)
# 910 tensor(1.1249, grad_fn=<AddBackward0>)
# 920 tensor(1.0770, grad_fn=<AddBackward0>)
# 930 tensor(1.0256, grad_fn=<AddBackward0>)
# 940 tensor(1.0845, grad_fn=<AddBackward0>)
# 950 tensor(1.0613, grad_fn=<AddBackward0>)
# 960 tensor(1.0864, grad_fn=<AddBackward0>)
# 970 tensor(1.0177, grad_fn=<AddBackward0>)
# 980 tensor(1.0755, grad_fn=<AddBackward0>)
# 990 tensor(1.0700, grad_fn=<AddBackward0>)
# 1000 tensor(1.0700, grad_fn=<AddBackward0>)
# 1010 tensor(1.0833, grad_fn=<AddBackward0>)
# 1020 tensor(1.0622, grad_fn=<AddBackward0>)
# 1030 tensor(1.0402, grad_fn=<AddBackward0>)
# 1040 tensor(1.0796, grad_fn=<AddBackward0>)
# 1050 tensor(1.0968, grad_fn=<AddBackward0>)
# 1060 tensor(1.0647, grad_fn=<AddBackward0>)
# 1070 tensor(1.0515, grad_fn=<AddBackward0>)
# 1080 tensor(1.0236, grad_fn=<AddBackward0>)
# 1090 tensor(1.0851, grad_fn=<AddBackward0>)
# 1100 tensor(1.0884, grad_fn=<AddBackward0>)
# 1110 tensor(1.0662, grad_fn=<AddBackward0>)
# 1120 tensor(1.0736, grad_fn=<AddBackward0>)
# 1130 tensor(1.0510, grad_fn=<AddBackward0>)
# 1140 tensor(1.0502, grad_fn=<AddBackward0>)
# 1150 tensor(1.0211, grad_fn=<AddBackward0>)
# 1160 tensor(1.0694, grad_fn=<AddBackward0>)
# 1170 tensor(1.0430, grad_fn=<AddBackward0>)
# 1180 tensor(1.0399, grad_fn=<AddBackward0>)
# 1190 tensor(1.0566, grad_fn=<AddBackward0>)
# 1200 tensor(0.9974, grad_fn=<AddBackward0>)
# 1210 tensor(1.0299, grad_fn=<AddBackward0>)
# 1220 tensor(1.0712, grad_fn=<AddBackward0>)
# 1230 tensor(1.0717, grad_fn=<AddBackward0>)
# 1240 tensor(1.0471, grad_fn=<AddBackward0>)
# 1250 tensor(1.0633, grad_fn=<AddBackward0>)
# 1260 tensor(1.0742, grad_fn=<AddBackward0>)
# 1270 tensor(1.0767, grad_fn=<AddBackward0>)
# 1280 tensor(1.0002, grad_fn=<AddBackward0>)
# 1290 tensor(1.0790, grad_fn=<AddBackward0>)
# 1300 tensor(1.0317, grad_fn=<AddBackward0>)
# 1310 tensor(1.0234, grad_fn=<AddBackward0>)
# 1320 tensor(1.0327, grad_fn=<AddBackward0>)
# 1330 tensor(1.0708, grad_fn=<AddBackward0>)
# 1340 tensor(1.0854, grad_fn=<AddBackward0>)
# 1350 tensor(1.0631, grad_fn=<AddBackward0>)
# 1360 tensor(1.0677, grad_fn=<AddBackward0>)
# 1370 tensor(1.0761, grad_fn=<AddBackward0>)
# 1380 tensor(1.0348, grad_fn=<AddBackward0>)
# 1390 tensor(1.0715, grad_fn=<AddBackward0>)
# 1400 tensor(1.0726, grad_fn=<AddBackward0>)
# 1410 tensor(1.0613, grad_fn=<AddBackward0>)
# 1420 tensor(1.0427, grad_fn=<AddBackward0>)
# 1430 tensor(1.0142, grad_fn=<AddBackward0>)
# 1440 tensor(1.0478, grad_fn=<AddBackward0>)
# 1450 tensor(1.0801, grad_fn=<AddBackward0>)
# 1460 tensor(1.0454, grad_fn=<AddBackward0>)
# 1470 tensor(1.0733, grad_fn=<AddBackward0>)
# 1480 tensor(1.0726, grad_fn=<AddBackward0>)
# 1490 tensor(1.1150, grad_fn=<AddBackward0>)
# 1500 tensor(1.0805, grad_fn=<AddBackward0>)
# 1510 tensor(1.1376, grad_fn=<AddBackward0>)
# 1520 tensor(1.0915, grad_fn=<AddBackward0>)
# 1530 tensor(1.0544, grad_fn=<AddBackward0>)
# 1540 tensor(1.0961, grad_fn=<AddBackward0>)
# 1550 tensor(1.0745, grad_fn=<AddBackward0>)
# 1560 tensor(1.0628, grad_fn=<AddBackward0>)
# 1570 tensor(1.1091, grad_fn=<AddBackward0>)
# 1580 tensor(1.0322, grad_fn=<AddBackward0>)
# 1590 tensor(1.0814, grad_fn=<AddBackward0>)
# 1600 tensor(1.0141, grad_fn=<AddBackward0>)
# 1610 tensor(1.0816, grad_fn=<AddBackward0>)
# 1620 tensor(1.0900, grad_fn=<AddBackward0>)
# 1630 tensor(1.0856, grad_fn=<AddBackward0>)
# 1640 tensor(1.0879, grad_fn=<AddBackward0>)
# 1650 tensor(0.9977, grad_fn=<AddBackward0>)
# 1660 tensor(1.0254, grad_fn=<AddBackward0>)
# 1670 tensor(1.0846, grad_fn=<AddBackward0>)
# 1680 tensor(1.0327, grad_fn=<AddBackward0>)
# 1690 tensor(1.0697, grad_fn=<AddBackward0>)
# 1700 tensor(1.0206, grad_fn=<AddBackward0>)
# 1710 tensor(1.0440, grad_fn=<AddBackward0>)
# 1720 tensor(1.0996, grad_fn=<AddBackward0>)
# 1730 tensor(1.0611, grad_fn=<AddBackward0>)
# 1740 tensor(1.0980, grad_fn=<AddBackward0>)
# 1750 tensor(1.0236, grad_fn=<AddBackward0>)
# 1760 tensor(1.0466, grad_fn=<AddBackward0>)
# 1770 tensor(1.0989, grad_fn=<AddBackward0>)
# 1780 tensor(1.0463, grad_fn=<AddBackward0>)
# 1790 tensor(1.0835, grad_fn=<AddBackward0>)
# 1800 tensor(1.0182, grad_fn=<AddBackward0>)
# 1810 tensor(1.0837, grad_fn=<AddBackward0>)
# 1820 tensor(1.0783, grad_fn=<AddBackward0>)
# 1830 tensor(1.0585, grad_fn=<AddBackward0>)
# 1840 tensor(1.0295, grad_fn=<AddBackward0>)
# 1850 tensor(1.1045, grad_fn=<AddBackward0>)
# 1860 tensor(1.0597, grad_fn=<AddBackward0>)
# 1870 tensor(1.0250, grad_fn=<AddBackward0>)
# 1880 tensor(1.0333, grad_fn=<AddBackward0>)
# 1890 tensor(1.0547, grad_fn=<AddBackward0>)
# 1900 tensor(1.0928, grad_fn=<AddBackward0>)
# 1910 tensor(1.0736, grad_fn=<AddBackward0>)
# 1920 tensor(1.0266, grad_fn=<AddBackward0>)
# 1930 tensor(1.0923, grad_fn=<AddBackward0>)
# 1940 tensor(1.0391, grad_fn=<AddBackward0>)
# 1950 tensor(1.0081, grad_fn=<AddBackward0>)
# 1960 tensor(1.0714, grad_fn=<AddBackward0>)
# 1970 tensor(1.0733, grad_fn=<AddBackward0>)
# 1980 tensor(1.0246, grad_fn=<AddBackward0>)
# 1990 tensor(1.0680, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 1 is bigger than 1.5788374 then go to left, else go to right
#     LEFT:
#     WHEN feature 1 is bigger than 1.1689166 then go to left, else go to right
#         LEFT:
#         WHEN feature 4 is bigger than 0.59462565 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 4 is bigger than 0.5337683 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
#     RIGHT:
#     WHEN feature 7 is bigger than 0.4661599 then go to left, else go to right
#         LEFT:
#         WHEN feature 4 is bigger than -0.39486003 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
#         RIGHT:
#         WHEN feature 1 is bigger than 0.15645109 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.6066481994459834
# f1_score:
#  0.525
# confusion_matrix:
#  [[42 10]
#  [18  6]]

# %%
print("accuracy:\n", np.array(all_results['accuracy']).mean())
print("f1_score:\n", np.array(all_results['f1_score']).mean())
print("confusion_matrix:\n", np.array(all_results['confusion_matrix']).mean(0))
# Out:
# accuracy:
#  0.6151662049861496
# f1_score:
#  0.44562724205801035
# confusion_matrix:
#  [[44.4  5.1]
#  [23.2  3.3]]

# %% [markdown]
# # The Breast Cancer Wisconsin (Diagnostic) dataset

# %%
# !wget https://raw.githubusercontent.com/jbrownlee/Datasets/refs/heads/master/breast-cancer-wisconsin.csv
# Out:
# --2024-10-26 12:15:17--  https://raw.githubusercontent.com/jbrownlee/Datasets/refs/heads/master/breast-cancer-wisconsin.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14486 (14K) [text/plain]
# Saving to: ‘breast-cancer-wisconsin.csv.2’
#
# breast-cancer-wisco 100%[===================>]  14.15K  --.-KB/s    in 0.003s
#
# 2024-10-26 12:15:17 (4.56 MB/s) - ‘breast-cancer-wisconsin.csv.2’ saved [14486/14486]

# %%
def load_breast_cancer_data(filepath):

  data = pd.read_csv(filepath)

  data.columns = [
      "ClumpThickness", "UniformityOfCellSize",
      "UniformityOfCellShape", "MarginalAdhesion", "SingleEpithelialCellSize",
      "BareNuclei", "BlandChromatin", "NormalNucleoli", "Mitoses", "Class"
  ]

  data['Class'] = data['Class'].replace({2: 'Benign', 4: 'Malignant'})

  return data

# %%
breast_cancer_dataset_begin = load_breast_cancer_data("/content/breast-cancer-wisconsin.csv")
breast_cancer_dataset_begin = breast_cancer_dataset_begin.to_numpy()

breast_cancer_dataset = []
for i in range(len(breast_cancer_dataset_begin)) :
  can_add = True
  for j in range(len(breast_cancer_dataset_begin[i])) :
    if breast_cancer_dataset_begin[i][j] == '?' :
      can_add = False
  if can_add :
    breast_cancer_dataset.append(breast_cancer_dataset_begin[i])
breast_cancer_dataset = np.stack(breast_cancer_dataset)

np.random.shuffle(breast_cancer_dataset)

x_all = breast_cancer_dataset[:,0:-1].astype(float)
y_all = (breast_cancer_dataset[:,-1:] == "Malignant").astype(float)

# %%
all_results, all_model = k_fold(x_all, y_all, num_k = 10, use_mlp = False, normalize = True, batch_size = 256,
                                focus_on_cont=True)
# Out:
# =============================================================
# (614, 9) (614, 1)
# (68, 9) (68, 1)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 256, 'focus_on_cont': True}
# Num Label: [403 211]
# Label Weight: [1.         1.90995261]
# 0 tensor(0.8787, grad_fn=<AddBackward0>)
# 10 tensor(0.9006, grad_fn=<AddBackward0>)
# 20 tensor(0.9255, grad_fn=<AddBackward0>)
# 30 tensor(0.8817, grad_fn=<AddBackward0>)
# 40 tensor(0.9029, grad_fn=<AddBackward0>)
# 50 tensor(0.9063, grad_fn=<AddBackward0>)
# 60 tensor(0.8936, grad_fn=<AddBackward0>)
# 70 tensor(0.9115, grad_fn=<AddBackward0>)
# 80 tensor(0.9162, grad_fn=<AddBackward0>)
# 90 tensor(0.9043, grad_fn=<AddBackward0>)
# 100 tensor(0.9285, grad_fn=<AddBackward0>)
# 110 tensor(0.8943, grad_fn=<AddBackward0>)
# 120 tensor(0.8903, grad_fn=<AddBackward0>)
# 130 tensor(0.8823, grad_fn=<AddBackward0>)
# 140 tensor(0.9019, grad_fn=<AddBackward0>)
# 150 tensor(0.8726, grad_fn=<AddBackward0>)
# 160 tensor(0.8982, grad_fn=<AddBackward0>)
# 170 tensor(0.8782, grad_fn=<AddBackward0>)
# 180 tensor(0.9242, grad_fn=<AddBackward0>)
# 190 tensor(0.9086, grad_fn=<AddBackward0>)
# 200 tensor(0.8868, grad_fn=<AddBackward0>)
# 210 tensor(0.9006, grad_fn=<AddBackward0>)
# 220 tensor(0.9329, grad_fn=<AddBackward0>)
# 230 tensor(0.8894, grad_fn=<AddBackward0>)
# 240 tensor(0.8867, grad_fn=<AddBackward0>)
# 250 tensor(0.9053, grad_fn=<AddBackward0>)
# 260 tensor(0.8872, grad_fn=<AddBackward0>)
# 270 tensor(0.8642, grad_fn=<AddBackward0>)
# 280 tensor(0.9165, grad_fn=<AddBackward0>)
# 290 tensor(0.9025, grad_fn=<AddBackward0>)
# 300 tensor(0.8892, grad_fn=<AddBackward0>)
# 310 tensor(0.8684, grad_fn=<AddBackward0>)
# 320 tensor(0.9103, grad_fn=<AddBackward0>)
# 330 tensor(0.8898, grad_fn=<AddBackward0>)
# 340 tensor(0.8738, grad_fn=<AddBackward0>)
# 350 tensor(0.9098, grad_fn=<AddBackward0>)
# 360 tensor(0.8812, grad_fn=<AddBackward0>)
# 370 tensor(0.8732, grad_fn=<AddBackward0>)
# 380 tensor(0.8882, grad_fn=<AddBackward0>)
# 390 tensor(0.8930, grad_fn=<AddBackward0>)
# 400 tensor(0.8718, grad_fn=<AddBackward0>)
# 410 tensor(0.9039, grad_fn=<AddBackward0>)
# 420 tensor(0.9021, grad_fn=<AddBackward0>)
# 430 tensor(0.8654, grad_fn=<AddBackward0>)
# 440 tensor(0.9322, grad_fn=<AddBackward0>)
# 450 tensor(0.9250, grad_fn=<AddBackward0>)
# 460 tensor(0.9276, grad_fn=<AddBackward0>)
# 470 tensor(0.8764, grad_fn=<AddBackward0>)
# 480 tensor(0.8680, grad_fn=<AddBackward0>)
# 490 tensor(0.9298, grad_fn=<AddBackward0>)
# 500 tensor(0.8901, grad_fn=<AddBackward0>)
# 510 tensor(0.9015, grad_fn=<AddBackward0>)
# 520 tensor(0.8778, grad_fn=<AddBackward0>)
# 530 tensor(0.8787, grad_fn=<AddBackward0>)
# 540 tensor(0.9312, grad_fn=<AddBackward0>)
# 550 tensor(0.8878, grad_fn=<AddBackward0>)
# 560 tensor(0.8882, grad_fn=<AddBackward0>)
# 570 tensor(0.9117, grad_fn=<AddBackward0>)
# 580 tensor(0.9083, grad_fn=<AddBackward0>)
# 590 tensor(0.8776, grad_fn=<AddBackward0>)
# 600 tensor(0.9176, grad_fn=<AddBackward0>)
# 610 tensor(0.8912, grad_fn=<AddBackward0>)
# 620 tensor(0.9259, grad_fn=<AddBackward0>)
# 630 tensor(0.8667, grad_fn=<AddBackward0>)
# 640 tensor(0.8790, grad_fn=<AddBackward0>)
# 650 tensor(0.9070, grad_fn=<AddBackward0>)
# 660 tensor(0.8675, grad_fn=<AddBackward0>)
# 670 tensor(0.8614, grad_fn=<AddBackward0>)
# 680 tensor(0.8660, grad_fn=<AddBackward0>)
# 690 tensor(0.8781, grad_fn=<AddBackward0>)
# 700 tensor(0.8559, grad_fn=<AddBackward0>)
# 710 tensor(0.8985, grad_fn=<AddBackward0>)
# 720 tensor(0.9000, grad_fn=<AddBackward0>)
# 730 tensor(0.8803, grad_fn=<AddBackward0>)
# 740 tensor(0.9003, grad_fn=<AddBackward0>)
# 750 tensor(0.8974, grad_fn=<AddBackward0>)
# 760 tensor(0.9008, grad_fn=<AddBackward0>)
# 770 tensor(0.9020, grad_fn=<AddBackward0>)
# 780 tensor(0.8480, grad_fn=<AddBackward0>)
# 790 tensor(0.9209, grad_fn=<AddBackward0>)
# 800 tensor(0.8675, grad_fn=<AddBackward0>)
# 810 tensor(0.8925, grad_fn=<AddBackward0>)
# 820 tensor(0.9169, grad_fn=<AddBackward0>)
# 830 tensor(0.8895, grad_fn=<AddBackward0>)
# 840 tensor(0.8468, grad_fn=<AddBackward0>)
# 850 tensor(0.8787, grad_fn=<AddBackward0>)
# 860 tensor(0.8545, grad_fn=<AddBackward0>)
# 870 tensor(0.9092, grad_fn=<AddBackward0>)
# 880 tensor(0.9057, grad_fn=<AddBackward0>)
# 890 tensor(0.9445, grad_fn=<AddBackward0>)
# 900 tensor(0.9026, grad_fn=<AddBackward0>)
# 910 tensor(0.9004, grad_fn=<AddBackward0>)
# 920 tensor(0.8916, grad_fn=<AddBackward0>)
# 930 tensor(0.8802, grad_fn=<AddBackward0>)
# 940 tensor(0.9167, grad_fn=<AddBackward0>)
# 950 tensor(0.8582, grad_fn=<AddBackward0>)
# 960 tensor(0.8909, grad_fn=<AddBackward0>)
# 970 tensor(0.8725, grad_fn=<AddBackward0>)
# 980 tensor(0.8875, grad_fn=<AddBackward0>)
# 990 tensor(0.8401, grad_fn=<AddBackward0>)
# 1000 tensor(0.8956, grad_fn=<AddBackward0>)
# 1010 tensor(0.8683, grad_fn=<AddBackward0>)
# 1020 tensor(0.8965, grad_fn=<AddBackward0>)
# 1030 tensor(0.8995, grad_fn=<AddBackward0>)
# 1040 tensor(0.8498, grad_fn=<AddBackward0>)
# 1050 tensor(0.9028, grad_fn=<AddBackward0>)
# 1060 tensor(0.9090, grad_fn=<AddBackward0>)
# 1070 tensor(0.8794, grad_fn=<AddBackward0>)
# 1080 tensor(0.9323, grad_fn=<AddBackward0>)
# 1090 tensor(0.8915, grad_fn=<AddBackward0>)
# 1100 tensor(0.8723, grad_fn=<AddBackward0>)
# 1110 tensor(0.8369, grad_fn=<AddBackward0>)
# 1120 tensor(0.8821, grad_fn=<AddBackward0>)
# 1130 tensor(0.8808, grad_fn=<AddBackward0>)
# 1140 tensor(0.8829, grad_fn=<AddBackward0>)
# 1150 tensor(0.8927, grad_fn=<AddBackward0>)
# 1160 tensor(0.9017, grad_fn=<AddBackward0>)
# 1170 tensor(0.8859, grad_fn=<AddBackward0>)
# 1180 tensor(0.8834, grad_fn=<AddBackward0>)
# 1190 tensor(0.8424, grad_fn=<AddBackward0>)
# 1200 tensor(0.9085, grad_fn=<AddBackward0>)
# 1210 tensor(0.8964, grad_fn=<AddBackward0>)
# 1220 tensor(0.8672, grad_fn=<AddBackward0>)
# 1230 tensor(0.9165, grad_fn=<AddBackward0>)
# 1240 tensor(0.8548, grad_fn=<AddBackward0>)
# 1250 tensor(0.8777, grad_fn=<AddBackward0>)
# 1260 tensor(0.8696, grad_fn=<AddBackward0>)
# 1270 tensor(0.9235, grad_fn=<AddBackward0>)
# 1280 tensor(0.9204, grad_fn=<AddBackward0>)
# 1290 tensor(0.8954, grad_fn=<AddBackward0>)
# 1300 tensor(0.8936, grad_fn=<AddBackward0>)
# 1310 tensor(0.9200, grad_fn=<AddBackward0>)
# 1320 tensor(0.8936, grad_fn=<AddBackward0>)
# 1330 tensor(0.8685, grad_fn=<AddBackward0>)
# 1340 tensor(0.9438, grad_fn=<AddBackward0>)
# 1350 tensor(0.9222, grad_fn=<AddBackward0>)
# 1360 tensor(0.8471, grad_fn=<AddBackward0>)
# 1370 tensor(0.8723, grad_fn=<AddBackward0>)
# 1380 tensor(0.8611, grad_fn=<AddBackward0>)
# 1390 tensor(0.8839, grad_fn=<AddBackward0>)
# 1400 tensor(0.9152, grad_fn=<AddBackward0>)
# 1410 tensor(0.8660, grad_fn=<AddBackward0>)
# 1420 tensor(0.8916, grad_fn=<AddBackward0>)
# 1430 tensor(0.8757, grad_fn=<AddBackward0>)
# 1440 tensor(0.8686, grad_fn=<AddBackward0>)
# 1450 tensor(0.8866, grad_fn=<AddBackward0>)
# 1460 tensor(0.8870, grad_fn=<AddBackward0>)
# 1470 tensor(0.9100, grad_fn=<AddBackward0>)
# 1480 tensor(0.9028, grad_fn=<AddBackward0>)
# 1490 tensor(0.8585, grad_fn=<AddBackward0>)
# 1500 tensor(0.9062, grad_fn=<AddBackward0>)
# 1510 tensor(0.8788, grad_fn=<AddBackward0>)
# 1520 tensor(0.9094, grad_fn=<AddBackward0>)
# 1530 tensor(0.9081, grad_fn=<AddBackward0>)
# 1540 tensor(0.8643, grad_fn=<AddBackward0>)
# 1550 tensor(0.9095, grad_fn=<AddBackward0>)
# 1560 tensor(0.9117, grad_fn=<AddBackward0>)
# 1570 tensor(0.9097, grad_fn=<AddBackward0>)
# 1580 tensor(0.9270, grad_fn=<AddBackward0>)
# 1590 tensor(0.8943, grad_fn=<AddBackward0>)
# 1600 tensor(0.9121, grad_fn=<AddBackward0>)
# 1610 tensor(0.8806, grad_fn=<AddBackward0>)
# 1620 tensor(0.8797, grad_fn=<AddBackward0>)
# 1630 tensor(0.8770, grad_fn=<AddBackward0>)
# 1640 tensor(0.8729, grad_fn=<AddBackward0>)
# 1650 tensor(0.8682, grad_fn=<AddBackward0>)
# 1660 tensor(0.8821, grad_fn=<AddBackward0>)
# 1670 tensor(0.8959, grad_fn=<AddBackward0>)
# 1680 tensor(0.9062, grad_fn=<AddBackward0>)
# 1690 tensor(0.8972, grad_fn=<AddBackward0>)
# 1700 tensor(0.8882, grad_fn=<AddBackward0>)
# 1710 tensor(0.9089, grad_fn=<AddBackward0>)
# 1720 tensor(0.9263, grad_fn=<AddBackward0>)
# 1730 tensor(0.8770, grad_fn=<AddBackward0>)
# 1740 tensor(0.8731, grad_fn=<AddBackward0>)
# 1750 tensor(0.9323, grad_fn=<AddBackward0>)
# 1760 tensor(0.8583, grad_fn=<AddBackward0>)
# 1770 tensor(0.8752, grad_fn=<AddBackward0>)
# 1780 tensor(0.8567, grad_fn=<AddBackward0>)
# 1790 tensor(0.8958, grad_fn=<AddBackward0>)
# 1800 tensor(0.8794, grad_fn=<AddBackward0>)
# 1810 tensor(0.8625, grad_fn=<AddBackward0>)
# 1820 tensor(0.8803, grad_fn=<AddBackward0>)
# 1830 tensor(0.8552, grad_fn=<AddBackward0>)
# 1840 tensor(0.8567, grad_fn=<AddBackward0>)
# 1850 tensor(0.8444, grad_fn=<AddBackward0>)
# 1860 tensor(0.9013, grad_fn=<AddBackward0>)
# 1870 tensor(0.8690, grad_fn=<AddBackward0>)
# 1880 tensor(0.9791, grad_fn=<AddBackward0>)
# 1890 tensor(0.9319, grad_fn=<AddBackward0>)
# 1900 tensor(0.9090, grad_fn=<AddBackward0>)
# 1910 tensor(0.8878, grad_fn=<AddBackward0>)
# 1920 tensor(0.8601, grad_fn=<AddBackward0>)
# 1930 tensor(0.8696, grad_fn=<AddBackward0>)
# 1940 tensor(0.8789, grad_fn=<AddBackward0>)
# 1950 tensor(0.8803, grad_fn=<AddBackward0>)
# 1960 tensor(0.9048, grad_fn=<AddBackward0>)
# 1970 tensor(0.9391, grad_fn=<AddBackward0>)
# 1980 tensor(0.8643, grad_fn=<AddBackward0>)
# 1990 tensor(0.8702, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 2 is bigger than 0.5783954 then go to left, else go to right
#     LEFT:
#     WHEN feature 5 is bigger than 6.0286117 then go to left, else go to right
#         LEFT:
#         WHEN feature 4 is bigger than -0.9292971 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 2 is bigger than -0.11618386 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#     RIGHT:
#     WHEN feature 1 is bigger than -2.4647717 then go to left, else go to right
#         LEFT:
#         WHEN feature 7 is bigger than -3.1163306 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 2 is bigger than 0.83450806 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.5882352941176471
# f1_score:
#  0.37037037037037035
# confusion_matrix:
#  [[40  0]
#  [28  0]]
# =============================================================
# (614, 9) (614, 1)
# (68, 9) (68, 1)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 256, 'focus_on_cont': True}
# Num Label: [397 217]
# Label Weight: [1.         1.82949309]
# 0 tensor(0.8903, grad_fn=<AddBackward0>)
# 10 tensor(0.8755, grad_fn=<AddBackward0>)
# 20 tensor(0.8594, grad_fn=<AddBackward0>)
# 30 tensor(0.9028, grad_fn=<AddBackward0>)
# 40 tensor(0.8799, grad_fn=<AddBackward0>)
# 50 tensor(0.8835, grad_fn=<AddBackward0>)
# 60 tensor(0.8944, grad_fn=<AddBackward0>)
# 70 tensor(0.9031, grad_fn=<AddBackward0>)
# 80 tensor(0.8789, grad_fn=<AddBackward0>)
# 90 tensor(0.9063, grad_fn=<AddBackward0>)
# 100 tensor(0.8981, grad_fn=<AddBackward0>)
# 110 tensor(0.8911, grad_fn=<AddBackward0>)
# 120 tensor(0.9116, grad_fn=<AddBackward0>)
# 130 tensor(0.8975, grad_fn=<AddBackward0>)
# 140 tensor(0.8961, grad_fn=<AddBackward0>)
# 150 tensor(0.8909, grad_fn=<AddBackward0>)
# 160 tensor(0.8614, grad_fn=<AddBackward0>)
# 170 tensor(0.8779, grad_fn=<AddBackward0>)
# 180 tensor(0.8907, grad_fn=<AddBackward0>)
# 190 tensor(0.8724, grad_fn=<AddBackward0>)
# 200 tensor(0.8873, grad_fn=<AddBackward0>)
# 210 tensor(0.8746, grad_fn=<AddBackward0>)
# 220 tensor(0.8443, grad_fn=<AddBackward0>)
# 230 tensor(0.8881, grad_fn=<AddBackward0>)
# 240 tensor(0.8409, grad_fn=<AddBackward0>)
# 250 tensor(0.8740, grad_fn=<AddBackward0>)
# 260 tensor(0.9083, grad_fn=<AddBackward0>)
# 270 tensor(0.8602, grad_fn=<AddBackward0>)
# 280 tensor(0.8987, grad_fn=<AddBackward0>)
# 290 tensor(0.8866, grad_fn=<AddBackward0>)
# 300 tensor(0.9387, grad_fn=<AddBackward0>)
# 310 tensor(0.8561, grad_fn=<AddBackward0>)
# 320 tensor(0.8717, grad_fn=<AddBackward0>)
# 330 tensor(0.9029, grad_fn=<AddBackward0>)
# 340 tensor(0.8654, grad_fn=<AddBackward0>)
# 350 tensor(0.8676, grad_fn=<AddBackward0>)
# 360 tensor(0.9008, grad_fn=<AddBackward0>)
# 370 tensor(0.8694, grad_fn=<AddBackward0>)
# 380 tensor(0.8835, grad_fn=<AddBackward0>)
# 390 tensor(0.8720, grad_fn=<AddBackward0>)
# 400 tensor(0.8596, grad_fn=<AddBackward0>)
# 410 tensor(0.8553, grad_fn=<AddBackward0>)
# 420 tensor(0.9125, grad_fn=<AddBackward0>)
# 430 tensor(0.8860, grad_fn=<AddBackward0>)
# 440 tensor(0.8644, grad_fn=<AddBackward0>)
# 450 tensor(0.8651, grad_fn=<AddBackward0>)
# 460 tensor(0.8237, grad_fn=<AddBackward0>)
# 470 tensor(0.8732, grad_fn=<AddBackward0>)
# 480 tensor(0.8370, grad_fn=<AddBackward0>)
# 490 tensor(0.9172, grad_fn=<AddBackward0>)
# 500 tensor(0.8364, grad_fn=<AddBackward0>)
# 510 tensor(0.8590, grad_fn=<AddBackward0>)
# 520 tensor(0.8676, grad_fn=<AddBackward0>)
# 530 tensor(0.9020, grad_fn=<AddBackward0>)
# 540 tensor(0.9045, grad_fn=<AddBackward0>)
# 550 tensor(0.8991, grad_fn=<AddBackward0>)
# 560 tensor(0.8768, grad_fn=<AddBackward0>)
# 570 tensor(0.8814, grad_fn=<AddBackward0>)
# 580 tensor(0.8498, grad_fn=<AddBackward0>)
# 590 tensor(0.9033, grad_fn=<AddBackward0>)
# 600 tensor(0.8809, grad_fn=<AddBackward0>)
# 610 tensor(0.8624, grad_fn=<AddBackward0>)
# 620 tensor(0.9034, grad_fn=<AddBackward0>)
# 630 tensor(0.8678, grad_fn=<AddBackward0>)
# 640 tensor(0.9035, grad_fn=<AddBackward0>)
# 650 tensor(0.8905, grad_fn=<AddBackward0>)
# 660 tensor(0.9199, grad_fn=<AddBackward0>)
# 670 tensor(0.8850, grad_fn=<AddBackward0>)
# 680 tensor(0.8551, grad_fn=<AddBackward0>)
# 690 tensor(0.8609, grad_fn=<AddBackward0>)
# 700 tensor(0.8979, grad_fn=<AddBackward0>)
# 710 tensor(0.8790, grad_fn=<AddBackward0>)
# 720 tensor(0.8623, grad_fn=<AddBackward0>)
# 730 tensor(0.8699, grad_fn=<AddBackward0>)
# 740 tensor(0.9051, grad_fn=<AddBackward0>)
# 750 tensor(0.8672, grad_fn=<AddBackward0>)
# 760 tensor(0.8742, grad_fn=<AddBackward0>)
# 770 tensor(0.8634, grad_fn=<AddBackward0>)
# 780 tensor(0.8978, grad_fn=<AddBackward0>)
# 790 tensor(0.8839, grad_fn=<AddBackward0>)
# 800 tensor(0.8360, grad_fn=<AddBackward0>)
# 810 tensor(0.8781, grad_fn=<AddBackward0>)
# 820 tensor(0.9120, grad_fn=<AddBackward0>)
# 830 tensor(0.9318, grad_fn=<AddBackward0>)
# 840 tensor(0.9112, grad_fn=<AddBackward0>)
# 850 tensor(0.8992, grad_fn=<AddBackward0>)
# 860 tensor(0.8608, grad_fn=<AddBackward0>)
# 870 tensor(0.8862, grad_fn=<AddBackward0>)
# 880 tensor(0.8486, grad_fn=<AddBackward0>)
# 890 tensor(0.9438, grad_fn=<AddBackward0>)
# 900 tensor(0.9206, grad_fn=<AddBackward0>)
# 910 tensor(0.9495, grad_fn=<AddBackward0>)
# 920 tensor(0.8694, grad_fn=<AddBackward0>)
# 930 tensor(0.9004, grad_fn=<AddBackward0>)
# 940 tensor(0.8581, grad_fn=<AddBackward0>)
# 950 tensor(0.8507, grad_fn=<AddBackward0>)
# 960 tensor(0.8758, grad_fn=<AddBackward0>)
# 970 tensor(0.8664, grad_fn=<AddBackward0>)
# 980 tensor(0.8548, grad_fn=<AddBackward0>)
# 990 tensor(0.8865, grad_fn=<AddBackward0>)
# 1000 tensor(0.8614, grad_fn=<AddBackward0>)
# 1010 tensor(0.8829, grad_fn=<AddBackward0>)
# 1020 tensor(0.8886, grad_fn=<AddBackward0>)
# 1030 tensor(0.9044, grad_fn=<AddBackward0>)
# 1040 tensor(0.8253, grad_fn=<AddBackward0>)
# 1050 tensor(0.8773, grad_fn=<AddBackward0>)
# 1060 tensor(0.9011, grad_fn=<AddBackward0>)
# 1070 tensor(0.9203, grad_fn=<AddBackward0>)
# 1080 tensor(0.8998, grad_fn=<AddBackward0>)
# 1090 tensor(0.8866, grad_fn=<AddBackward0>)
# 1100 tensor(0.8944, grad_fn=<AddBackward0>)
# 1110 tensor(0.8869, grad_fn=<AddBackward0>)
# 1120 tensor(0.8919, grad_fn=<AddBackward0>)
# 1130 tensor(0.8739, grad_fn=<AddBackward0>)
# 1140 tensor(0.9093, grad_fn=<AddBackward0>)
# 1150 tensor(0.9283, grad_fn=<AddBackward0>)
# 1160 tensor(0.8918, grad_fn=<AddBackward0>)
# 1170 tensor(0.8721, grad_fn=<AddBackward0>)
# 1180 tensor(0.8607, grad_fn=<AddBackward0>)
# 1190 tensor(0.8408, grad_fn=<AddBackward0>)
# 1200 tensor(0.8384, grad_fn=<AddBackward0>)
# 1210 tensor(0.8916, grad_fn=<AddBackward0>)
# 1220 tensor(0.8889, grad_fn=<AddBackward0>)
# 1230 tensor(0.8764, grad_fn=<AddBackward0>)
# 1240 tensor(0.9088, grad_fn=<AddBackward0>)
# 1250 tensor(0.8889, grad_fn=<AddBackward0>)
# 1260 tensor(0.8961, grad_fn=<AddBackward0>)
# 1270 tensor(0.9026, grad_fn=<AddBackward0>)
# 1280 tensor(0.8705, grad_fn=<AddBackward0>)
# 1290 tensor(0.8566, grad_fn=<AddBackward0>)
# 1300 tensor(0.8927, grad_fn=<AddBackward0>)
# 1310 tensor(0.8589, grad_fn=<AddBackward0>)
# 1320 tensor(0.8699, grad_fn=<AddBackward0>)
# 1330 tensor(0.9240, grad_fn=<AddBackward0>)
# 1340 tensor(0.8963, grad_fn=<AddBackward0>)
# 1350 tensor(0.9202, grad_fn=<AddBackward0>)
# 1360 tensor(0.8699, grad_fn=<AddBackward0>)
# 1370 tensor(0.8585, grad_fn=<AddBackward0>)
# 1380 tensor(0.8827, grad_fn=<AddBackward0>)
# 1390 tensor(0.8578, grad_fn=<AddBackward0>)
# 1400 tensor(0.8452, grad_fn=<AddBackward0>)
# 1410 tensor(0.8577, grad_fn=<AddBackward0>)
# 1420 tensor(0.9269, grad_fn=<AddBackward0>)
# 1430 tensor(0.8930, grad_fn=<AddBackward0>)
# 1440 tensor(0.8995, grad_fn=<AddBackward0>)
# 1450 tensor(0.8886, grad_fn=<AddBackward0>)
# 1460 tensor(0.8862, grad_fn=<AddBackward0>)
# 1470 tensor(0.8560, grad_fn=<AddBackward0>)
# 1480 tensor(0.9488, grad_fn=<AddBackward0>)
# 1490 tensor(0.8439, grad_fn=<AddBackward0>)
# 1500 tensor(0.8957, grad_fn=<AddBackward0>)
# 1510 tensor(0.8898, grad_fn=<AddBackward0>)
# 1520 tensor(0.8712, grad_fn=<AddBackward0>)
# 1530 tensor(0.8790, grad_fn=<AddBackward0>)
# 1540 tensor(0.8669, grad_fn=<AddBackward0>)
# 1550 tensor(0.8837, grad_fn=<AddBackward0>)
# 1560 tensor(0.8814, grad_fn=<AddBackward0>)
# 1570 tensor(0.8891, grad_fn=<AddBackward0>)
# 1580 tensor(0.9088, grad_fn=<AddBackward0>)
# 1590 tensor(0.9022, grad_fn=<AddBackward0>)
# 1600 tensor(0.8678, grad_fn=<AddBackward0>)
# 1610 tensor(0.8634, grad_fn=<AddBackward0>)
# 1620 tensor(0.8724, grad_fn=<AddBackward0>)
# 1630 tensor(0.8995, grad_fn=<AddBackward0>)
# 1640 tensor(0.8715, grad_fn=<AddBackward0>)
# 1650 tensor(0.8838, grad_fn=<AddBackward0>)
# 1660 tensor(0.8575, grad_fn=<AddBackward0>)
# 1670 tensor(0.9197, grad_fn=<AddBackward0>)
# 1680 tensor(0.8553, grad_fn=<AddBackward0>)
# 1690 tensor(0.8651, grad_fn=<AddBackward0>)
# 1700 tensor(0.8500, grad_fn=<AddBackward0>)
# 1710 tensor(0.8720, grad_fn=<AddBackward0>)
# 1720 tensor(0.8591, grad_fn=<AddBackward0>)
# 1730 tensor(0.9062, grad_fn=<AddBackward0>)
# 1740 tensor(0.8798, grad_fn=<AddBackward0>)
# 1750 tensor(0.8866, grad_fn=<AddBackward0>)
# 1760 tensor(0.8549, grad_fn=<AddBackward0>)
# 1770 tensor(0.8850, grad_fn=<AddBackward0>)
# 1780 tensor(0.9035, grad_fn=<AddBackward0>)
# 1790 tensor(0.8856, grad_fn=<AddBackward0>)
# 1800 tensor(0.8900, grad_fn=<AddBackward0>)
# 1810 tensor(0.9158, grad_fn=<AddBackward0>)
# 1820 tensor(0.8858, grad_fn=<AddBackward0>)
# 1830 tensor(0.8825, grad_fn=<AddBackward0>)
# 1840 tensor(0.8726, grad_fn=<AddBackward0>)
# 1850 tensor(0.8493, grad_fn=<AddBackward0>)
# 1860 tensor(0.8803, grad_fn=<AddBackward0>)
# 1870 tensor(0.8855, grad_fn=<AddBackward0>)
# 1880 tensor(0.8430, grad_fn=<AddBackward0>)
# 1890 tensor(0.8658, grad_fn=<AddBackward0>)
# 1900 tensor(0.8514, grad_fn=<AddBackward0>)
# 1910 tensor(0.8751, grad_fn=<AddBackward0>)
# 1920 tensor(0.8813, grad_fn=<AddBackward0>)
# 1930 tensor(0.8939, grad_fn=<AddBackward0>)
# 1940 tensor(0.9009, grad_fn=<AddBackward0>)
# 1950 tensor(0.9049, grad_fn=<AddBackward0>)
# 1960 tensor(0.9202, grad_fn=<AddBackward0>)
# 1970 tensor(0.8879, grad_fn=<AddBackward0>)
# 1980 tensor(0.8816, grad_fn=<AddBackward0>)
# 1990 tensor(0.8855, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 8 is bigger than -0.5933303 then go to left, else go to right
#     LEFT:
#     WHEN feature 5 is bigger than 0.8635015 then go to left, else go to right
#         LEFT:
#         WHEN feature 4 is bigger than -0.5356682 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 6 is bigger than -1.1359532 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#     RIGHT:
#     WHEN feature 8 is bigger than 0.7260554 then go to left, else go to right
#         LEFT:
#         WHEN feature 2 is bigger than 0.6046935 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 0 is bigger than 0.10026517 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.6141868512110726
# f1_score:
#  0.803921568627451
# confusion_matrix:
#  [[46  0]
#  [10 12]]
# =============================================================
# (614, 9) (614, 1)
# (68, 9) (68, 1)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 256, 'focus_on_cont': True}
# Num Label: [401 213]
# Label Weight: [1.         1.88262911]
# 0 tensor(0.9138, grad_fn=<AddBackward0>)
# 10 tensor(0.8747, grad_fn=<AddBackward0>)
# 20 tensor(0.8986, grad_fn=<AddBackward0>)
# 30 tensor(0.8960, grad_fn=<AddBackward0>)
# 40 tensor(0.9043, grad_fn=<AddBackward0>)
# 50 tensor(0.8859, grad_fn=<AddBackward0>)
# 60 tensor(0.8907, grad_fn=<AddBackward0>)
# 70 tensor(0.9106, grad_fn=<AddBackward0>)
# 80 tensor(0.8921, grad_fn=<AddBackward0>)
# 90 tensor(0.9061, grad_fn=<AddBackward0>)
# 100 tensor(0.8864, grad_fn=<AddBackward0>)
# 110 tensor(0.8682, grad_fn=<AddBackward0>)
# 120 tensor(0.8882, grad_fn=<AddBackward0>)
# 130 tensor(0.8804, grad_fn=<AddBackward0>)
# 140 tensor(0.9007, grad_fn=<AddBackward0>)
# 150 tensor(0.8923, grad_fn=<AddBackward0>)
# 160 tensor(0.9176, grad_fn=<AddBackward0>)
# 170 tensor(0.8865, grad_fn=<AddBackward0>)
# 180 tensor(0.9023, grad_fn=<AddBackward0>)
# 190 tensor(0.8885, grad_fn=<AddBackward0>)
# 200 tensor(0.9068, grad_fn=<AddBackward0>)
# 210 tensor(0.8660, grad_fn=<AddBackward0>)
# 220 tensor(0.9133, grad_fn=<AddBackward0>)
# 230 tensor(0.9067, grad_fn=<AddBackward0>)
# 240 tensor(0.9073, grad_fn=<AddBackward0>)
# 250 tensor(0.8903, grad_fn=<AddBackward0>)
# 260 tensor(0.8827, grad_fn=<AddBackward0>)
# 270 tensor(0.8648, grad_fn=<AddBackward0>)
# 280 tensor(0.9035, grad_fn=<AddBackward0>)
# 290 tensor(0.8847, grad_fn=<AddBackward0>)
# 300 tensor(0.9144, grad_fn=<AddBackward0>)
# 310 tensor(0.8657, grad_fn=<AddBackward0>)
# 320 tensor(0.8956, grad_fn=<AddBackward0>)
# 330 tensor(0.8902, grad_fn=<AddBackward0>)
# 340 tensor(0.8882, grad_fn=<AddBackward0>)
# 350 tensor(0.8995, grad_fn=<AddBackward0>)
# 360 tensor(0.9157, grad_fn=<AddBackward0>)
# 370 tensor(0.9058, grad_fn=<AddBackward0>)
# 380 tensor(0.8864, grad_fn=<AddBackward0>)
# 390 tensor(0.8733, grad_fn=<AddBackward0>)
# 400 tensor(0.9243, grad_fn=<AddBackward0>)
# 410 tensor(0.8906, grad_fn=<AddBackward0>)
# 420 tensor(0.8965, grad_fn=<AddBackward0>)
# 430 tensor(0.8549, grad_fn=<AddBackward0>)
# 440 tensor(0.8587, grad_fn=<AddBackward0>)
# 450 tensor(0.8970, grad_fn=<AddBackward0>)
# 460 tensor(0.8720, grad_fn=<AddBackward0>)
# 470 tensor(0.9036, grad_fn=<AddBackward0>)
# 480 tensor(0.8991, grad_fn=<AddBackward0>)
# 490 tensor(0.9012, grad_fn=<AddBackward0>)
# 500 tensor(0.9014, grad_fn=<AddBackward0>)
# 510 tensor(0.8923, grad_fn=<AddBackward0>)
# 520 tensor(0.9054, grad_fn=<AddBackward0>)
# 530 tensor(0.8666, grad_fn=<AddBackward0>)
# 540 tensor(0.8808, grad_fn=<AddBackward0>)
# 550 tensor(0.9055, grad_fn=<AddBackward0>)
# 560 tensor(0.9320, grad_fn=<AddBackward0>)
# 570 tensor(0.8914, grad_fn=<AddBackward0>)
# 580 tensor(0.8916, grad_fn=<AddBackward0>)
# 590 tensor(0.9010, grad_fn=<AddBackward0>)
# 600 tensor(0.9067, grad_fn=<AddBackward0>)
# 610 tensor(0.9003, grad_fn=<AddBackward0>)
# 620 tensor(0.8963, grad_fn=<AddBackward0>)
# 630 tensor(0.8466, grad_fn=<AddBackward0>)
# 640 tensor(0.8919, grad_fn=<AddBackward0>)
# 650 tensor(0.8770, grad_fn=<AddBackward0>)
# 660 tensor(0.9064, grad_fn=<AddBackward0>)
# 670 tensor(0.9278, grad_fn=<AddBackward0>)
# 680 tensor(0.8923, grad_fn=<AddBackward0>)
# 690 tensor(0.9018, grad_fn=<AddBackward0>)
# 700 tensor(0.8722, grad_fn=<AddBackward0>)
# 710 tensor(0.9002, grad_fn=<AddBackward0>)
# 720 tensor(0.8922, grad_fn=<AddBackward0>)
# 730 tensor(0.8778, grad_fn=<AddBackward0>)
# 740 tensor(0.9235, grad_fn=<AddBackward0>)
# 750 tensor(0.8627, grad_fn=<AddBackward0>)
# 760 tensor(0.8918, grad_fn=<AddBackward0>)
# 770 tensor(0.8932, grad_fn=<AddBackward0>)
# 780 tensor(0.8833, grad_fn=<AddBackward0>)
# 790 tensor(0.8904, grad_fn=<AddBackward0>)
# 800 tensor(0.9013, grad_fn=<AddBackward0>)
# 810 tensor(0.8874, grad_fn=<AddBackward0>)
# 820 tensor(0.8975, grad_fn=<AddBackward0>)
# 830 tensor(0.9095, grad_fn=<AddBackward0>)
# 840 tensor(0.8819, grad_fn=<AddBackward0>)
# 850 tensor(0.9024, grad_fn=<AddBackward0>)
# 860 tensor(0.8592, grad_fn=<AddBackward0>)
# 870 tensor(0.9222, grad_fn=<AddBackward0>)
# 880 tensor(0.8842, grad_fn=<AddBackward0>)
# 890 tensor(0.9015, grad_fn=<AddBackward0>)
# 900 tensor(0.8950, grad_fn=<AddBackward0>)
# 910 tensor(0.8924, grad_fn=<AddBackward0>)
# 920 tensor(0.8367, grad_fn=<AddBackward0>)
# 930 tensor(0.9136, grad_fn=<AddBackward0>)
# 940 tensor(0.8785, grad_fn=<AddBackward0>)
# 950 tensor(0.8721, grad_fn=<AddBackward0>)
# 960 tensor(0.8766, grad_fn=<AddBackward0>)
# 970 tensor(0.8798, grad_fn=<AddBackward0>)
# 980 tensor(0.8881, grad_fn=<AddBackward0>)
# 990 tensor(0.8730, grad_fn=<AddBackward0>)
# 1000 tensor(0.8909, grad_fn=<AddBackward0>)
# 1010 tensor(0.9217, grad_fn=<AddBackward0>)
# 1020 tensor(0.8951, grad_fn=<AddBackward0>)
# 1030 tensor(0.8385, grad_fn=<AddBackward0>)
# 1040 tensor(0.9223, grad_fn=<AddBackward0>)
# 1050 tensor(0.8910, grad_fn=<AddBackward0>)
# 1060 tensor(0.8630, grad_fn=<AddBackward0>)
# 1070 tensor(0.9401, grad_fn=<AddBackward0>)
# 1080 tensor(0.8830, grad_fn=<AddBackward0>)
# 1090 tensor(0.9127, grad_fn=<AddBackward0>)
# 1100 tensor(0.8850, grad_fn=<AddBackward0>)
# 1110 tensor(0.8802, grad_fn=<AddBackward0>)
# 1120 tensor(0.8713, grad_fn=<AddBackward0>)
# 1130 tensor(0.9225, grad_fn=<AddBackward0>)
# 1140 tensor(0.8728, grad_fn=<AddBackward0>)
# 1150 tensor(0.8670, grad_fn=<AddBackward0>)
# 1160 tensor(0.9055, grad_fn=<AddBackward0>)
# 1170 tensor(0.8741, grad_fn=<AddBackward0>)
# 1180 tensor(0.8608, grad_fn=<AddBackward0>)
# 1190 tensor(0.8776, grad_fn=<AddBackward0>)
# 1200 tensor(0.8407, grad_fn=<AddBackward0>)
# 1210 tensor(0.8714, grad_fn=<AddBackward0>)
# 1220 tensor(0.9102, grad_fn=<AddBackward0>)
# 1230 tensor(0.9022, grad_fn=<AddBackward0>)
# 1240 tensor(0.8787, grad_fn=<AddBackward0>)
# 1250 tensor(0.8970, grad_fn=<AddBackward0>)
# 1260 tensor(0.9148, grad_fn=<AddBackward0>)
# 1270 tensor(0.8426, grad_fn=<AddBackward0>)
# 1280 tensor(0.8904, grad_fn=<AddBackward0>)
# 1290 tensor(0.9106, grad_fn=<AddBackward0>)
# 1300 tensor(0.8977, grad_fn=<AddBackward0>)
# 1310 tensor(0.8938, grad_fn=<AddBackward0>)
# 1320 tensor(0.9008, grad_fn=<AddBackward0>)
# 1330 tensor(0.8838, grad_fn=<AddBackward0>)
# 1340 tensor(0.9241, grad_fn=<AddBackward0>)
# 1350 tensor(0.8764, grad_fn=<AddBackward0>)
# 1360 tensor(0.8794, grad_fn=<AddBackward0>)
# 1370 tensor(0.9091, grad_fn=<AddBackward0>)
# 1380 tensor(0.8672, grad_fn=<AddBackward0>)
# 1390 tensor(0.9552, grad_fn=<AddBackward0>)
# 1400 tensor(0.9131, grad_fn=<AddBackward0>)
# 1410 tensor(0.9054, grad_fn=<AddBackward0>)
# 1420 tensor(0.8751, grad_fn=<AddBackward0>)
# 1430 tensor(0.9091, grad_fn=<AddBackward0>)
# 1440 tensor(0.8728, grad_fn=<AddBackward0>)
# 1450 tensor(0.9188, grad_fn=<AddBackward0>)
# 1460 tensor(0.8467, grad_fn=<AddBackward0>)
# 1470 tensor(0.8866, grad_fn=<AddBackward0>)
# 1480 tensor(0.8507, grad_fn=<AddBackward0>)
# 1490 tensor(0.8659, grad_fn=<AddBackward0>)
# 1500 tensor(0.9169, grad_fn=<AddBackward0>)
# 1510 tensor(0.8696, grad_fn=<AddBackward0>)
# 1520 tensor(0.8818, grad_fn=<AddBackward0>)
# 1530 tensor(0.9093, grad_fn=<AddBackward0>)
# 1540 tensor(0.9224, grad_fn=<AddBackward0>)
# 1550 tensor(0.8490, grad_fn=<AddBackward0>)
# 1560 tensor(0.8874, grad_fn=<AddBackward0>)
# 1570 tensor(0.9119, grad_fn=<AddBackward0>)
# 1580 tensor(0.8677, grad_fn=<AddBackward0>)
# 1590 tensor(0.8549, grad_fn=<AddBackward0>)
# 1600 tensor(0.9198, grad_fn=<AddBackward0>)
# 1610 tensor(0.9216, grad_fn=<AddBackward0>)
# 1620 tensor(0.8883, grad_fn=<AddBackward0>)
# 1630 tensor(0.9280, grad_fn=<AddBackward0>)
# 1640 tensor(0.9206, grad_fn=<AddBackward0>)
# 1650 tensor(0.8960, grad_fn=<AddBackward0>)
# 1660 tensor(0.8534, grad_fn=<AddBackward0>)
# 1670 tensor(0.8636, grad_fn=<AddBackward0>)
# 1680 tensor(0.8911, grad_fn=<AddBackward0>)
# 1690 tensor(0.8943, grad_fn=<AddBackward0>)
# 1700 tensor(0.9012, grad_fn=<AddBackward0>)
# 1710 tensor(0.9079, grad_fn=<AddBackward0>)
# 1720 tensor(0.8971, grad_fn=<AddBackward0>)
# 1730 tensor(0.9067, grad_fn=<AddBackward0>)
# 1740 tensor(0.8976, grad_fn=<AddBackward0>)
# 1750 tensor(0.8880, grad_fn=<AddBackward0>)
# 1760 tensor(0.8381, grad_fn=<AddBackward0>)
# 1770 tensor(0.9015, grad_fn=<AddBackward0>)
# 1780 tensor(0.8959, grad_fn=<AddBackward0>)
# 1790 tensor(0.9124, grad_fn=<AddBackward0>)
# 1800 tensor(0.8455, grad_fn=<AddBackward0>)
# 1810 tensor(0.9154, grad_fn=<AddBackward0>)
# 1820 tensor(0.8642, grad_fn=<AddBackward0>)
# 1830 tensor(0.9179, grad_fn=<AddBackward0>)
# 1840 tensor(0.9159, grad_fn=<AddBackward0>)
# 1850 tensor(0.9122, grad_fn=<AddBackward0>)
# 1860 tensor(0.8685, grad_fn=<AddBackward0>)
# 1870 tensor(0.8967, grad_fn=<AddBackward0>)
# 1880 tensor(0.9181, grad_fn=<AddBackward0>)
# 1890 tensor(0.8578, grad_fn=<AddBackward0>)
# 1900 tensor(0.9033, grad_fn=<AddBackward0>)
# 1910 tensor(0.8921, grad_fn=<AddBackward0>)
# 1920 tensor(0.8836, grad_fn=<AddBackward0>)
# 1930 tensor(0.8816, grad_fn=<AddBackward0>)
# 1940 tensor(0.8740, grad_fn=<AddBackward0>)
# 1950 tensor(0.8725, grad_fn=<AddBackward0>)
# 1960 tensor(0.8724, grad_fn=<AddBackward0>)
# 1970 tensor(0.9278, grad_fn=<AddBackward0>)
# 1980 tensor(0.8575, grad_fn=<AddBackward0>)
# 1990 tensor(0.8921, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 5 is bigger than 1.2617837 then go to left, else go to right
#     LEFT:
#     WHEN feature 4 is bigger than -118.98342 then go to left, else go to right
#         LEFT:
#         WHEN feature 2 is bigger than 0.867802 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 1 is bigger than 1.885812 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#     RIGHT:
#     WHEN feature 8 is bigger than 0.8373901 then go to left, else go to right
#         LEFT:
#         WHEN feature 0 is bigger than 4.4268017 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 1 is bigger than 20.34832 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.6176470588235294
# f1_score:
#  0.38181818181818183
# confusion_matrix:
#  [[42  0]
#  [26  0]]
# =============================================================
# (614, 9) (614, 1)
# (68, 9) (68, 1)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 256, 'focus_on_cont': True}
# Num Label: [397 217]
# Label Weight: [1.         1.82949309]
# 0 tensor(0.8700, grad_fn=<AddBackward0>)
# 10 tensor(0.8584, grad_fn=<AddBackward0>)
# 20 tensor(0.8873, grad_fn=<AddBackward0>)
# 30 tensor(0.8785, grad_fn=<AddBackward0>)
# 40 tensor(0.8811, grad_fn=<AddBackward0>)
# 50 tensor(0.8625, grad_fn=<AddBackward0>)
# 60 tensor(0.8987, grad_fn=<AddBackward0>)
# 70 tensor(0.8947, grad_fn=<AddBackward0>)
# 80 tensor(0.8805, grad_fn=<AddBackward0>)
# 90 tensor(0.8993, grad_fn=<AddBackward0>)
# 100 tensor(0.8879, grad_fn=<AddBackward0>)
# 110 tensor(0.8897, grad_fn=<AddBackward0>)
# 120 tensor(0.8709, grad_fn=<AddBackward0>)
# 130 tensor(0.8618, grad_fn=<AddBackward0>)
# 140 tensor(0.8875, grad_fn=<AddBackward0>)
# 150 tensor(0.8713, grad_fn=<AddBackward0>)
# 160 tensor(0.8962, grad_fn=<AddBackward0>)
# 170 tensor(0.8742, grad_fn=<AddBackward0>)
# 180 tensor(0.9248, grad_fn=<AddBackward0>)
# 190 tensor(0.8910, grad_fn=<AddBackward0>)
# 200 tensor(0.9036, grad_fn=<AddBackward0>)
# 210 tensor(0.8770, grad_fn=<AddBackward0>)
# 220 tensor(0.9099, grad_fn=<AddBackward0>)
# 230 tensor(0.9084, grad_fn=<AddBackward0>)
# 240 tensor(0.9159, grad_fn=<AddBackward0>)
# 250 tensor(0.8709, grad_fn=<AddBackward0>)
# 260 tensor(0.8836, grad_fn=<AddBackward0>)
# 270 tensor(0.9104, grad_fn=<AddBackward0>)
# 280 tensor(0.8942, grad_fn=<AddBackward0>)
# 290 tensor(0.8525, grad_fn=<AddBackward0>)
# 300 tensor(0.8614, grad_fn=<AddBackward0>)
# 310 tensor(0.8883, grad_fn=<AddBackward0>)
# 320 tensor(0.9001, grad_fn=<AddBackward0>)
# 330 tensor(0.8817, grad_fn=<AddBackward0>)
# 340 tensor(0.8763, grad_fn=<AddBackward0>)
# 350 tensor(0.8962, grad_fn=<AddBackward0>)
# 360 tensor(0.8924, grad_fn=<AddBackward0>)
# 370 tensor(0.8802, grad_fn=<AddBackward0>)
# 380 tensor(0.8617, grad_fn=<AddBackward0>)
# 390 tensor(0.8699, grad_fn=<AddBackward0>)
# 400 tensor(0.9001, grad_fn=<AddBackward0>)
# 410 tensor(0.9033, grad_fn=<AddBackward0>)
# 420 tensor(0.9029, grad_fn=<AddBackward0>)
# 430 tensor(0.8436, grad_fn=<AddBackward0>)
# 440 tensor(0.8862, grad_fn=<AddBackward0>)
# 450 tensor(0.9263, grad_fn=<AddBackward0>)
# 460 tensor(0.8952, grad_fn=<AddBackward0>)
# 470 tensor(0.8486, grad_fn=<AddBackward0>)
# 480 tensor(0.8727, grad_fn=<AddBackward0>)
# 490 tensor(0.8833, grad_fn=<AddBackward0>)
# 500 tensor(0.8633, grad_fn=<AddBackward0>)
# 510 tensor(0.9020, grad_fn=<AddBackward0>)
# 520 tensor(0.8898, grad_fn=<AddBackward0>)
# 530 tensor(0.8866, grad_fn=<AddBackward0>)
# 540 tensor(0.9005, grad_fn=<AddBackward0>)
# 550 tensor(0.9088, grad_fn=<AddBackward0>)
# 560 tensor(0.8393, grad_fn=<AddBackward0>)
# 570 tensor(0.9382, grad_fn=<AddBackward0>)
# 580 tensor(0.9158, grad_fn=<AddBackward0>)
# 590 tensor(0.8535, grad_fn=<AddBackward0>)
# 600 tensor(0.8353, grad_fn=<AddBackward0>)
# 610 tensor(0.9138, grad_fn=<AddBackward0>)
# 620 tensor(0.8957, grad_fn=<AddBackward0>)
# 630 tensor(0.8906, grad_fn=<AddBackward0>)
# 640 tensor(0.8684, grad_fn=<AddBackward0>)
# 650 tensor(0.9026, grad_fn=<AddBackward0>)
# 660 tensor(0.8642, grad_fn=<AddBackward0>)
# 670 tensor(0.8843, grad_fn=<AddBackward0>)
# 680 tensor(0.8324, grad_fn=<AddBackward0>)
# 690 tensor(0.8666, grad_fn=<AddBackward0>)
# 700 tensor(0.8949, grad_fn=<AddBackward0>)
# 710 tensor(0.8915, grad_fn=<AddBackward0>)
# 720 tensor(0.8726, grad_fn=<AddBackward0>)
# 730 tensor(0.8742, grad_fn=<AddBackward0>)
# 740 tensor(0.8884, grad_fn=<AddBackward0>)
# 750 tensor(0.8902, grad_fn=<AddBackward0>)
# 760 tensor(0.9189, grad_fn=<AddBackward0>)
# 770 tensor(0.8846, grad_fn=<AddBackward0>)
# 780 tensor(0.8835, grad_fn=<AddBackward0>)
# 790 tensor(0.8926, grad_fn=<AddBackward0>)
# 800 tensor(0.8949, grad_fn=<AddBackward0>)
# 810 tensor(0.8857, grad_fn=<AddBackward0>)
# 820 tensor(0.9012, grad_fn=<AddBackward0>)
# 830 tensor(0.8540, grad_fn=<AddBackward0>)
# 840 tensor(0.8803, grad_fn=<AddBackward0>)
# 850 tensor(0.8645, grad_fn=<AddBackward0>)
# 860 tensor(0.9253, grad_fn=<AddBackward0>)
# 870 tensor(0.8833, grad_fn=<AddBackward0>)
# 880 tensor(0.8687, grad_fn=<AddBackward0>)
# 890 tensor(0.8522, grad_fn=<AddBackward0>)
# 900 tensor(0.8815, grad_fn=<AddBackward0>)
# 910 tensor(0.8778, grad_fn=<AddBackward0>)
# 920 tensor(0.8807, grad_fn=<AddBackward0>)
# 930 tensor(0.9121, grad_fn=<AddBackward0>)
# 940 tensor(0.8694, grad_fn=<AddBackward0>)
# 950 tensor(0.9131, grad_fn=<AddBackward0>)
# 960 tensor(0.8759, grad_fn=<AddBackward0>)
# 970 tensor(0.8586, grad_fn=<AddBackward0>)
# 980 tensor(0.8591, grad_fn=<AddBackward0>)
# 990 tensor(0.8987, grad_fn=<AddBackward0>)
# 1000 tensor(0.8917, grad_fn=<AddBackward0>)
# 1010 tensor(0.8962, grad_fn=<AddBackward0>)
# 1020 tensor(0.9053, grad_fn=<AddBackward0>)
# 1030 tensor(0.8881, grad_fn=<AddBackward0>)
# 1040 tensor(0.9066, grad_fn=<AddBackward0>)
# 1050 tensor(0.8929, grad_fn=<AddBackward0>)
# 1060 tensor(0.9054, grad_fn=<AddBackward0>)
# 1070 tensor(0.8924, grad_fn=<AddBackward0>)
# 1080 tensor(0.8945, grad_fn=<AddBackward0>)
# 1090 tensor(0.8788, grad_fn=<AddBackward0>)
# 1100 tensor(0.8459, grad_fn=<AddBackward0>)
# 1110 tensor(0.8749, grad_fn=<AddBackward0>)
# 1120 tensor(0.8705, grad_fn=<AddBackward0>)
# 1130 tensor(0.8688, grad_fn=<AddBackward0>)
# 1140 tensor(0.8871, grad_fn=<AddBackward0>)
# 1150 tensor(0.9099, grad_fn=<AddBackward0>)
# 1160 tensor(0.8552, grad_fn=<AddBackward0>)
# 1170 tensor(0.9337, grad_fn=<AddBackward0>)
# 1180 tensor(0.9047, grad_fn=<AddBackward0>)
# 1190 tensor(0.9041, grad_fn=<AddBackward0>)
# 1200 tensor(0.8941, grad_fn=<AddBackward0>)
# 1210 tensor(0.8955, grad_fn=<AddBackward0>)
# 1220 tensor(0.8828, grad_fn=<AddBackward0>)
# 1230 tensor(0.9078, grad_fn=<AddBackward0>)
# 1240 tensor(0.8933, grad_fn=<AddBackward0>)
# 1250 tensor(0.9013, grad_fn=<AddBackward0>)
# 1260 tensor(0.8959, grad_fn=<AddBackward0>)
# 1270 tensor(0.8779, grad_fn=<AddBackward0>)
# 1280 tensor(0.8700, grad_fn=<AddBackward0>)
# 1290 tensor(0.8890, grad_fn=<AddBackward0>)
# 1300 tensor(0.8749, grad_fn=<AddBackward0>)
# 1310 tensor(0.9154, grad_fn=<AddBackward0>)
# 1320 tensor(0.9045, grad_fn=<AddBackward0>)
# 1330 tensor(0.8539, grad_fn=<AddBackward0>)
# 1340 tensor(0.8941, grad_fn=<AddBackward0>)
# 1350 tensor(0.8867, grad_fn=<AddBackward0>)
# 1360 tensor(0.8744, grad_fn=<AddBackward0>)
# 1370 tensor(0.8898, grad_fn=<AddBackward0>)
# 1380 tensor(0.8651, grad_fn=<AddBackward0>)
# 1390 tensor(0.8442, grad_fn=<AddBackward0>)
# 1400 tensor(0.8729, grad_fn=<AddBackward0>)
# 1410 tensor(0.9239, grad_fn=<AddBackward0>)
# 1420 tensor(0.9125, grad_fn=<AddBackward0>)
# 1430 tensor(0.8726, grad_fn=<AddBackward0>)
# 1440 tensor(0.8897, grad_fn=<AddBackward0>)
# 1450 tensor(0.8683, grad_fn=<AddBackward0>)
# 1460 tensor(0.8939, grad_fn=<AddBackward0>)
# 1470 tensor(0.8773, grad_fn=<AddBackward0>)
# 1480 tensor(0.9216, grad_fn=<AddBackward0>)
# 1490 tensor(0.9272, grad_fn=<AddBackward0>)
# 1500 tensor(0.8899, grad_fn=<AddBackward0>)
# 1510 tensor(0.8750, grad_fn=<AddBackward0>)
# 1520 tensor(0.8881, grad_fn=<AddBackward0>)
# 1530 tensor(0.8805, grad_fn=<AddBackward0>)
# 1540 tensor(0.8803, grad_fn=<AddBackward0>)
# 1550 tensor(0.8772, grad_fn=<AddBackward0>)
# 1560 tensor(0.8779, grad_fn=<AddBackward0>)
# 1570 tensor(0.9384, grad_fn=<AddBackward0>)
# 1580 tensor(0.8874, grad_fn=<AddBackward0>)
# 1590 tensor(0.8965, grad_fn=<AddBackward0>)
# 1600 tensor(0.8545, grad_fn=<AddBackward0>)
# 1610 tensor(0.8872, grad_fn=<AddBackward0>)
# 1620 tensor(0.8941, grad_fn=<AddBackward0>)
# 1630 tensor(0.8492, grad_fn=<AddBackward0>)
# 1640 tensor(0.9029, grad_fn=<AddBackward0>)
# 1650 tensor(0.8927, grad_fn=<AddBackward0>)
# 1660 tensor(0.8911, grad_fn=<AddBackward0>)
# 1670 tensor(0.8642, grad_fn=<AddBackward0>)
# 1680 tensor(0.8434, grad_fn=<AddBackward0>)
# 1690 tensor(0.9111, grad_fn=<AddBackward0>)
# 1700 tensor(0.8728, grad_fn=<AddBackward0>)
# 1710 tensor(0.8832, grad_fn=<AddBackward0>)
# 1720 tensor(0.8787, grad_fn=<AddBackward0>)
# 1730 tensor(0.8844, grad_fn=<AddBackward0>)
# 1740 tensor(0.8725, grad_fn=<AddBackward0>)
# 1750 tensor(0.8842, grad_fn=<AddBackward0>)
# 1760 tensor(0.9090, grad_fn=<AddBackward0>)
# 1770 tensor(0.8719, grad_fn=<AddBackward0>)
# 1780 tensor(0.8641, grad_fn=<AddBackward0>)
# 1790 tensor(0.8587, grad_fn=<AddBackward0>)
# 1800 tensor(0.8569, grad_fn=<AddBackward0>)
# 1810 tensor(0.9180, grad_fn=<AddBackward0>)
# 1820 tensor(0.8456, grad_fn=<AddBackward0>)
# 1830 tensor(0.8501, grad_fn=<AddBackward0>)
# 1840 tensor(0.8694, grad_fn=<AddBackward0>)
# 1850 tensor(0.8750, grad_fn=<AddBackward0>)
# 1860 tensor(0.8819, grad_fn=<AddBackward0>)
# 1870 tensor(0.8593, grad_fn=<AddBackward0>)
# 1880 tensor(0.8565, grad_fn=<AddBackward0>)
# 1890 tensor(0.9023, grad_fn=<AddBackward0>)
# 1900 tensor(0.8690, grad_fn=<AddBackward0>)
# 1910 tensor(0.8919, grad_fn=<AddBackward0>)
# 1920 tensor(0.8840, grad_fn=<AddBackward0>)
# 1930 tensor(0.8453, grad_fn=<AddBackward0>)
# 1940 tensor(0.9371, grad_fn=<AddBackward0>)
# 1950 tensor(0.9167, grad_fn=<AddBackward0>)
# 1960 tensor(0.8817, grad_fn=<AddBackward0>)
# 1970 tensor(0.9013, grad_fn=<AddBackward0>)
# 1980 tensor(0.9001, grad_fn=<AddBackward0>)
# 1990 tensor(0.8992, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 3 is bigger than -6.751227 then go to left, else go to right
#     LEFT:
#     WHEN feature 5 is bigger than 0.604125 then go to left, else go to right
#         LEFT:
#         WHEN feature 2 is bigger than -0.6324386 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 1 is bigger than 0.24385917 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#     RIGHT:
#     WHEN feature 4 is bigger than 0.7873276 then go to left, else go to right
#         LEFT:
#         WHEN feature 4 is bigger than -1.5679756 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 3 is bigger than 29.17283 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.6764705882352942
# f1_score:
#  0.40350877192982454
# confusion_matrix:
#  [[46  0]
#  [22  0]]
# =============================================================
# (614, 9) (614, 1)
# (68, 9) (68, 1)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 256, 'focus_on_cont': True}
# Num Label: [402 212]
# Label Weight: [1.         1.89622642]
# 0 tensor(0.8977, grad_fn=<AddBackward0>)
# 10 tensor(0.9229, grad_fn=<AddBackward0>)
# 20 tensor(0.9171, grad_fn=<AddBackward0>)
# 30 tensor(0.9155, grad_fn=<AddBackward0>)
# 40 tensor(0.8974, grad_fn=<AddBackward0>)
# 50 tensor(0.8806, grad_fn=<AddBackward0>)
# 60 tensor(0.8922, grad_fn=<AddBackward0>)
# 70 tensor(0.8996, grad_fn=<AddBackward0>)
# 80 tensor(0.8880, grad_fn=<AddBackward0>)
# 90 tensor(0.8811, grad_fn=<AddBackward0>)
# 100 tensor(0.8881, grad_fn=<AddBackward0>)
# 110 tensor(0.8701, grad_fn=<AddBackward0>)
# 120 tensor(0.8915, grad_fn=<AddBackward0>)
# 130 tensor(0.8742, grad_fn=<AddBackward0>)
# 140 tensor(0.8801, grad_fn=<AddBackward0>)
# 150 tensor(0.8737, grad_fn=<AddBackward0>)
# 160 tensor(0.8969, grad_fn=<AddBackward0>)
# 170 tensor(0.8829, grad_fn=<AddBackward0>)
# 180 tensor(0.8840, grad_fn=<AddBackward0>)
# 190 tensor(0.8465, grad_fn=<AddBackward0>)
# 200 tensor(0.9199, grad_fn=<AddBackward0>)
# 210 tensor(0.8983, grad_fn=<AddBackward0>)
# 220 tensor(0.8613, grad_fn=<AddBackward0>)
# 230 tensor(0.8618, grad_fn=<AddBackward0>)
# 240 tensor(0.8661, grad_fn=<AddBackward0>)
# 250 tensor(0.8723, grad_fn=<AddBackward0>)
# 260 tensor(0.9125, grad_fn=<AddBackward0>)
# 270 tensor(0.8699, grad_fn=<AddBackward0>)
# 280 tensor(0.8409, grad_fn=<AddBackward0>)
# 290 tensor(0.8866, grad_fn=<AddBackward0>)
# 300 tensor(0.8749, grad_fn=<AddBackward0>)
# 310 tensor(0.8748, grad_fn=<AddBackward0>)
# 320 tensor(0.8897, grad_fn=<AddBackward0>)
# 330 tensor(0.9016, grad_fn=<AddBackward0>)
# 340 tensor(0.8390, grad_fn=<AddBackward0>)
# 350 tensor(0.8857, grad_fn=<AddBackward0>)
# 360 tensor(0.9227, grad_fn=<AddBackward0>)
# 370 tensor(0.9158, grad_fn=<AddBackward0>)
# 380 tensor(0.9170, grad_fn=<AddBackward0>)
# 390 tensor(0.8945, grad_fn=<AddBackward0>)
# 400 tensor(0.8816, grad_fn=<AddBackward0>)
# 410 tensor(0.8918, grad_fn=<AddBackward0>)
# 420 tensor(0.8973, grad_fn=<AddBackward0>)
# 430 tensor(0.8700, grad_fn=<AddBackward0>)
# 440 tensor(0.9031, grad_fn=<AddBackward0>)
# 450 tensor(0.8528, grad_fn=<AddBackward0>)
# 460 tensor(0.9067, grad_fn=<AddBackward0>)
# 470 tensor(0.9083, grad_fn=<AddBackward0>)
# 480 tensor(0.9127, grad_fn=<AddBackward0>)
# 490 tensor(0.9373, grad_fn=<AddBackward0>)
# 500 tensor(0.8843, grad_fn=<AddBackward0>)
# 510 tensor(0.8722, grad_fn=<AddBackward0>)
# 520 tensor(0.8342, grad_fn=<AddBackward0>)
# 530 tensor(0.9078, grad_fn=<AddBackward0>)
# 540 tensor(0.8601, grad_fn=<AddBackward0>)
# 550 tensor(0.9051, grad_fn=<AddBackward0>)
# 560 tensor(0.9135, grad_fn=<AddBackward0>)
# 570 tensor(0.8964, grad_fn=<AddBackward0>)
# 580 tensor(0.8869, grad_fn=<AddBackward0>)
# 590 tensor(0.8845, grad_fn=<AddBackward0>)
# 600 tensor(0.8709, grad_fn=<AddBackward0>)
# 610 tensor(0.8242, grad_fn=<AddBackward0>)
# 620 tensor(0.8991, grad_fn=<AddBackward0>)
# 630 tensor(0.9350, grad_fn=<AddBackward0>)
# 640 tensor(0.8862, grad_fn=<AddBackward0>)
# 650 tensor(0.9243, grad_fn=<AddBackward0>)
# 660 tensor(0.9083, grad_fn=<AddBackward0>)
# 670 tensor(0.9035, grad_fn=<AddBackward0>)
# 680 tensor(0.9140, grad_fn=<AddBackward0>)
# 690 tensor(0.8520, grad_fn=<AddBackward0>)
# 700 tensor(0.9155, grad_fn=<AddBackward0>)
# 710 tensor(0.8898, grad_fn=<AddBackward0>)
# 720 tensor(0.9054, grad_fn=<AddBackward0>)
# 730 tensor(0.8503, grad_fn=<AddBackward0>)
# 740 tensor(0.8768, grad_fn=<AddBackward0>)
# 750 tensor(0.8900, grad_fn=<AddBackward0>)
# 760 tensor(0.9063, grad_fn=<AddBackward0>)
# 770 tensor(0.9323, grad_fn=<AddBackward0>)
# 780 tensor(0.8984, grad_fn=<AddBackward0>)
# 790 tensor(0.8578, grad_fn=<AddBackward0>)
# 800 tensor(0.9005, grad_fn=<AddBackward0>)
# 810 tensor(0.9022, grad_fn=<AddBackward0>)
# 820 tensor(0.8635, grad_fn=<AddBackward0>)
# 830 tensor(0.8838, grad_fn=<AddBackward0>)
# 840 tensor(0.8758, grad_fn=<AddBackward0>)
# 850 tensor(0.8907, grad_fn=<AddBackward0>)
# 860 tensor(0.8818, grad_fn=<AddBackward0>)
# 870 tensor(0.8939, grad_fn=<AddBackward0>)
# 880 tensor(0.8743, grad_fn=<AddBackward0>)
# 890 tensor(0.9446, grad_fn=<AddBackward0>)
# 900 tensor(0.8363, grad_fn=<AddBackward0>)
# 910 tensor(0.9016, grad_fn=<AddBackward0>)
# 920 tensor(0.8805, grad_fn=<AddBackward0>)
# 930 tensor(0.9064, grad_fn=<AddBackward0>)
# 940 tensor(0.9046, grad_fn=<AddBackward0>)
# 950 tensor(0.8671, grad_fn=<AddBackward0>)
# 960 tensor(0.9001, grad_fn=<AddBackward0>)
# 970 tensor(0.8864, grad_fn=<AddBackward0>)
# 980 tensor(0.9189, grad_fn=<AddBackward0>)
# 990 tensor(0.8972, grad_fn=<AddBackward0>)
# 1000 tensor(0.8585, grad_fn=<AddBackward0>)
# 1010 tensor(0.8427, grad_fn=<AddBackward0>)
# 1020 tensor(0.8879, grad_fn=<AddBackward0>)
# 1030 tensor(0.8955, grad_fn=<AddBackward0>)
# 1040 tensor(0.8847, grad_fn=<AddBackward0>)
# 1050 tensor(0.8978, grad_fn=<AddBackward0>)
# 1060 tensor(0.9064, grad_fn=<AddBackward0>)
# 1070 tensor(0.8982, grad_fn=<AddBackward0>)
# 1080 tensor(0.8583, grad_fn=<AddBackward0>)
# 1090 tensor(0.8510, grad_fn=<AddBackward0>)
# 1100 tensor(0.8592, grad_fn=<AddBackward0>)
# 1110 tensor(0.8860, grad_fn=<AddBackward0>)
# 1120 tensor(0.9051, grad_fn=<AddBackward0>)
# 1130 tensor(0.9152, grad_fn=<AddBackward0>)
# 1140 tensor(0.9037, grad_fn=<AddBackward0>)
# 1150 tensor(0.9231, grad_fn=<AddBackward0>)
# 1160 tensor(0.8904, grad_fn=<AddBackward0>)
# 1170 tensor(0.9196, grad_fn=<AddBackward0>)
# 1180 tensor(0.9113, grad_fn=<AddBackward0>)
# 1190 tensor(0.9350, grad_fn=<AddBackward0>)
# 1200 tensor(0.9398, grad_fn=<AddBackward0>)
# 1210 tensor(0.9008, grad_fn=<AddBackward0>)
# 1220 tensor(0.9141, grad_fn=<AddBackward0>)
# 1230 tensor(0.8818, grad_fn=<AddBackward0>)
# 1240 tensor(0.8615, grad_fn=<AddBackward0>)
# 1250 tensor(0.8758, grad_fn=<AddBackward0>)
# 1260 tensor(0.9017, grad_fn=<AddBackward0>)
# 1270 tensor(0.8938, grad_fn=<AddBackward0>)
# 1280 tensor(0.9102, grad_fn=<AddBackward0>)
# 1290 tensor(0.9163, grad_fn=<AddBackward0>)
# 1300 tensor(0.9160, grad_fn=<AddBackward0>)
# ...
# 980 tensor(0.8696, grad_fn=<AddBackward0>)
# 990 tensor(0.9239, grad_fn=<AddBackward0>)
# 1000 tensor(0.8599, grad_fn=<AddBackward0>)
# 1010 tensor(0.8994, grad_fn=<AddBackward0>)
# 1020 tensor(0.8918, grad_fn=<AddBackward0>)
# 1030 tensor(0.8780, grad_fn=<AddBackward0>)
# 1040 tensor(0.8807, grad_fn=<AddBackward0>)
# 1050 tensor(0.8913, grad_fn=<AddBackward0>)
# 1060 tensor(0.8674, grad_fn=<AddBackward0>)
# 1070 tensor(0.9124, grad_fn=<AddBackward0>)
# 1080 tensor(0.8612, grad_fn=<AddBackward0>)
# 1090 tensor(0.8754, grad_fn=<AddBackward0>)
# 1100 tensor(0.9230, grad_fn=<AddBackward0>)
# 1110 tensor(0.8816, grad_fn=<AddBackward0>)
# 1120 tensor(0.8892, grad_fn=<AddBackward0>)
# 1130 tensor(0.8805, grad_fn=<AddBackward0>)
# 1140 tensor(0.8744, grad_fn=<AddBackward0>)
# 1150 tensor(0.8738, grad_fn=<AddBackward0>)
# 1160 tensor(0.8892, grad_fn=<AddBackward0>)
# 1170 tensor(0.8986, grad_fn=<AddBackward0>)
# 1180 tensor(0.8971, grad_fn=<AddBackward0>)
# 1190 tensor(0.9070, grad_fn=<AddBackward0>)
# 1200 tensor(0.8859, grad_fn=<AddBackward0>)
# 1210 tensor(0.8493, grad_fn=<AddBackward0>)
# 1220 tensor(0.8925, grad_fn=<AddBackward0>)
# 1230 tensor(0.8918, grad_fn=<AddBackward0>)
# 1240 tensor(0.8942, grad_fn=<AddBackward0>)
# 1250 tensor(0.8441, grad_fn=<AddBackward0>)
# 1260 tensor(0.9020, grad_fn=<AddBackward0>)
# 1270 tensor(0.9123, grad_fn=<AddBackward0>)
# 1280 tensor(0.9212, grad_fn=<AddBackward0>)
# 1290 tensor(0.8855, grad_fn=<AddBackward0>)
# 1300 tensor(0.8922, grad_fn=<AddBackward0>)
# 1310 tensor(0.9233, grad_fn=<AddBackward0>)
# 1320 tensor(0.8759, grad_fn=<AddBackward0>)
# 1330 tensor(0.9074, grad_fn=<AddBackward0>)
# 1340 tensor(0.8930, grad_fn=<AddBackward0>)
# 1350 tensor(0.8673, grad_fn=<AddBackward0>)
# 1360 tensor(0.8875, grad_fn=<AddBackward0>)
# 1370 tensor(0.8981, grad_fn=<AddBackward0>)
# 1380 tensor(0.8545, grad_fn=<AddBackward0>)
# 1390 tensor(0.8576, grad_fn=<AddBackward0>)
# 1400 tensor(0.8769, grad_fn=<AddBackward0>)
# 1410 tensor(0.8683, grad_fn=<AddBackward0>)
# 1420 tensor(0.8170, grad_fn=<AddBackward0>)
# 1430 tensor(0.8922, grad_fn=<AddBackward0>)
# 1440 tensor(0.9338, grad_fn=<AddBackward0>)
# 1450 tensor(0.9000, grad_fn=<AddBackward0>)
# 1460 tensor(0.8931, grad_fn=<AddBackward0>)
# 1470 tensor(0.9043, grad_fn=<AddBackward0>)
# 1480 tensor(0.9030, grad_fn=<AddBackward0>)
# 1490 tensor(0.8842, grad_fn=<AddBackward0>)
# 1500 tensor(0.8696, grad_fn=<AddBackward0>)
# 1510 tensor(0.9028, grad_fn=<AddBackward0>)
# 1520 tensor(0.8968, grad_fn=<AddBackward0>)
# 1530 tensor(0.8778, grad_fn=<AddBackward0>)
# 1540 tensor(0.8736, grad_fn=<AddBackward0>)
# 1550 tensor(0.8933, grad_fn=<AddBackward0>)
# 1560 tensor(0.8711, grad_fn=<AddBackward0>)
# 1570 tensor(0.9281, grad_fn=<AddBackward0>)
# 1580 tensor(0.8917, grad_fn=<AddBackward0>)
# 1590 tensor(0.8906, grad_fn=<AddBackward0>)
# 1600 tensor(0.9061, grad_fn=<AddBackward0>)
# 1610 tensor(0.8835, grad_fn=<AddBackward0>)
# 1620 tensor(0.8834, grad_fn=<AddBackward0>)
# 1630 tensor(0.8994, grad_fn=<AddBackward0>)
# 1640 tensor(0.9062, grad_fn=<AddBackward0>)
# 1650 tensor(0.8735, grad_fn=<AddBackward0>)
# 1660 tensor(0.8668, grad_fn=<AddBackward0>)
# 1670 tensor(0.8900, grad_fn=<AddBackward0>)
# 1680 tensor(0.8837, grad_fn=<AddBackward0>)
# 1690 tensor(0.8953, grad_fn=<AddBackward0>)
# 1700 tensor(0.8714, grad_fn=<AddBackward0>)
# 1710 tensor(0.8969, grad_fn=<AddBackward0>)
# 1720 tensor(0.8995, grad_fn=<AddBackward0>)
# 1730 tensor(0.8420, grad_fn=<AddBackward0>)
# 1740 tensor(0.9134, grad_fn=<AddBackward0>)
# 1750 tensor(0.8903, grad_fn=<AddBackward0>)
# 1760 tensor(0.8555, grad_fn=<AddBackward0>)
# 1770 tensor(0.8699, grad_fn=<AddBackward0>)
# 1780 tensor(0.8517, grad_fn=<AddBackward0>)
# 1790 tensor(0.8624, grad_fn=<AddBackward0>)
# 1800 tensor(0.9204, grad_fn=<AddBackward0>)
# 1810 tensor(0.8873, grad_fn=<AddBackward0>)
# 1820 tensor(0.8688, grad_fn=<AddBackward0>)
# 1830 tensor(0.8709, grad_fn=<AddBackward0>)
# 1840 tensor(0.9075, grad_fn=<AddBackward0>)
# 1850 tensor(0.9000, grad_fn=<AddBackward0>)
# 1860 tensor(0.8840, grad_fn=<AddBackward0>)
# 1870 tensor(0.8706, grad_fn=<AddBackward0>)
# 1880 tensor(0.9045, grad_fn=<AddBackward0>)
# 1890 tensor(0.8919, grad_fn=<AddBackward0>)
# 1900 tensor(0.8864, grad_fn=<AddBackward0>)
# 1910 tensor(0.8921, grad_fn=<AddBackward0>)
# 1920 tensor(0.8945, grad_fn=<AddBackward0>)
# 1930 tensor(0.8817, grad_fn=<AddBackward0>)
# 1940 tensor(0.8991, grad_fn=<AddBackward0>)
# 1950 tensor(0.9023, grad_fn=<AddBackward0>)
# 1960 tensor(0.9064, grad_fn=<AddBackward0>)
# 1970 tensor(0.8790, grad_fn=<AddBackward0>)
# 1980 tensor(0.8713, grad_fn=<AddBackward0>)
# 1990 tensor(0.8916, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 8 is bigger than -0.3921444 then go to left, else go to right
#     LEFT:
#     WHEN feature 5 is bigger than 0.73442686 then go to left, else go to right
#         LEFT:
#         WHEN feature 2 is bigger than -41.28464 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 5 is bigger than -0.28920245 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#     RIGHT:
#     WHEN feature 0 is bigger than 3.1053593 then go to left, else go to right
#         LEFT:
#         WHEN feature 1 is bigger than -0.68383116 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 0 is bigger than 0.6875143 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.6911764705882353
# f1_score:
#  0.40869565217391307
# confusion_matrix:
#  [[47  0]
#  [21  0]]
# =============================================================
# (614, 9) (614, 1)
# (68, 9) (68, 1)
# Node(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
# )
# =============================================================
# {'batch_size': 256, 'focus_on_cont': True}
# Num Label: [396 218]
# Label Weight: [1.         1.81651376]
# 0 tensor(0.8904, grad_fn=<AddBackward0>)
# 10 tensor(0.8899, grad_fn=<AddBackward0>)
# 20 tensor(0.8737, grad_fn=<AddBackward0>)
# 30 tensor(0.8487, grad_fn=<AddBackward0>)
# 40 tensor(0.8766, grad_fn=<AddBackward0>)
# 50 tensor(0.8887, grad_fn=<AddBackward0>)
# 60 tensor(0.8986, grad_fn=<AddBackward0>)
# 70 tensor(0.8754, grad_fn=<AddBackward0>)
# 80 tensor(0.9443, grad_fn=<AddBackward0>)
# 90 tensor(0.8846, grad_fn=<AddBackward0>)
# 100 tensor(0.8931, grad_fn=<AddBackward0>)
# 110 tensor(0.8594, grad_fn=<AddBackward0>)
# 120 tensor(0.8916, grad_fn=<AddBackward0>)
# 130 tensor(0.8721, grad_fn=<AddBackward0>)
# 140 tensor(0.8918, grad_fn=<AddBackward0>)
# 150 tensor(0.9055, grad_fn=<AddBackward0>)
# 160 tensor(0.8735, grad_fn=<AddBackward0>)
# 170 tensor(0.8784, grad_fn=<AddBackward0>)
# 180 tensor(0.8776, grad_fn=<AddBackward0>)
# 190 tensor(0.8976, grad_fn=<AddBackward0>)
# 200 tensor(0.9012, grad_fn=<AddBackward0>)
# 210 tensor(0.9043, grad_fn=<AddBackward0>)
# 220 tensor(0.8910, grad_fn=<AddBackward0>)
# 230 tensor(0.8980, grad_fn=<AddBackward0>)
# 240 tensor(0.8701, grad_fn=<AddBackward0>)
# 250 tensor(0.8671, grad_fn=<AddBackward0>)
# 260 tensor(0.8355, grad_fn=<AddBackward0>)
# 270 tensor(0.8776, grad_fn=<AddBackward0>)
# 280 tensor(0.8758, grad_fn=<AddBackward0>)
# 290 tensor(0.8941, grad_fn=<AddBackward0>)
# 300 tensor(0.8850, grad_fn=<AddBackward0>)
# 310 tensor(0.8469, grad_fn=<AddBackward0>)
# 320 tensor(0.8639, grad_fn=<AddBackward0>)
# 330 tensor(0.8901, grad_fn=<AddBackward0>)
# 340 tensor(0.8859, grad_fn=<AddBackward0>)
# 350 tensor(0.8956, grad_fn=<AddBackward0>)
# 360 tensor(0.8615, grad_fn=<AddBackward0>)
# 370 tensor(0.8957, grad_fn=<AddBackward0>)
# 380 tensor(0.8729, grad_fn=<AddBackward0>)
# 390 tensor(0.8977, grad_fn=<AddBackward0>)
# 400 tensor(0.8783, grad_fn=<AddBackward0>)
# 410 tensor(0.9055, grad_fn=<AddBackward0>)
# 420 tensor(0.8562, grad_fn=<AddBackward0>)
# 430 tensor(0.9047, grad_fn=<AddBackward0>)
# 440 tensor(0.8632, grad_fn=<AddBackward0>)
# 450 tensor(0.8843, grad_fn=<AddBackward0>)
# 460 tensor(0.9015, grad_fn=<AddBackward0>)
# 470 tensor(0.8164, grad_fn=<AddBackward0>)
# 480 tensor(0.8935, grad_fn=<AddBackward0>)
# 490 tensor(0.8753, grad_fn=<AddBackward0>)
# 500 tensor(0.8872, grad_fn=<AddBackward0>)
# 510 tensor(0.8951, grad_fn=<AddBackward0>)
# 520 tensor(0.8698, grad_fn=<AddBackward0>)
# 530 tensor(0.9134, grad_fn=<AddBackward0>)
# 540 tensor(0.8802, grad_fn=<AddBackward0>)
# 550 tensor(0.8895, grad_fn=<AddBackward0>)
# 560 tensor(0.8941, grad_fn=<AddBackward0>)
# 570 tensor(0.8883, grad_fn=<AddBackward0>)
# 580 tensor(0.8575, grad_fn=<AddBackward0>)
# 590 tensor(0.8667, grad_fn=<AddBackward0>)
# 600 tensor(0.8664, grad_fn=<AddBackward0>)
# 610 tensor(0.8966, grad_fn=<AddBackward0>)
# 620 tensor(0.8836, grad_fn=<AddBackward0>)
# 630 tensor(0.8528, grad_fn=<AddBackward0>)
# 640 tensor(0.8629, grad_fn=<AddBackward0>)
# 650 tensor(0.8906, grad_fn=<AddBackward0>)
# 660 tensor(0.8707, grad_fn=<AddBackward0>)
# 670 tensor(0.8999, grad_fn=<AddBackward0>)
# 680 tensor(0.8967, grad_fn=<AddBackward0>)
# 690 tensor(0.8582, grad_fn=<AddBackward0>)
# 700 tensor(0.9156, grad_fn=<AddBackward0>)
# 710 tensor(0.9034, grad_fn=<AddBackward0>)
# 720 tensor(0.9075, grad_fn=<AddBackward0>)
# 730 tensor(0.8842, grad_fn=<AddBackward0>)
# 740 tensor(0.8452, grad_fn=<AddBackward0>)
# 750 tensor(0.9129, grad_fn=<AddBackward0>)
# 760 tensor(0.8850, grad_fn=<AddBackward0>)
# 770 tensor(0.8551, grad_fn=<AddBackward0>)
# 780 tensor(0.9072, grad_fn=<AddBackward0>)
# 790 tensor(0.8453, grad_fn=<AddBackward0>)
# 800 tensor(0.8861, grad_fn=<AddBackward0>)
# 810 tensor(0.8854, grad_fn=<AddBackward0>)
# 820 tensor(0.8501, grad_fn=<AddBackward0>)
# 830 tensor(0.8534, grad_fn=<AddBackward0>)
# 840 tensor(0.9216, grad_fn=<AddBackward0>)
# 850 tensor(0.8447, grad_fn=<AddBackward0>)
# 860 tensor(0.8735, grad_fn=<AddBackward0>)
# 870 tensor(0.8714, grad_fn=<AddBackward0>)
# 880 tensor(0.8629, grad_fn=<AddBackward0>)
# 890 tensor(0.8472, grad_fn=<AddBackward0>)
# 900 tensor(0.8885, grad_fn=<AddBackward0>)
# 910 tensor(0.8744, grad_fn=<AddBackward0>)
# 920 tensor(0.8715, grad_fn=<AddBackward0>)
# 930 tensor(0.8571, grad_fn=<AddBackward0>)
# 940 tensor(0.8760, grad_fn=<AddBackward0>)
# 950 tensor(0.8771, grad_fn=<AddBackward0>)
# 960 tensor(0.8511, grad_fn=<AddBackward0>)
# 970 tensor(0.8995, grad_fn=<AddBackward0>)
# 980 tensor(0.8673, grad_fn=<AddBackward0>)
# 990 tensor(0.8431, grad_fn=<AddBackward0>)
# 1000 tensor(0.9036, grad_fn=<AddBackward0>)
# 1010 tensor(0.9147, grad_fn=<AddBackward0>)
# 1020 tensor(0.8571, grad_fn=<AddBackward0>)
# 1030 tensor(0.8657, grad_fn=<AddBackward0>)
# 1040 tensor(0.8877, grad_fn=<AddBackward0>)
# 1050 tensor(0.8575, grad_fn=<AddBackward0>)
# 1060 tensor(0.8232, grad_fn=<AddBackward0>)
# 1070 tensor(0.9133, grad_fn=<AddBackward0>)
# 1080 tensor(0.8976, grad_fn=<AddBackward0>)
# 1090 tensor(0.8391, grad_fn=<AddBackward0>)
# 1100 tensor(0.8758, grad_fn=<AddBackward0>)
# 1110 tensor(0.8706, grad_fn=<AddBackward0>)
# 1120 tensor(0.8544, grad_fn=<AddBackward0>)
# 1130 tensor(0.9007, grad_fn=<AddBackward0>)
# 1140 tensor(0.8744, grad_fn=<AddBackward0>)
# 1150 tensor(0.8796, grad_fn=<AddBackward0>)
# 1160 tensor(0.8525, grad_fn=<AddBackward0>)
# 1170 tensor(0.8544, grad_fn=<AddBackward0>)
# 1180 tensor(0.8539, grad_fn=<AddBackward0>)
# 1190 tensor(0.8796, grad_fn=<AddBackward0>)
# 1200 tensor(0.8900, grad_fn=<AddBackward0>)
# 1210 tensor(0.8730, grad_fn=<AddBackward0>)
# 1220 tensor(0.8990, grad_fn=<AddBackward0>)
# 1230 tensor(0.8864, grad_fn=<AddBackward0>)
# 1240 tensor(0.9110, grad_fn=<AddBackward0>)
# 1250 tensor(0.8751, grad_fn=<AddBackward0>)
# 1260 tensor(0.8890, grad_fn=<AddBackward0>)
# 1270 tensor(0.9049, grad_fn=<AddBackward0>)
# 1280 tensor(0.8431, grad_fn=<AddBackward0>)
# 1290 tensor(0.8627, grad_fn=<AddBackward0>)
# 1300 tensor(0.8792, grad_fn=<AddBackward0>)
# 1310 tensor(0.8884, grad_fn=<AddBackward0>)
# 1320 tensor(0.8423, grad_fn=<AddBackward0>)
# 1330 tensor(0.8656, grad_fn=<AddBackward0>)
# 1340 tensor(0.9220, grad_fn=<AddBackward0>)
# 1350 tensor(0.9411, grad_fn=<AddBackward0>)
# 1360 tensor(0.8871, grad_fn=<AddBackward0>)
# 1370 tensor(0.8602, grad_fn=<AddBackward0>)
# 1380 tensor(0.8721, grad_fn=<AddBackward0>)
# 1390 tensor(0.8973, grad_fn=<AddBackward0>)
# 1400 tensor(0.8830, grad_fn=<AddBackward0>)
# 1410 tensor(0.8736, grad_fn=<AddBackward0>)
# 1420 tensor(0.9045, grad_fn=<AddBackward0>)
# 1430 tensor(0.8809, grad_fn=<AddBackward0>)
# 1440 tensor(0.8954, grad_fn=<AddBackward0>)
# 1450 tensor(0.8719, grad_fn=<AddBackward0>)
# 1460 tensor(0.8865, grad_fn=<AddBackward0>)
# 1470 tensor(0.8695, grad_fn=<AddBackward0>)
# 1480 tensor(0.8954, grad_fn=<AddBackward0>)
# 1490 tensor(0.8779, grad_fn=<AddBackward0>)
# 1500 tensor(0.8905, grad_fn=<AddBackward0>)
# 1510 tensor(0.8948, grad_fn=<AddBackward0>)
# 1520 tensor(0.8555, grad_fn=<AddBackward0>)
# 1530 tensor(0.8967, grad_fn=<AddBackward0>)
# 1540 tensor(0.8796, grad_fn=<AddBackward0>)
# 1550 tensor(0.8520, grad_fn=<AddBackward0>)
# 1560 tensor(0.9307, grad_fn=<AddBackward0>)
# 1570 tensor(0.8925, grad_fn=<AddBackward0>)
# 1580 tensor(0.8549, grad_fn=<AddBackward0>)
# 1590 tensor(0.8824, grad_fn=<AddBackward0>)
# 1600 tensor(0.8263, grad_fn=<AddBackward0>)
# 1610 tensor(0.8934, grad_fn=<AddBackward0>)
# 1620 tensor(0.9071, grad_fn=<AddBackward0>)
# 1630 tensor(0.8681, grad_fn=<AddBackward0>)
# 1640 tensor(0.8643, grad_fn=<AddBackward0>)
# 1650 tensor(0.8700, grad_fn=<AddBackward0>)
# 1660 tensor(0.8448, grad_fn=<AddBackward0>)
# 1670 tensor(0.8971, grad_fn=<AddBackward0>)
# 1680 tensor(0.8731, grad_fn=<AddBackward0>)
# 1690 tensor(0.9238, grad_fn=<AddBackward0>)
# 1700 tensor(0.8572, grad_fn=<AddBackward0>)
# 1710 tensor(0.8706, grad_fn=<AddBackward0>)
# 1720 tensor(0.8628, grad_fn=<AddBackward0>)
# 1730 tensor(0.8511, grad_fn=<AddBackward0>)
# 1740 tensor(0.8765, grad_fn=<AddBackward0>)
# 1750 tensor(0.8853, grad_fn=<AddBackward0>)
# 1760 tensor(0.8738, grad_fn=<AddBackward0>)
# 1770 tensor(0.8380, grad_fn=<AddBackward0>)
# 1780 tensor(0.8602, grad_fn=<AddBackward0>)
# 1790 tensor(0.8677, grad_fn=<AddBackward0>)
# 1800 tensor(0.8837, grad_fn=<AddBackward0>)
# 1810 tensor(0.8916, grad_fn=<AddBackward0>)
# 1820 tensor(0.8608, grad_fn=<AddBackward0>)
# 1830 tensor(0.8812, grad_fn=<AddBackward0>)
# 1840 tensor(0.8625, grad_fn=<AddBackward0>)
# 1850 tensor(0.8898, grad_fn=<AddBackward0>)
# 1860 tensor(0.9113, grad_fn=<AddBackward0>)
# 1870 tensor(0.8928, grad_fn=<AddBackward0>)
# 1880 tensor(0.8858, grad_fn=<AddBackward0>)
# 1890 tensor(0.8724, grad_fn=<AddBackward0>)
# 1900 tensor(0.8649, grad_fn=<AddBackward0>)
# 1910 tensor(0.8588, grad_fn=<AddBackward0>)
# 1920 tensor(0.9115, grad_fn=<AddBackward0>)
# 1930 tensor(0.8615, grad_fn=<AddBackward0>)
# 1940 tensor(0.8501, grad_fn=<AddBackward0>)
# 1950 tensor(0.8591, grad_fn=<AddBackward0>)
# 1960 tensor(0.8609, grad_fn=<AddBackward0>)
# 1970 tensor(0.8863, grad_fn=<AddBackward0>)
# 1980 tensor(0.8755, grad_fn=<AddBackward0>)
# 1990 tensor(0.8860, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 7 is bigger than -1.3955376 then go to left, else go to right
#     LEFT:
#     WHEN feature 0 is bigger than 0.64346033 then go to left, else go to right
#         LEFT:
#         WHEN feature 5 is bigger than 0.13228844 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 7 is bigger than 0.3400309 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#     RIGHT:
#     WHEN feature 0 is bigger than 1.145675 then go to left, else go to right
#         LEFT:
#         WHEN feature 8 is bigger than -0.78586525 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 0 is bigger than 0.54944366 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.6349480968858131
# f1_score:
#  0.770199692780338
# confusion_matrix:
#  [[47  0]
#  [11 10]]

# %%
print("accuracy:\n", np.array(all_results['accuracy']).mean())
print("f1_score:\n", np.array(all_results['f1_score']).mean())
print("confusion_matrix:\n", np.array(all_results['confusion_matrix']).mean(0))
# Out:
# accuracy:
#  0.6381487889273356
# f1_score:
#  0.46970545890051263
# confusion_matrix:
#  [[44.2  0. ]
#  [21.6  2.2]]

# %% [markdown]
# # Adult Dataset

# %%
# !wget https://raw.githubusercontent.com/jbrownlee/Datasets/refs/heads/master/adult-all.csv
# Out:
# --2024-10-26 12:21:46--  https://raw.githubusercontent.com/jbrownlee/Datasets/refs/heads/master/adult-all.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5277365 (5.0M) [text/plain]
# Saving to: ‘adult-all.csv.2’
#
# adult-all.csv.2     100%[===================>]   5.03M  19.7MB/s    in 0.3s
#
# 2024-10-26 12:21:47 (19.7 MB/s) - ‘adult-all.csv.2’ saved [5277365/5277365]

# %%
def preproc_col(str_column) :
  all_str = []
  for str_now in str_column :
    if not (str_now in all_str) :
      all_str.append(str_now)
  all_str = np.array(all_str)

  new_feature = []
  for str_now in str_column :
    now_feat = (all_str == str_now).astype(float)
    new_feature.append(now_feat)
  new_feature = np.stack(new_feature)

  return new_feature

# %%
def load_adult_data(filepath):

    data = pd.read_csv(filepath,
                       names=[
                           "age", "workclass", "fnlwgt", "education", "education-num",
                           "marital-status", "occupation", "relationship", "race", "sex",
                           "capital-gain", "capital-loss", "hours-per-week", "native-country",
                           "income"
                       ],
                       na_values=["?"])  # Treat "?" as missing values

    return data

# %%
filepath = '/content/adult-all.csv'  # Update with your actual file path
adult_data = load_adult_data(filepath)
# adult_data = adult_data.dropna()
adult_data = adult_data.to_numpy()
np.random.shuffle(adult_data)

# %%
all_adult_feat = adult_data[:,0:1]
for col_idx in range(1, adult_data.shape[1] - 1) :
  if type(adult_data[0][col_idx]) == str :
    feat_now = preproc_col(adult_data[:,col_idx])
    all_adult_feat = np.concatenate((all_adult_feat, feat_now),-1)
    print(all_adult_feat.shape)

print("----")

for col_idx in range(1, adult_data.shape[1] - 1) :
  if not (type(adult_data[0][col_idx]) == str) :
    all_adult_feat = np.concatenate((all_adult_feat, adult_data[:,col_idx:col_idx+1 ]),-1)
print(all_adult_feat.shape)
# Out:
# (48842, 10)
# (48842, 26)
# (48842, 33)
# (48842, 48)
# (48842, 54)
# (48842, 59)
# (48842, 61)
# (48842, 103)
# ----
# (48842, 108)

# %%
x_all = all_adult_feat
y_all = (adult_data[:,-1:] == ">50K").astype(float)

# %%
all_results, all_model = k_fold(x_all, y_all, num_k = 10, use_mlp = True, normalize = False, batch_size = 512,
                                focus_on_cont=True)
# Out:
# =============================================================
# (43958, 108) (43958, 1)
# (4884, 108) (4884, 1)
# LinearTree(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (linear1): Linear(in_features=108, out_features=64, bias=True)
#   (linear2): Linear(in_features=64, out_features=64, bias=True)
#   (linear3): Linear(in_features=64, out_features=64, bias=True)
#   (linear4): Linear(in_features=64, out_features=16, bias=True)
# )
# =============================================================
# {'batch_size': 512, 'focus_on_cont': True}
# Num Label: [33437 10521]
# Label Weight: [1.         3.17811995]
# 0 tensor(1.0622, grad_fn=<AddBackward0>)
# 10 tensor(1.0000, grad_fn=<AddBackward0>)
# 20 tensor(1.0033, grad_fn=<AddBackward0>)
# 30 tensor(0.9674, grad_fn=<AddBackward0>)
# 40 tensor(1.0265, grad_fn=<AddBackward0>)
# 50 tensor(1.0113, grad_fn=<AddBackward0>)
# 60 tensor(0.9965, grad_fn=<AddBackward0>)
# 70 tensor(0.9816, grad_fn=<AddBackward0>)
# 80 tensor(1.0186, grad_fn=<AddBackward0>)
# 90 tensor(1.0122, grad_fn=<AddBackward0>)
# 100 tensor(1.0148, grad_fn=<AddBackward0>)
# 110 tensor(0.9776, grad_fn=<AddBackward0>)
# 120 tensor(0.9651, grad_fn=<AddBackward0>)
# 130 tensor(1.0423, grad_fn=<AddBackward0>)
# 140 tensor(1.0149, grad_fn=<AddBackward0>)
# 150 tensor(1.0106, grad_fn=<AddBackward0>)
# 160 tensor(0.9760, grad_fn=<AddBackward0>)
# 170 tensor(1.0257, grad_fn=<AddBackward0>)
# 180 tensor(1.0067, grad_fn=<AddBackward0>)
# 190 tensor(0.9770, grad_fn=<AddBackward0>)
# 200 tensor(0.9687, grad_fn=<AddBackward0>)
# 210 tensor(0.9671, grad_fn=<AddBackward0>)
# 220 tensor(0.9615, grad_fn=<AddBackward0>)
# 230 tensor(1.0002, grad_fn=<AddBackward0>)
# 240 tensor(1.0191, grad_fn=<AddBackward0>)
# 250 tensor(0.9736, grad_fn=<AddBackward0>)
# 260 tensor(1.0250, grad_fn=<AddBackward0>)
# 270 tensor(1.0173, grad_fn=<AddBackward0>)
# 280 tensor(0.9610, grad_fn=<AddBackward0>)
# 290 tensor(1.0075, grad_fn=<AddBackward0>)
# 300 tensor(0.9718, grad_fn=<AddBackward0>)
# 310 tensor(0.9870, grad_fn=<AddBackward0>)
# 320 tensor(0.9832, grad_fn=<AddBackward0>)
# 330 tensor(1.0048, grad_fn=<AddBackward0>)
# 340 tensor(0.9827, grad_fn=<AddBackward0>)
# 350 tensor(1.0123, grad_fn=<AddBackward0>)
# 360 tensor(0.9385, grad_fn=<AddBackward0>)
# 370 tensor(0.9920, grad_fn=<AddBackward0>)
# 380 tensor(1.0225, grad_fn=<AddBackward0>)
# 390 tensor(1.0126, grad_fn=<AddBackward0>)
# 400 tensor(0.9500, grad_fn=<AddBackward0>)
# 410 tensor(1.0032, grad_fn=<AddBackward0>)
# 420 tensor(1.0614, grad_fn=<AddBackward0>)
# 430 tensor(1.0028, grad_fn=<AddBackward0>)
# 440 tensor(0.9734, grad_fn=<AddBackward0>)
# 450 tensor(0.9892, grad_fn=<AddBackward0>)
# 460 tensor(0.9834, grad_fn=<AddBackward0>)
# 470 tensor(0.9868, grad_fn=<AddBackward0>)
# 480 tensor(0.9719, grad_fn=<AddBackward0>)
# 490 tensor(0.9878, grad_fn=<AddBackward0>)
# 500 tensor(1.0268, grad_fn=<AddBackward0>)
# 510 tensor(1.0181, grad_fn=<AddBackward0>)
# 520 tensor(0.9870, grad_fn=<AddBackward0>)
# 530 tensor(1.0155, grad_fn=<AddBackward0>)
# 540 tensor(0.9288, grad_fn=<AddBackward0>)
# 550 tensor(0.9644, grad_fn=<AddBackward0>)
# 560 tensor(1.0500, grad_fn=<AddBackward0>)
# 570 tensor(0.9527, grad_fn=<AddBackward0>)
# 580 tensor(1.0485, grad_fn=<AddBackward0>)
# 590 tensor(1.0330, grad_fn=<AddBackward0>)
# 600 tensor(1.0171, grad_fn=<AddBackward0>)
# 610 tensor(1.0418, grad_fn=<AddBackward0>)
# 620 tensor(0.9727, grad_fn=<AddBackward0>)
# 630 tensor(0.9939, grad_fn=<AddBackward0>)
# 640 tensor(1.0397, grad_fn=<AddBackward0>)
# 650 tensor(1.0205, grad_fn=<AddBackward0>)
# 660 tensor(1.0590, grad_fn=<AddBackward0>)
# 670 tensor(0.9863, grad_fn=<AddBackward0>)
# 680 tensor(1.0122, grad_fn=<AddBackward0>)
# 690 tensor(0.9619, grad_fn=<AddBackward0>)
# 700 tensor(1.0156, grad_fn=<AddBackward0>)
# 710 tensor(1.0645, grad_fn=<AddBackward0>)
# 720 tensor(1.0033, grad_fn=<AddBackward0>)
# 730 tensor(1.0418, grad_fn=<AddBackward0>)
# 740 tensor(0.8978, grad_fn=<AddBackward0>)
# 750 tensor(0.9662, grad_fn=<AddBackward0>)
# 760 tensor(0.9747, grad_fn=<AddBackward0>)
# 770 tensor(0.9740, grad_fn=<AddBackward0>)
# 780 tensor(1.0218, grad_fn=<AddBackward0>)
# 790 tensor(0.9576, grad_fn=<AddBackward0>)
# 800 tensor(1.0524, grad_fn=<AddBackward0>)
# 810 tensor(1.0442, grad_fn=<AddBackward0>)
# 820 tensor(0.9707, grad_fn=<AddBackward0>)
# 830 tensor(0.9761, grad_fn=<AddBackward0>)
# 840 tensor(1.0541, grad_fn=<AddBackward0>)
# 850 tensor(1.0423, grad_fn=<AddBackward0>)
# 860 tensor(0.9885, grad_fn=<AddBackward0>)
# 870 tensor(0.9853, grad_fn=<AddBackward0>)
# 880 tensor(1.0278, grad_fn=<AddBackward0>)
# 890 tensor(1.0266, grad_fn=<AddBackward0>)
# 900 tensor(0.9438, grad_fn=<AddBackward0>)
# 910 tensor(0.9868, grad_fn=<AddBackward0>)
# 920 tensor(1.0329, grad_fn=<AddBackward0>)
# 930 tensor(1.0016, grad_fn=<AddBackward0>)
# 940 tensor(1.0031, grad_fn=<AddBackward0>)
# 950 tensor(1.0071, grad_fn=<AddBackward0>)
# 960 tensor(0.9944, grad_fn=<AddBackward0>)
# 970 tensor(0.9461, grad_fn=<AddBackward0>)
# 980 tensor(0.9920, grad_fn=<AddBackward0>)
# 990 tensor(0.9490, grad_fn=<AddBackward0>)
# 1000 tensor(1.0338, grad_fn=<AddBackward0>)
# 1010 tensor(0.9875, grad_fn=<AddBackward0>)
# 1020 tensor(1.0140, grad_fn=<AddBackward0>)
# 1030 tensor(0.9735, grad_fn=<AddBackward0>)
# 1040 tensor(1.0321, grad_fn=<AddBackward0>)
# 1050 tensor(0.9543, grad_fn=<AddBackward0>)
# 1060 tensor(0.9885, grad_fn=<AddBackward0>)
# 1070 tensor(1.0207, grad_fn=<AddBackward0>)
# 1080 tensor(1.0719, grad_fn=<AddBackward0>)
# 1090 tensor(0.9855, grad_fn=<AddBackward0>)
# 1100 tensor(1.0402, grad_fn=<AddBackward0>)
# 1110 tensor(1.0293, grad_fn=<AddBackward0>)
# 1120 tensor(1.0039, grad_fn=<AddBackward0>)
# 1130 tensor(1.0411, grad_fn=<AddBackward0>)
# 1140 tensor(0.9866, grad_fn=<AddBackward0>)
# 1150 tensor(0.9240, grad_fn=<AddBackward0>)
# 1160 tensor(0.9958, grad_fn=<AddBackward0>)
# 1170 tensor(0.9769, grad_fn=<AddBackward0>)
# 1180 tensor(1.0024, grad_fn=<AddBackward0>)
# 1190 tensor(1.0268, grad_fn=<AddBackward0>)
# 1200 tensor(1.0121, grad_fn=<AddBackward0>)
# 1210 tensor(1.0061, grad_fn=<AddBackward0>)
# 1220 tensor(1.0351, grad_fn=<AddBackward0>)
# 1230 tensor(0.9878, grad_fn=<AddBackward0>)
# 1240 tensor(0.9890, grad_fn=<AddBackward0>)
# 1250 tensor(1.0461, grad_fn=<AddBackward0>)
# 1260 tensor(0.9979, grad_fn=<AddBackward0>)
# 1270 tensor(0.9543, grad_fn=<AddBackward0>)
# 1280 tensor(1.0228, grad_fn=<AddBackward0>)
# 1290 tensor(0.9767, grad_fn=<AddBackward0>)
# 1300 tensor(0.9809, grad_fn=<AddBackward0>)
# 1310 tensor(0.9696, grad_fn=<AddBackward0>)
# 1320 tensor(1.0074, grad_fn=<AddBackward0>)
# 1330 tensor(1.0038, grad_fn=<AddBackward0>)
# 1340 tensor(0.9937, grad_fn=<AddBackward0>)
# 1350 tensor(0.9966, grad_fn=<AddBackward0>)
# 1360 tensor(1.0129, grad_fn=<AddBackward0>)
# 1370 tensor(1.0282, grad_fn=<AddBackward0>)
# 1380 tensor(0.9832, grad_fn=<AddBackward0>)
# 1390 tensor(1.0299, grad_fn=<AddBackward0>)
# 1400 tensor(0.9683, grad_fn=<AddBackward0>)
# 1410 tensor(0.9591, grad_fn=<AddBackward0>)
# 1420 tensor(1.0004, grad_fn=<AddBackward0>)
# 1430 tensor(0.9803, grad_fn=<AddBackward0>)
# 1440 tensor(1.0689, grad_fn=<AddBackward0>)
# 1450 tensor(0.9934, grad_fn=<AddBackward0>)
# 1460 tensor(1.0349, grad_fn=<AddBackward0>)
# 1470 tensor(1.0573, grad_fn=<AddBackward0>)
# 1480 tensor(1.0064, grad_fn=<AddBackward0>)
# 1490 tensor(1.0022, grad_fn=<AddBackward0>)
# 1500 tensor(1.0037, grad_fn=<AddBackward0>)
# 1510 tensor(0.9741, grad_fn=<AddBackward0>)
# 1520 tensor(0.9523, grad_fn=<AddBackward0>)
# 1530 tensor(1.0410, grad_fn=<AddBackward0>)
# 1540 tensor(0.9843, grad_fn=<AddBackward0>)
# 1550 tensor(0.9663, grad_fn=<AddBackward0>)
# 1560 tensor(0.9675, grad_fn=<AddBackward0>)
# 1570 tensor(0.9997, grad_fn=<AddBackward0>)
# 1580 tensor(1.0108, grad_fn=<AddBackward0>)
# 1590 tensor(0.9942, grad_fn=<AddBackward0>)
# 1600 tensor(1.0721, grad_fn=<AddBackward0>)
# 1610 tensor(1.0403, grad_fn=<AddBackward0>)
# 1620 tensor(1.0348, grad_fn=<AddBackward0>)
# 1630 tensor(0.9601, grad_fn=<AddBackward0>)
# 1640 tensor(0.9680, grad_fn=<AddBackward0>)
# 1650 tensor(0.9856, grad_fn=<AddBackward0>)
# 1660 tensor(0.9799, grad_fn=<AddBackward0>)
# 1670 tensor(0.9649, grad_fn=<AddBackward0>)
# 1680 tensor(0.9779, grad_fn=<AddBackward0>)
# 1690 tensor(0.9892, grad_fn=<AddBackward0>)
# 1700 tensor(0.9880, grad_fn=<AddBackward0>)
# 1710 tensor(1.0058, grad_fn=<AddBackward0>)
# 1720 tensor(1.0310, grad_fn=<AddBackward0>)
# 1730 tensor(1.0082, grad_fn=<AddBackward0>)
# 1740 tensor(0.9335, grad_fn=<AddBackward0>)
# 1750 tensor(1.0153, grad_fn=<AddBackward0>)
# 1760 tensor(1.0228, grad_fn=<AddBackward0>)
# 1770 tensor(1.0390, grad_fn=<AddBackward0>)
# 1780 tensor(0.9711, grad_fn=<AddBackward0>)
# 1790 tensor(0.9502, grad_fn=<AddBackward0>)
# 1800 tensor(1.0090, grad_fn=<AddBackward0>)
# 1810 tensor(0.9756, grad_fn=<AddBackward0>)
# 1820 tensor(0.9857, grad_fn=<AddBackward0>)
# 1830 tensor(0.9988, grad_fn=<AddBackward0>)
# 1840 tensor(0.9420, grad_fn=<AddBackward0>)
# 1850 tensor(0.9925, grad_fn=<AddBackward0>)
# 1860 tensor(1.0036, grad_fn=<AddBackward0>)
# 1870 tensor(0.9783, grad_fn=<AddBackward0>)
# 1880 tensor(1.0109, grad_fn=<AddBackward0>)
# 1890 tensor(0.9775, grad_fn=<AddBackward0>)
# 1900 tensor(1.0248, grad_fn=<AddBackward0>)
# 1910 tensor(1.0155, grad_fn=<AddBackward0>)
# 1920 tensor(1.0379, grad_fn=<AddBackward0>)
# 1930 tensor(0.9447, grad_fn=<AddBackward0>)
# 1940 tensor(1.0403, grad_fn=<AddBackward0>)
# 1950 tensor(0.9806, grad_fn=<AddBackward0>)
# 1960 tensor(1.0199, grad_fn=<AddBackward0>)
# 1970 tensor(1.0196, grad_fn=<AddBackward0>)
# 1980 tensor(1.0264, grad_fn=<AddBackward0>)
# 1990 tensor(0.9903, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 7 is bigger than 0.91091883 then go to left, else go to right
#     LEFT:
#     WHEN feature 6 is bigger than 0.28313327 then go to left, else go to right
#         LEFT:
#         WHEN feature 7 is bigger than -0.5298086 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
#         RIGHT:
#         WHEN feature 13 is bigger than -0.53423536 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#     RIGHT:
#     WHEN feature 7 is bigger than -1.3545619 then go to left, else go to right
#         LEFT:
#         WHEN feature 8 is bigger than -0.12977943 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 9 is bigger than 0.71696925 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
# accuracy:
#  0.7612612612612613
# f1_score:
#  0.4322250639386189
# confusion_matrix:
#  [[3718    0]
#  [1166    0]]
# =============================================================
# (43958, 108) (43958, 1)
# (4884, 108) (4884, 1)
# LinearTree(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (linear1): Linear(in_features=108, out_features=64, bias=True)
#   (linear2): Linear(in_features=64, out_features=64, bias=True)
#   (linear3): Linear(in_features=64, out_features=64, bias=True)
#   (linear4): Linear(in_features=64, out_features=16, bias=True)
# )
# =============================================================
# {'batch_size': 512, 'focus_on_cont': True}
# Num Label: [33476 10482]
# Label Weight: [1.         3.19366533]
# 0 tensor(1.1128, grad_fn=<AddBackward0>)
# 10 tensor(1.0073, grad_fn=<AddBackward0>)
# 20 tensor(1.0435, grad_fn=<AddBackward0>)
# 30 tensor(1.0031, grad_fn=<AddBackward0>)
# 40 tensor(1.0134, grad_fn=<AddBackward0>)
# 50 tensor(0.9954, grad_fn=<AddBackward0>)
# 60 tensor(1.0048, grad_fn=<AddBackward0>)
# 70 tensor(0.9638, grad_fn=<AddBackward0>)
# 80 tensor(0.9708, grad_fn=<AddBackward0>)
# 90 tensor(0.9543, grad_fn=<AddBackward0>)
# 100 tensor(1.0084, grad_fn=<AddBackward0>)
# 110 tensor(0.9532, grad_fn=<AddBackward0>)
# 120 tensor(0.9996, grad_fn=<AddBackward0>)
# 130 tensor(1.0263, grad_fn=<AddBackward0>)
# 140 tensor(1.0855, grad_fn=<AddBackward0>)
# 150 tensor(1.0192, grad_fn=<AddBackward0>)
# 160 tensor(1.0113, grad_fn=<AddBackward0>)
# 170 tensor(1.0391, grad_fn=<AddBackward0>)
# 180 tensor(1.0593, grad_fn=<AddBackward0>)
# 190 tensor(1.0220, grad_fn=<AddBackward0>)
# 200 tensor(1.0362, grad_fn=<AddBackward0>)
# 210 tensor(1.0236, grad_fn=<AddBackward0>)
# 220 tensor(0.9710, grad_fn=<AddBackward0>)
# 230 tensor(0.9696, grad_fn=<AddBackward0>)
# 240 tensor(0.9795, grad_fn=<AddBackward0>)
# 250 tensor(1.0303, grad_fn=<AddBackward0>)
# 260 tensor(1.0504, grad_fn=<AddBackward0>)
# 270 tensor(0.9988, grad_fn=<AddBackward0>)
# 280 tensor(1.0597, grad_fn=<AddBackward0>)
# 290 tensor(0.9789, grad_fn=<AddBackward0>)
# 300 tensor(1.0252, grad_fn=<AddBackward0>)
# 310 tensor(1.0335, grad_fn=<AddBackward0>)
# 320 tensor(0.9775, grad_fn=<AddBackward0>)
# 330 tensor(1.0237, grad_fn=<AddBackward0>)
# 340 tensor(1.0700, grad_fn=<AddBackward0>)
# 350 tensor(0.9743, grad_fn=<AddBackward0>)
# 360 tensor(0.9738, grad_fn=<AddBackward0>)
# 370 tensor(0.9994, grad_fn=<AddBackward0>)
# 380 tensor(1.0141, grad_fn=<AddBackward0>)
# 390 tensor(1.1035, grad_fn=<AddBackward0>)
# 400 tensor(0.9705, grad_fn=<AddBackward0>)
# 410 tensor(1.0111, grad_fn=<AddBackward0>)
# 420 tensor(1.0015, grad_fn=<AddBackward0>)
# 430 tensor(1.0160, grad_fn=<AddBackward0>)
# 440 tensor(0.9684, grad_fn=<AddBackward0>)
# 450 tensor(1.0238, grad_fn=<AddBackward0>)
# 460 tensor(1.0520, grad_fn=<AddBackward0>)
# 470 tensor(0.9991, grad_fn=<AddBackward0>)
# 480 tensor(1.0178, grad_fn=<AddBackward0>)
# 490 tensor(1.0622, grad_fn=<AddBackward0>)
# 500 tensor(1.0069, grad_fn=<AddBackward0>)
# 510 tensor(1.0459, grad_fn=<AddBackward0>)
# 520 tensor(0.9075, grad_fn=<AddBackward0>)
# 530 tensor(0.9867, grad_fn=<AddBackward0>)
# 540 tensor(0.9873, grad_fn=<AddBackward0>)
# 550 tensor(0.9593, grad_fn=<AddBackward0>)
# 560 tensor(0.9919, grad_fn=<AddBackward0>)
# 570 tensor(1.0005, grad_fn=<AddBackward0>)
# 580 tensor(1.0837, grad_fn=<AddBackward0>)
# 590 tensor(1.0057, grad_fn=<AddBackward0>)
# 600 tensor(1.0050, grad_fn=<AddBackward0>)
# 610 tensor(0.9924, grad_fn=<AddBackward0>)
# 620 tensor(0.9981, grad_fn=<AddBackward0>)
# 630 tensor(0.9471, grad_fn=<AddBackward0>)
# 640 tensor(1.0440, grad_fn=<AddBackward0>)
# 650 tensor(1.0061, grad_fn=<AddBackward0>)
# 660 tensor(1.0331, grad_fn=<AddBackward0>)
# 670 tensor(0.9784, grad_fn=<AddBackward0>)
# 680 tensor(1.0754, grad_fn=<AddBackward0>)
# 690 tensor(0.9417, grad_fn=<AddBackward0>)
# 700 tensor(0.9992, grad_fn=<AddBackward0>)
# 710 tensor(0.9302, grad_fn=<AddBackward0>)
# 720 tensor(0.9606, grad_fn=<AddBackward0>)
# 730 tensor(0.9390, grad_fn=<AddBackward0>)
# 740 tensor(1.0472, grad_fn=<AddBackward0>)
# 750 tensor(1.0238, grad_fn=<AddBackward0>)
# 760 tensor(0.9912, grad_fn=<AddBackward0>)
# 770 tensor(0.9782, grad_fn=<AddBackward0>)
# 780 tensor(1.0647, grad_fn=<AddBackward0>)
# 790 tensor(1.0344, grad_fn=<AddBackward0>)
# 800 tensor(0.9295, grad_fn=<AddBackward0>)
# 810 tensor(1.0298, grad_fn=<AddBackward0>)
# 820 tensor(1.0038, grad_fn=<AddBackward0>)
# 830 tensor(1.0115, grad_fn=<AddBackward0>)
# 840 tensor(1.0079, grad_fn=<AddBackward0>)
# 850 tensor(1.0485, grad_fn=<AddBackward0>)
# 860 tensor(0.9904, grad_fn=<AddBackward0>)
# 870 tensor(1.0370, grad_fn=<AddBackward0>)
# 880 tensor(1.0243, grad_fn=<AddBackward0>)
# 890 tensor(0.9917, grad_fn=<AddBackward0>)
# 900 tensor(0.9586, grad_fn=<AddBackward0>)
# 910 tensor(0.9501, grad_fn=<AddBackward0>)
# 920 tensor(0.9635, grad_fn=<AddBackward0>)
# 930 tensor(1.0414, grad_fn=<AddBackward0>)
# 940 tensor(1.0661, grad_fn=<AddBackward0>)
# 950 tensor(0.9898, grad_fn=<AddBackward0>)
# 960 tensor(0.9403, grad_fn=<AddBackward0>)
# 970 tensor(0.9982, grad_fn=<AddBackward0>)
# 980 tensor(0.9704, grad_fn=<AddBackward0>)
# 990 tensor(1.0383, grad_fn=<AddBackward0>)
# 1000 tensor(1.0386, grad_fn=<AddBackward0>)
# 1010 tensor(1.0113, grad_fn=<AddBackward0>)
# 1020 tensor(1.0504, grad_fn=<AddBackward0>)
# 1030 tensor(1.0313, grad_fn=<AddBackward0>)
# 1040 tensor(0.9956, grad_fn=<AddBackward0>)
# 1050 tensor(1.0480, grad_fn=<AddBackward0>)
# 1060 tensor(1.0342, grad_fn=<AddBackward0>)
# 1070 tensor(0.9326, grad_fn=<AddBackward0>)
# 1080 tensor(1.0189, grad_fn=<AddBackward0>)
# 1090 tensor(0.9776, grad_fn=<AddBackward0>)
# 1100 tensor(1.0406, grad_fn=<AddBackward0>)
# 1110 tensor(1.0120, grad_fn=<AddBackward0>)
# 1120 tensor(0.9927, grad_fn=<AddBackward0>)
# 1130 tensor(0.9695, grad_fn=<AddBackward0>)
# 1140 tensor(1.0181, grad_fn=<AddBackward0>)
# 1150 tensor(0.9526, grad_fn=<AddBackward0>)
# 1160 tensor(0.9651, grad_fn=<AddBackward0>)
# 1170 tensor(0.9916, grad_fn=<AddBackward0>)
# 1180 tensor(0.9755, grad_fn=<AddBackward0>)
# 1190 tensor(1.0464, grad_fn=<AddBackward0>)
# 1200 tensor(0.9862, grad_fn=<AddBackward0>)
# 1210 tensor(1.0419, grad_fn=<AddBackward0>)
# 1220 tensor(0.9903, grad_fn=<AddBackward0>)
# 1230 tensor(1.0137, grad_fn=<AddBackward0>)
# 1240 tensor(1.1149, grad_fn=<AddBackward0>)
# 1250 tensor(0.9905, grad_fn=<AddBackward0>)
# 1260 tensor(1.0184, grad_fn=<AddBackward0>)
# 1270 tensor(0.9830, grad_fn=<AddBackward0>)
# 1280 tensor(1.0383, grad_fn=<AddBackward0>)
# 1290 tensor(1.0386, grad_fn=<AddBackward0>)
# 1300 tensor(1.0219, grad_fn=<AddBackward0>)
# 1310 tensor(0.9661, grad_fn=<AddBackward0>)
# 1320 tensor(1.0612, grad_fn=<AddBackward0>)
# 1330 tensor(1.0451, grad_fn=<AddBackward0>)
# 1340 tensor(0.9411, grad_fn=<AddBackward0>)
# 1350 tensor(0.9820, grad_fn=<AddBackward0>)
# 1360 tensor(1.0122, grad_fn=<AddBackward0>)
# 1370 tensor(0.9753, grad_fn=<AddBackward0>)
# 1380 tensor(1.0179, grad_fn=<AddBackward0>)
# 1390 tensor(1.0038, grad_fn=<AddBackward0>)
# 1400 tensor(1.0460, grad_fn=<AddBackward0>)
# 1410 tensor(1.0707, grad_fn=<AddBackward0>)
# 1420 tensor(1.0114, grad_fn=<AddBackward0>)
# 1430 tensor(0.9619, grad_fn=<AddBackward0>)
# 1440 tensor(1.0061, grad_fn=<AddBackward0>)
# 1450 tensor(1.0256, grad_fn=<AddBackward0>)
# 1460 tensor(0.9439, grad_fn=<AddBackward0>)
# 1470 tensor(0.9608, grad_fn=<AddBackward0>)
# 1480 tensor(1.0343, grad_fn=<AddBackward0>)
# 1490 tensor(0.9491, grad_fn=<AddBackward0>)
# 1500 tensor(1.0320, grad_fn=<AddBackward0>)
# 1510 tensor(1.0522, grad_fn=<AddBackward0>)
# 1520 tensor(1.0581, grad_fn=<AddBackward0>)
# 1530 tensor(1.0237, grad_fn=<AddBackward0>)
# 1540 tensor(1.0133, grad_fn=<AddBackward0>)
# 1550 tensor(0.9631, grad_fn=<AddBackward0>)
# 1560 tensor(0.9782, grad_fn=<AddBackward0>)
# 1570 tensor(1.0105, grad_fn=<AddBackward0>)
# 1580 tensor(1.0271, grad_fn=<AddBackward0>)
# 1590 tensor(0.9869, grad_fn=<AddBackward0>)
# 1600 tensor(1.0010, grad_fn=<AddBackward0>)
# 1610 tensor(0.9547, grad_fn=<AddBackward0>)
# 1620 tensor(1.0282, grad_fn=<AddBackward0>)
# 1630 tensor(1.0120, grad_fn=<AddBackward0>)
# 1640 tensor(0.9452, grad_fn=<AddBackward0>)
# 1650 tensor(0.9581, grad_fn=<AddBackward0>)
# 1660 tensor(1.0095, grad_fn=<AddBackward0>)
# 1670 tensor(1.0194, grad_fn=<AddBackward0>)
# 1680 tensor(1.0270, grad_fn=<AddBackward0>)
# 1690 tensor(0.9987, grad_fn=<AddBackward0>)
# 1700 tensor(1.0428, grad_fn=<AddBackward0>)
# 1710 tensor(0.9982, grad_fn=<AddBackward0>)
# 1720 tensor(0.9960, grad_fn=<AddBackward0>)
# 1730 tensor(0.9927, grad_fn=<AddBackward0>)
# 1740 tensor(0.9970, grad_fn=<AddBackward0>)
# 1750 tensor(1.0010, grad_fn=<AddBackward0>)
# 1760 tensor(1.0133, grad_fn=<AddBackward0>)
# 1770 tensor(1.0234, grad_fn=<AddBackward0>)
# 1780 tensor(0.9947, grad_fn=<AddBackward0>)
# 1790 tensor(0.9400, grad_fn=<AddBackward0>)
# 1800 tensor(1.0033, grad_fn=<AddBackward0>)
# 1810 tensor(0.9744, grad_fn=<AddBackward0>)
# 1820 tensor(1.0070, grad_fn=<AddBackward0>)
# 1830 tensor(1.0267, grad_fn=<AddBackward0>)
# 1840 tensor(1.0281, grad_fn=<AddBackward0>)
# 1850 tensor(1.0162, grad_fn=<AddBackward0>)
# 1860 tensor(1.0324, grad_fn=<AddBackward0>)
# 1870 tensor(1.0592, grad_fn=<AddBackward0>)
# 1880 tensor(0.9559, grad_fn=<AddBackward0>)
# 1890 tensor(0.9430, grad_fn=<AddBackward0>)
# 1900 tensor(0.9522, grad_fn=<AddBackward0>)
# 1910 tensor(0.9367, grad_fn=<AddBackward0>)
# 1920 tensor(1.0315, grad_fn=<AddBackward0>)
# 1930 tensor(1.0340, grad_fn=<AddBackward0>)
# 1940 tensor(1.0334, grad_fn=<AddBackward0>)
# 1950 tensor(0.9918, grad_fn=<AddBackward0>)
# 1960 tensor(0.9900, grad_fn=<AddBackward0>)
# 1970 tensor(1.0168, grad_fn=<AddBackward0>)
# 1980 tensor(1.0154, grad_fn=<AddBackward0>)
# 1990 tensor(1.0460, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 10 is bigger than 0.57194245 then go to left, else go to right
#     LEFT:
#     WHEN feature 7 is bigger than -0.39851776 then go to left, else go to right
#         LEFT:
#         WHEN feature 8 is bigger than 0.38741153 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 11 is bigger than 0.28406876 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#     RIGHT:
#     WHEN feature 14 is bigger than -1.176298 then go to left, else go to right
#         LEFT:
#         WHEN feature 4 is bigger than -0.24144723 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
#         RIGHT:
#         WHEN feature 8 is bigger than 0.90007836 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.7532760032760033
# f1_score:
#  0.42963914515940677
# confusion_matrix:
#  [[3679    0]
#  [1205    0]]
# =============================================================
# (43958, 108) (43958, 1)
# (4884, 108) (4884, 1)
# LinearTree(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (linear1): Linear(in_features=108, out_features=64, bias=True)
#   (linear2): Linear(in_features=64, out_features=64, bias=True)
#   (linear3): Linear(in_features=64, out_features=64, bias=True)
#   (linear4): Linear(in_features=64, out_features=16, bias=True)
# )
# =============================================================
# {'batch_size': 512, 'focus_on_cont': True}
# Num Label: [33380 10578]
# Label Weight: [1.         3.15560597]
# 0 tensor(1.0521, grad_fn=<AddBackward0>)
# 10 tensor(1.0478, grad_fn=<AddBackward0>)
# 20 tensor(0.9815, grad_fn=<AddBackward0>)
# 30 tensor(1.0389, grad_fn=<AddBackward0>)
# 40 tensor(0.9821, grad_fn=<AddBackward0>)
# 50 tensor(1.0328, grad_fn=<AddBackward0>)
# 60 tensor(1.0173, grad_fn=<AddBackward0>)
# 70 tensor(1.0331, grad_fn=<AddBackward0>)
# 80 tensor(1.0267, grad_fn=<AddBackward0>)
# 90 tensor(1.0492, grad_fn=<AddBackward0>)
# 100 tensor(1.0061, grad_fn=<AddBackward0>)
# 110 tensor(1.0173, grad_fn=<AddBackward0>)
# 120 tensor(1.0366, grad_fn=<AddBackward0>)
# 130 tensor(0.9747, grad_fn=<AddBackward0>)
# 140 tensor(0.9836, grad_fn=<AddBackward0>)
# 150 tensor(1.0259, grad_fn=<AddBackward0>)
# 160 tensor(1.0234, grad_fn=<AddBackward0>)
# 170 tensor(0.9966, grad_fn=<AddBackward0>)
# 180 tensor(1.0535, grad_fn=<AddBackward0>)
# 190 tensor(0.9842, grad_fn=<AddBackward0>)
# 200 tensor(0.9631, grad_fn=<AddBackward0>)
# 210 tensor(1.0568, grad_fn=<AddBackward0>)
# 220 tensor(1.0431, grad_fn=<AddBackward0>)
# 230 tensor(1.0647, grad_fn=<AddBackward0>)
# 240 tensor(0.9344, grad_fn=<AddBackward0>)
# 250 tensor(1.0590, grad_fn=<AddBackward0>)
# 260 tensor(0.9853, grad_fn=<AddBackward0>)
# 270 tensor(1.0276, grad_fn=<AddBackward0>)
# 280 tensor(0.9871, grad_fn=<AddBackward0>)
# 290 tensor(0.9495, grad_fn=<AddBackward0>)
# 300 tensor(1.0271, grad_fn=<AddBackward0>)
# 310 tensor(0.9852, grad_fn=<AddBackward0>)
# 320 tensor(0.9407, grad_fn=<AddBackward0>)
# 330 tensor(1.0271, grad_fn=<AddBackward0>)
# 340 tensor(0.9682, grad_fn=<AddBackward0>)
# 350 tensor(1.0393, grad_fn=<AddBackward0>)
# 360 tensor(0.9938, grad_fn=<AddBackward0>)
# 370 tensor(0.9971, grad_fn=<AddBackward0>)
# 380 tensor(0.9779, grad_fn=<AddBackward0>)
# 390 tensor(1.0072, grad_fn=<AddBackward0>)
# 400 tensor(1.0023, grad_fn=<AddBackward0>)
# 410 tensor(0.9737, grad_fn=<AddBackward0>)
# 420 tensor(0.9956, grad_fn=<AddBackward0>)
# 430 tensor(1.0240, grad_fn=<AddBackward0>)
# 440 tensor(1.0207, grad_fn=<AddBackward0>)
# 450 tensor(0.9440, grad_fn=<AddBackward0>)
# 460 tensor(0.9894, grad_fn=<AddBackward0>)
# 470 tensor(0.9594, grad_fn=<AddBackward0>)
# 480 tensor(0.9910, grad_fn=<AddBackward0>)
# 490 tensor(0.9948, grad_fn=<AddBackward0>)
# 500 tensor(1.0430, grad_fn=<AddBackward0>)
# 510 tensor(1.0031, grad_fn=<AddBackward0>)
# 520 tensor(1.0219, grad_fn=<AddBackward0>)
# 530 tensor(0.9875, grad_fn=<AddBackward0>)
# 540 tensor(0.9409, grad_fn=<AddBackward0>)
# 550 tensor(0.9596, grad_fn=<AddBackward0>)
# 560 tensor(1.0118, grad_fn=<AddBackward0>)
# 570 tensor(0.9922, grad_fn=<AddBackward0>)
# 580 tensor(1.0034, grad_fn=<AddBackward0>)
# 590 tensor(1.0261, grad_fn=<AddBackward0>)
# 600 tensor(1.0437, grad_fn=<AddBackward0>)
# 610 tensor(0.9807, grad_fn=<AddBackward0>)
# 620 tensor(0.9759, grad_fn=<AddBackward0>)
# 630 tensor(0.9843, grad_fn=<AddBackward0>)
# 640 tensor(0.9898, grad_fn=<AddBackward0>)
# 650 tensor(1.0264, grad_fn=<AddBackward0>)
# 660 tensor(1.0244, grad_fn=<AddBackward0>)
# 670 tensor(1.0282, grad_fn=<AddBackward0>)
# 680 tensor(1.0252, grad_fn=<AddBackward0>)
# 690 tensor(1.0074, grad_fn=<AddBackward0>)
# 700 tensor(0.9958, grad_fn=<AddBackward0>)
# 710 tensor(1.0467, grad_fn=<AddBackward0>)
# 720 tensor(0.9647, grad_fn=<AddBackward0>)
# 730 tensor(0.9578, grad_fn=<AddBackward0>)
# 740 tensor(1.0007, grad_fn=<AddBackward0>)
# 750 tensor(0.9963, grad_fn=<AddBackward0>)
# 760 tensor(0.9575, grad_fn=<AddBackward0>)
# 770 tensor(1.0037, grad_fn=<AddBackward0>)
# 780 tensor(1.0409, grad_fn=<AddBackward0>)
# 790 tensor(1.0501, grad_fn=<AddBackward0>)
# 800 tensor(0.9863, grad_fn=<AddBackward0>)
# 810 tensor(0.9832, grad_fn=<AddBackward0>)
# 820 tensor(0.9680, grad_fn=<AddBackward0>)
# 830 tensor(1.0539, grad_fn=<AddBackward0>)
# 840 tensor(0.9917, grad_fn=<AddBackward0>)
# 850 tensor(1.0103, grad_fn=<AddBackward0>)
# 860 tensor(1.0163, grad_fn=<AddBackward0>)
# 870 tensor(0.9915, grad_fn=<AddBackward0>)
# 880 tensor(1.0013, grad_fn=<AddBackward0>)
# 890 tensor(0.9751, grad_fn=<AddBackward0>)
# 900 tensor(1.0411, grad_fn=<AddBackward0>)
# 910 tensor(1.0007, grad_fn=<AddBackward0>)
# 920 tensor(0.9607, grad_fn=<AddBackward0>)
# 930 tensor(1.0176, grad_fn=<AddBackward0>)
# 940 tensor(1.0093, grad_fn=<AddBackward0>)
# 950 tensor(1.0409, grad_fn=<AddBackward0>)
# 960 tensor(1.0225, grad_fn=<AddBackward0>)
# 970 tensor(1.0218, grad_fn=<AddBackward0>)
# 980 tensor(1.0351, grad_fn=<AddBackward0>)
# 990 tensor(0.9795, grad_fn=<AddBackward0>)
# 1000 tensor(1.0064, grad_fn=<AddBackward0>)
# 1010 tensor(1.0167, grad_fn=<AddBackward0>)
# 1020 tensor(0.9663, grad_fn=<AddBackward0>)
# 1030 tensor(1.0143, grad_fn=<AddBackward0>)
# 1040 tensor(0.9697, grad_fn=<AddBackward0>)
# 1050 tensor(0.9625, grad_fn=<AddBackward0>)
# 1060 tensor(0.9805, grad_fn=<AddBackward0>)
# 1070 tensor(0.9551, grad_fn=<AddBackward0>)
# 1080 tensor(0.9799, grad_fn=<AddBackward0>)
# 1090 tensor(0.9783, grad_fn=<AddBackward0>)
# 1100 tensor(1.0438, grad_fn=<AddBackward0>)
# 1110 tensor(0.9161, grad_fn=<AddBackward0>)
# 1120 tensor(1.0249, grad_fn=<AddBackward0>)
# 1130 tensor(0.9800, grad_fn=<AddBackward0>)
# 1140 tensor(1.0171, grad_fn=<AddBackward0>)
# 1150 tensor(0.9977, grad_fn=<AddBackward0>)
# 1160 tensor(1.0577, grad_fn=<AddBackward0>)
# 1170 tensor(1.0498, grad_fn=<AddBackward0>)
# 1180 tensor(1.0116, grad_fn=<AddBackward0>)
# 1190 tensor(0.9468, grad_fn=<AddBackward0>)
# 1200 tensor(1.0093, grad_fn=<AddBackward0>)
# 1210 tensor(0.9199, grad_fn=<AddBackward0>)
# 1220 tensor(0.9600, grad_fn=<AddBackward0>)
# 1230 tensor(1.0582, grad_fn=<AddBackward0>)
# 1240 tensor(0.9863, grad_fn=<AddBackward0>)
# 1250 tensor(1.0053, grad_fn=<AddBackward0>)
# 1260 tensor(0.9695, grad_fn=<AddBackward0>)
# 1270 tensor(0.9711, grad_fn=<AddBackward0>)
# 1280 tensor(1.0398, grad_fn=<AddBackward0>)
# 1290 tensor(1.0576, grad_fn=<AddBackward0>)
# 1300 tensor(1.0541, grad_fn=<AddBackward0>)
# 1310 tensor(0.9762, grad_fn=<AddBackward0>)
# 1320 tensor(0.9886, grad_fn=<AddBackward0>)
# 1330 tensor(0.9915, grad_fn=<AddBackward0>)
# 1340 tensor(1.0094, grad_fn=<AddBackward0>)
# 1350 tensor(1.0086, grad_fn=<AddBackward0>)
# 1360 tensor(1.0009, grad_fn=<AddBackward0>)
# 1370 tensor(1.0436, grad_fn=<AddBackward0>)
# 1380 tensor(0.9978, grad_fn=<AddBackward0>)
# 1390 tensor(1.0516, grad_fn=<AddBackward0>)
# 1400 tensor(1.0407, grad_fn=<AddBackward0>)
# 1410 tensor(0.9810, grad_fn=<AddBackward0>)
# 1420 tensor(0.9618, grad_fn=<AddBackward0>)
# 1430 tensor(1.0024, grad_fn=<AddBackward0>)
# 1440 tensor(0.9830, grad_fn=<AddBackward0>)
# 1450 tensor(0.9568, grad_fn=<AddBackward0>)
# 1460 tensor(0.9719, grad_fn=<AddBackward0>)
# 1470 tensor(1.0312, grad_fn=<AddBackward0>)
# 1480 tensor(1.0402, grad_fn=<AddBackward0>)
# 1490 tensor(1.0042, grad_fn=<AddBackward0>)
# 1500 tensor(1.0118, grad_fn=<AddBackward0>)
# 1510 tensor(0.9983, grad_fn=<AddBackward0>)
# 1520 tensor(0.9440, grad_fn=<AddBackward0>)
# 1530 tensor(1.0070, grad_fn=<AddBackward0>)
# 1540 tensor(0.9845, grad_fn=<AddBackward0>)
# 1550 tensor(1.0546, grad_fn=<AddBackward0>)
# 1560 tensor(1.0074, grad_fn=<AddBackward0>)
# 1570 tensor(0.9922, grad_fn=<AddBackward0>)
# 1580 tensor(1.0243, grad_fn=<AddBackward0>)
# 1590 tensor(0.9840, grad_fn=<AddBackward0>)
# 1600 tensor(1.1159, grad_fn=<AddBackward0>)
# 1610 tensor(1.0745, grad_fn=<AddBackward0>)
# 1620 tensor(0.9856, grad_fn=<AddBackward0>)
# 1630 tensor(0.9889, grad_fn=<AddBackward0>)
# 1640 tensor(0.9760, grad_fn=<AddBackward0>)
# 1650 tensor(0.9599, grad_fn=<AddBackward0>)
# 1660 tensor(0.9325, grad_fn=<AddBackward0>)
# 1670 tensor(0.9617, grad_fn=<AddBackward0>)
# 1680 tensor(1.0326, grad_fn=<AddBackward0>)
# 1690 tensor(1.0163, grad_fn=<AddBackward0>)
# 1700 tensor(0.9829, grad_fn=<AddBackward0>)
# 1710 tensor(1.0463, grad_fn=<AddBackward0>)
# 1720 tensor(0.9542, grad_fn=<AddBackward0>)
# 1730 tensor(1.0033, grad_fn=<AddBackward0>)
# 1740 tensor(1.0555, grad_fn=<AddBackward0>)
# 1750 tensor(1.0423, grad_fn=<AddBackward0>)
# 1760 tensor(0.9956, grad_fn=<AddBackward0>)
# 1770 tensor(1.0112, grad_fn=<AddBackward0>)
# 1780 tensor(0.9988, grad_fn=<AddBackward0>)
# 1790 tensor(0.9467, grad_fn=<AddBackward0>)
# 1800 tensor(1.0551, grad_fn=<AddBackward0>)
# 1810 tensor(0.9806, grad_fn=<AddBackward0>)
# 1820 tensor(0.9991, grad_fn=<AddBackward0>)
# 1830 tensor(1.0046, grad_fn=<AddBackward0>)
# 1840 tensor(0.9937, grad_fn=<AddBackward0>)
# 1850 tensor(0.9546, grad_fn=<AddBackward0>)
# 1860 tensor(1.0863, grad_fn=<AddBackward0>)
# 1870 tensor(0.9867, grad_fn=<AddBackward0>)
# 1880 tensor(1.0325, grad_fn=<AddBackward0>)
# 1890 tensor(0.9275, grad_fn=<AddBackward0>)
# 1900 tensor(1.0525, grad_fn=<AddBackward0>)
# 1910 tensor(0.9791, grad_fn=<AddBackward0>)
# 1920 tensor(1.0222, grad_fn=<AddBackward0>)
# 1930 tensor(1.0305, grad_fn=<AddBackward0>)
# 1940 tensor(0.9989, grad_fn=<AddBackward0>)
# 1950 tensor(0.9861, grad_fn=<AddBackward0>)
# 1960 tensor(1.0284, grad_fn=<AddBackward0>)
# 1970 tensor(1.0450, grad_fn=<AddBackward0>)
# 1980 tensor(1.0570, grad_fn=<AddBackward0>)
# 1990 tensor(0.9978, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 2 is bigger than 0.48825654 then go to left, else go to right
#     LEFT:
#     WHEN feature 12 is bigger than -0.5675837 then go to left, else go to right
#         LEFT:
#         WHEN feature 7 is bigger than -1.0158535 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
#         RIGHT:
#         WHEN feature 14 is bigger than -0.63332117 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 1
#     RIGHT:
#     WHEN feature 7 is bigger than 0.75644946 then go to left, else go to right
#         LEFT:
#         WHEN feature 3 is bigger than 0.55526376 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 3 is bigger than -0.62034774 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
# accuracy:
#  0.7729320229320229
# f1_score:
#  0.43596258228432844
# confusion_matrix:
#  [[3775    0]
#  [1109    0]]
# =============================================================
# (43958, 108) (43958, 1)
# (4884, 108) (4884, 1)
# LinearTree(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (linear1): Linear(in_features=108, out_features=64, bias=True)
#   (linear2): Linear(in_features=64, out_features=64, bias=True)
#   (linear3): Linear(in_features=64, out_features=64, bias=True)
#   (linear4): Linear(in_features=64, out_features=16, bias=True)
# )
# =============================================================
# {'batch_size': 512, 'focus_on_cont': True}
# Num Label: [33430 10528]
# Label Weight: [1.         3.17534195]
# 0 tensor(1.0823, grad_fn=<AddBackward0>)
# 10 tensor(1.0589, grad_fn=<AddBackward0>)
# 20 tensor(1.0227, grad_fn=<AddBackward0>)
# 30 tensor(1.0880, grad_fn=<AddBackward0>)
# 40 tensor(1.0681, grad_fn=<AddBackward0>)
# 50 tensor(1.0261, grad_fn=<AddBackward0>)
# 60 tensor(1.0049, grad_fn=<AddBackward0>)
# 70 tensor(1.0080, grad_fn=<AddBackward0>)
# 80 tensor(1.0273, grad_fn=<AddBackward0>)
# 90 tensor(1.0394, grad_fn=<AddBackward0>)
# 100 tensor(1.0064, grad_fn=<AddBackward0>)
# 110 tensor(1.0077, grad_fn=<AddBackward0>)
# 120 tensor(1.0344, grad_fn=<AddBackward0>)
# 130 tensor(0.9706, grad_fn=<AddBackward0>)
# 140 tensor(1.0440, grad_fn=<AddBackward0>)
# 150 tensor(1.0444, grad_fn=<AddBackward0>)
# 160 tensor(1.0549, grad_fn=<AddBackward0>)
# 170 tensor(0.9977, grad_fn=<AddBackward0>)
# 180 tensor(1.0403, grad_fn=<AddBackward0>)
# 190 tensor(0.9980, grad_fn=<AddBackward0>)
# 200 tensor(1.0165, grad_fn=<AddBackward0>)
# 210 tensor(0.9660, grad_fn=<AddBackward0>)
# 220 tensor(1.0323, grad_fn=<AddBackward0>)
# 230 tensor(1.0054, grad_fn=<AddBackward0>)
# 240 tensor(0.9914, grad_fn=<AddBackward0>)
# 250 tensor(0.9398, grad_fn=<AddBackward0>)
# 260 tensor(0.9951, grad_fn=<AddBackward0>)
# 270 tensor(0.9789, grad_fn=<AddBackward0>)
# 280 tensor(0.9824, grad_fn=<AddBackward0>)
# 290 tensor(1.0251, grad_fn=<AddBackward0>)
# 300 tensor(1.0070, grad_fn=<AddBackward0>)
# 310 tensor(1.0955, grad_fn=<AddBackward0>)
# 320 tensor(1.0071, grad_fn=<AddBackward0>)
# 330 tensor(0.9619, grad_fn=<AddBackward0>)
# 340 tensor(1.0069, grad_fn=<AddBackward0>)
# 350 tensor(0.9979, grad_fn=<AddBackward0>)
# 360 tensor(0.9745, grad_fn=<AddBackward0>)
# 370 tensor(0.9776, grad_fn=<AddBackward0>)
# 380 tensor(1.0456, grad_fn=<AddBackward0>)
# 390 tensor(0.9657, grad_fn=<AddBackward0>)
# 400 tensor(1.0293, grad_fn=<AddBackward0>)
# 410 tensor(0.9883, grad_fn=<AddBackward0>)
# 420 tensor(1.0367, grad_fn=<AddBackward0>)
# 430 tensor(0.9955, grad_fn=<AddBackward0>)
# 440 tensor(1.0094, grad_fn=<AddBackward0>)
# 450 tensor(1.0442, grad_fn=<AddBackward0>)
# 460 tensor(0.9859, grad_fn=<AddBackward0>)
# 470 tensor(0.9564, grad_fn=<AddBackward0>)
# 480 tensor(1.0656, grad_fn=<AddBackward0>)
# 490 tensor(1.0212, grad_fn=<AddBackward0>)
# 500 tensor(0.9931, grad_fn=<AddBackward0>)
# 510 tensor(0.9485, grad_fn=<AddBackward0>)
# 520 tensor(0.9628, grad_fn=<AddBackward0>)
# 530 tensor(1.0409, grad_fn=<AddBackward0>)
# 540 tensor(0.9886, grad_fn=<AddBackward0>)
# 550 tensor(1.0269, grad_fn=<AddBackward0>)
# 560 tensor(0.9518, grad_fn=<AddBackward0>)
# 570 tensor(0.9930, grad_fn=<AddBackward0>)
# 580 tensor(1.0341, grad_fn=<AddBackward0>)
# 590 tensor(1.0062, grad_fn=<AddBackward0>)
# 600 tensor(1.0384, grad_fn=<AddBackward0>)
# 610 tensor(1.0229, grad_fn=<AddBackward0>)
# 620 tensor(1.0248, grad_fn=<AddBackward0>)
# 630 tensor(0.9969, grad_fn=<AddBackward0>)
# 640 tensor(1.0217, grad_fn=<AddBackward0>)
# 650 tensor(1.0442, grad_fn=<AddBackward0>)
# 660 tensor(1.0198, grad_fn=<AddBackward0>)
# 670 tensor(1.0140, grad_fn=<AddBackward0>)
# 680 tensor(1.1034, grad_fn=<AddBackward0>)
# 690 tensor(0.9589, grad_fn=<AddBackward0>)
# 700 tensor(0.9774, grad_fn=<AddBackward0>)
# 710 tensor(0.9905, grad_fn=<AddBackward0>)
# 720 tensor(1.0273, grad_fn=<AddBackward0>)
# 730 tensor(0.9739, grad_fn=<AddBackward0>)
# 740 tensor(1.0114, grad_fn=<AddBackward0>)
# 750 tensor(0.9724, grad_fn=<AddBackward0>)
# 760 tensor(1.0210, grad_fn=<AddBackward0>)
# 770 tensor(0.9902, grad_fn=<AddBackward0>)
# 780 tensor(1.0039, grad_fn=<AddBackward0>)
# 790 tensor(0.9694, grad_fn=<AddBackward0>)
# 800 tensor(0.9686, grad_fn=<AddBackward0>)
# 810 tensor(0.9682, grad_fn=<AddBackward0>)
# 820 tensor(1.0278, grad_fn=<AddBackward0>)
# 830 tensor(1.0400, grad_fn=<AddBackward0>)
# 840 tensor(0.9713, grad_fn=<AddBackward0>)
# 850 tensor(0.9936, grad_fn=<AddBackward0>)
# 860 tensor(0.9983, grad_fn=<AddBackward0>)
# 870 tensor(0.9746, grad_fn=<AddBackward0>)
# 880 tensor(0.9876, grad_fn=<AddBackward0>)
# 890 tensor(0.9602, grad_fn=<AddBackward0>)
# 900 tensor(1.0102, grad_fn=<AddBackward0>)
# 910 tensor(1.0141, grad_fn=<AddBackward0>)
# 920 tensor(1.0297, grad_fn=<AddBackward0>)
# 930 tensor(1.0047, grad_fn=<AddBackward0>)
# 940 tensor(0.9424, grad_fn=<AddBackward0>)
# 950 tensor(1.0136, grad_fn=<AddBackward0>)
# 960 tensor(0.9804, grad_fn=<AddBackward0>)
# 970 tensor(0.9573, grad_fn=<AddBackward0>)
# 980 tensor(0.9488, grad_fn=<AddBackward0>)
# 990 tensor(0.9176, grad_fn=<AddBackward0>)
# 1000 tensor(0.9897, grad_fn=<AddBackward0>)
# 1010 tensor(1.0851, grad_fn=<AddBackward0>)
# 1020 tensor(1.0264, grad_fn=<AddBackward0>)
# 1030 tensor(1.0210, grad_fn=<AddBackward0>)
# 1040 tensor(1.0735, grad_fn=<AddBackward0>)
# 1050 tensor(0.9943, grad_fn=<AddBackward0>)
# 1060 tensor(1.0181, grad_fn=<AddBackward0>)
# 1070 tensor(0.9927, grad_fn=<AddBackward0>)
# 1080 tensor(1.0453, grad_fn=<AddBackward0>)
# 1090 tensor(1.0595, grad_fn=<AddBackward0>)
# 1100 tensor(1.0558, grad_fn=<AddBackward0>)
# 1110 tensor(0.9860, grad_fn=<AddBackward0>)
# 1120 tensor(0.9792, grad_fn=<AddBackward0>)
# 1130 tensor(0.9785, grad_fn=<AddBackward0>)
# 1140 tensor(1.0026, grad_fn=<AddBackward0>)
# 1150 tensor(0.9971, grad_fn=<AddBackward0>)
# 1160 tensor(0.9638, grad_fn=<AddBackward0>)
# 1170 tensor(0.9853, grad_fn=<AddBackward0>)
# 1180 tensor(1.0032, grad_fn=<AddBackward0>)
# 1190 tensor(1.0400, grad_fn=<AddBackward0>)
# 1200 tensor(0.9999, grad_fn=<AddBackward0>)
# 1210 tensor(1.0251, grad_fn=<AddBackward0>)
# 1220 tensor(1.0103, grad_fn=<AddBackward0>)
# 1230 tensor(1.0127, grad_fn=<AddBackward0>)
# 1240 tensor(1.0060, grad_fn=<AddBackward0>)
# 1250 tensor(0.9901, grad_fn=<AddBackward0>)
# 1260 tensor(0.9995, grad_fn=<AddBackward0>)
# 1270 tensor(0.9923, grad_fn=<AddBackward0>)
# 1280 tensor(1.0538, grad_fn=<AddBackward0>)
# 1290 tensor(1.0832, grad_fn=<AddBackward0>)
# 1300 tensor(0.9924, grad_fn=<AddBackward0>)
# 1310 tensor(1.0272, grad_fn=<AddBackward0>)
# 1320 tensor(0.9450, grad_fn=<AddBackward0>)
# 1330 tensor(0.9901, grad_fn=<AddBackward0>)
# 1340 tensor(1.0385, grad_fn=<AddBackward0>)
# 1350 tensor(0.9779, grad_fn=<AddBackward0>)
# 1360 tensor(1.0134, grad_fn=<AddBackward0>)
# 1370 tensor(1.0385, grad_fn=<AddBackward0>)
# 1380 tensor(0.9752, grad_fn=<AddBackward0>)
# 1390 tensor(1.0011, grad_fn=<AddBackward0>)
# 1400 tensor(0.9795, grad_fn=<AddBackward0>)
# 1410 tensor(0.9731, grad_fn=<AddBackward0>)
# 1420 tensor(1.0231, grad_fn=<AddBackward0>)
# 1430 tensor(1.0160, grad_fn=<AddBackward0>)
# 1440 tensor(0.9352, grad_fn=<AddBackward0>)
# 1450 tensor(0.9684, grad_fn=<AddBackward0>)
# 1460 tensor(1.0680, grad_fn=<AddBackward0>)
# 1470 tensor(1.0110, grad_fn=<AddBackward0>)
# 1480 tensor(0.9937, grad_fn=<AddBackward0>)
# 1490 tensor(0.9661, grad_fn=<AddBackward0>)
# 1500 tensor(1.0259, grad_fn=<AddBackward0>)
# 1510 tensor(1.0478, grad_fn=<AddBackward0>)
# 1520 tensor(0.9393, grad_fn=<AddBackward0>)
# 1530 tensor(1.0079, grad_fn=<AddBackward0>)
# 1540 tensor(1.0583, grad_fn=<AddBackward0>)
# 1550 tensor(1.0526, grad_fn=<AddBackward0>)
# 1560 tensor(0.9760, grad_fn=<AddBackward0>)
# 1570 tensor(1.0786, grad_fn=<AddBackward0>)
# 1580 tensor(1.0649, grad_fn=<AddBackward0>)
# 1590 tensor(0.9830, grad_fn=<AddBackward0>)
# 1600 tensor(1.0854, grad_fn=<AddBackward0>)
# 1610 tensor(0.9656, grad_fn=<AddBackward0>)
# 1620 tensor(0.9915, grad_fn=<AddBackward0>)
# 1630 tensor(1.0105, grad_fn=<AddBackward0>)
# 1640 tensor(1.0267, grad_fn=<AddBackward0>)
# 1650 tensor(0.9812, grad_fn=<AddBackward0>)
# 1660 tensor(1.0291, grad_fn=<AddBackward0>)
# 1670 tensor(1.0159, grad_fn=<AddBackward0>)
# 1680 tensor(0.9730, grad_fn=<AddBackward0>)
# 1690 tensor(0.9673, grad_fn=<AddBackward0>)
# 1700 tensor(0.9868, grad_fn=<AddBackward0>)
# 1710 tensor(1.0027, grad_fn=<AddBackward0>)
# 1720 tensor(0.9803, grad_fn=<AddBackward0>)
# 1730 tensor(1.0069, grad_fn=<AddBackward0>)
# 1740 tensor(1.0422, grad_fn=<AddBackward0>)
# 1750 tensor(1.0364, grad_fn=<AddBackward0>)
# 1760 tensor(0.9819, grad_fn=<AddBackward0>)
# 1770 tensor(0.9881, grad_fn=<AddBackward0>)
# 1780 tensor(0.9822, grad_fn=<AddBackward0>)
# 1790 tensor(1.0049, grad_fn=<AddBackward0>)
# 1800 tensor(1.0174, grad_fn=<AddBackward0>)
# 1810 tensor(0.9945, grad_fn=<AddBackward0>)
# 1820 tensor(1.0027, grad_fn=<AddBackward0>)
# 1830 tensor(0.9747, grad_fn=<AddBackward0>)
# 1840 tensor(0.9829, grad_fn=<AddBackward0>)
# 1850 tensor(0.9800, grad_fn=<AddBackward0>)
# 1860 tensor(1.0147, grad_fn=<AddBackward0>)
# 1870 tensor(1.0236, grad_fn=<AddBackward0>)
# 1880 tensor(0.9962, grad_fn=<AddBackward0>)
# 1890 tensor(1.0417, grad_fn=<AddBackward0>)
# 1900 tensor(1.0067, grad_fn=<AddBackward0>)
# 1910 tensor(1.0268, grad_fn=<AddBackward0>)
# 1920 tensor(0.9961, grad_fn=<AddBackward0>)
# 1930 tensor(0.9880, grad_fn=<AddBackward0>)
# 1940 tensor(0.9738, grad_fn=<AddBackward0>)
# 1950 tensor(1.0040, grad_fn=<AddBackward0>)
# 1960 tensor(0.9880, grad_fn=<AddBackward0>)
# 1970 tensor(0.9815, grad_fn=<AddBackward0>)
# 1980 tensor(1.0047, grad_fn=<AddBackward0>)
# 1990 tensor(0.9950, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 9 is bigger than 0.49030223 then go to left, else go to right
#     LEFT:
#     WHEN feature 12 is bigger than 0.30381402 then go to left, else go to right
#         LEFT:
#         WHEN feature 3 is bigger than -0.3982596 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
#         RIGHT:
#         WHEN feature 1 is bigger than 0.6293921 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 0
#     RIGHT:
#     WHEN feature 7 is bigger than 0.568928 then go to left, else go to right
#         LEFT:
#         WHEN feature 6 is bigger than 0.6596903 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 2 is bigger than -0.89936495 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.7626945126945127
# f1_score:
#  0.4326867231966547
# confusion_matrix:
#  [[3725    0]
#  [1159    0]]
# =============================================================
# (43958, 108) (43958, 1)
# (4884, 108) (4884, 1)
# LinearTree(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (linear1): Linear(in_features=108, out_features=64, bias=True)
#   (linear2): Linear(in_features=64, out_features=64, bias=True)
#   (linear3): Linear(in_features=64, out_features=64, bias=True)
#   (linear4): Linear(in_features=64, out_features=16, bias=True)
# )
# =============================================================
# {'batch_size': 512, 'focus_on_cont': True}
# Num Label: [33402 10556]
# Label Weight: [1.         3.16426677]
# 0 tensor(1.0524, grad_fn=<AddBackward0>)
# 10 tensor(1.0204, grad_fn=<AddBackward0>)
# 20 tensor(1.0215, grad_fn=<AddBackward0>)
# 30 tensor(1.0395, grad_fn=<AddBackward0>)
# 40 tensor(0.9711, grad_fn=<AddBackward0>)
# 50 tensor(1.0590, grad_fn=<AddBackward0>)
# 60 tensor(0.9825, grad_fn=<AddBackward0>)
# 70 tensor(0.9944, grad_fn=<AddBackward0>)
# 80 tensor(0.9882, grad_fn=<AddBackward0>)
# 90 tensor(1.0347, grad_fn=<AddBackward0>)
# 100 tensor(1.0609, grad_fn=<AddBackward0>)
# 110 tensor(0.9742, grad_fn=<AddBackward0>)
# 120 tensor(0.9905, grad_fn=<AddBackward0>)
# 130 tensor(1.0287, grad_fn=<AddBackward0>)
# 140 tensor(1.0164, grad_fn=<AddBackward0>)
# 150 tensor(1.0176, grad_fn=<AddBackward0>)
# 160 tensor(1.0225, grad_fn=<AddBackward0>)
# 170 tensor(0.9782, grad_fn=<AddBackward0>)
# 180 tensor(1.0355, grad_fn=<AddBackward0>)
# 190 tensor(1.0177, grad_fn=<AddBackward0>)
# 200 tensor(1.0172, grad_fn=<AddBackward0>)
# 210 tensor(1.0239, grad_fn=<AddBackward0>)
# 220 tensor(1.0067, grad_fn=<AddBackward0>)
# 230 tensor(1.0070, grad_fn=<AddBackward0>)
# 240 tensor(1.0126, grad_fn=<AddBackward0>)
# 250 tensor(1.0240, grad_fn=<AddBackward0>)
# 260 tensor(1.0371, grad_fn=<AddBackward0>)
# 270 tensor(0.9800, grad_fn=<AddBackward0>)
# 280 tensor(1.0549, grad_fn=<AddBackward0>)
# 290 tensor(1.0328, grad_fn=<AddBackward0>)
# 300 tensor(1.0128, grad_fn=<AddBackward0>)
# 310 tensor(1.0276, grad_fn=<AddBackward0>)
# 320 tensor(0.9942, grad_fn=<AddBackward0>)
# 330 tensor(0.9567, grad_fn=<AddBackward0>)
# 340 tensor(1.0201, grad_fn=<AddBackward0>)
# 350 tensor(1.0666, grad_fn=<AddBackward0>)
# 360 tensor(1.0394, grad_fn=<AddBackward0>)
# 370 tensor(1.0150, grad_fn=<AddBackward0>)
# 380 tensor(1.0490, grad_fn=<AddBackward0>)
# 390 tensor(1.0815, grad_fn=<AddBackward0>)
# 400 tensor(1.0068, grad_fn=<AddBackward0>)
# 410 tensor(1.0174, grad_fn=<AddBackward0>)
# 420 tensor(0.9743, grad_fn=<AddBackward0>)
# 430 tensor(1.0013, grad_fn=<AddBackward0>)
# 440 tensor(1.0059, grad_fn=<AddBackward0>)
# 450 tensor(1.0344, grad_fn=<AddBackward0>)
# 460 tensor(0.9900, grad_fn=<AddBackward0>)
# 470 tensor(1.0225, grad_fn=<AddBackward0>)
# 480 tensor(0.9777, grad_fn=<AddBackward0>)
# 490 tensor(1.0168, grad_fn=<AddBackward0>)
# 500 tensor(1.0181, grad_fn=<AddBackward0>)
# 510 tensor(1.0087, grad_fn=<AddBackward0>)
# 520 tensor(0.9915, grad_fn=<AddBackward0>)
# 530 tensor(1.0117, grad_fn=<AddBackward0>)
# 540 tensor(0.9994, grad_fn=<AddBackward0>)
# 550 tensor(1.0054, grad_fn=<AddBackward0>)
# 560 tensor(0.9376, grad_fn=<AddBackward0>)
# 570 tensor(1.0059, grad_fn=<AddBackward0>)
# 580 tensor(1.0594, grad_fn=<AddBackward0>)
# 590 tensor(0.9869, grad_fn=<AddBackward0>)
# 600 tensor(1.0421, grad_fn=<AddBackward0>)
# 610 tensor(0.9985, grad_fn=<AddBackward0>)
# 620 tensor(1.0370, grad_fn=<AddBackward0>)
# 630 tensor(1.0308, grad_fn=<AddBackward0>)
# 640 tensor(0.9670, grad_fn=<AddBackward0>)
# 650 tensor(1.0157, grad_fn=<AddBackward0>)
# 660 tensor(0.9969, grad_fn=<AddBackward0>)
# 670 tensor(1.0144, grad_fn=<AddBackward0>)
# 680 tensor(1.0101, grad_fn=<AddBackward0>)
# 690 tensor(0.9921, grad_fn=<AddBackward0>)
# 700 tensor(1.0579, grad_fn=<AddBackward0>)
# 710 tensor(1.0333, grad_fn=<AddBackward0>)
# 720 tensor(1.0721, grad_fn=<AddBackward0>)
# 730 tensor(1.0084, grad_fn=<AddBackward0>)
# 740 tensor(1.0181, grad_fn=<AddBackward0>)
# 750 tensor(0.9995, grad_fn=<AddBackward0>)
# 760 tensor(0.9895, grad_fn=<AddBackward0>)
# 770 tensor(0.9697, grad_fn=<AddBackward0>)
# 780 tensor(0.9915, grad_fn=<AddBackward0>)
# 790 tensor(0.9803, grad_fn=<AddBackward0>)
# 800 tensor(0.9556, grad_fn=<AddBackward0>)
# 810 tensor(0.9709, grad_fn=<AddBackward0>)
# 820 tensor(0.9856, grad_fn=<AddBackward0>)
# 830 tensor(0.9546, grad_fn=<AddBackward0>)
# 840 tensor(0.9839, grad_fn=<AddBackward0>)
# 850 tensor(1.0455, grad_fn=<AddBackward0>)
# 860 tensor(0.9496, grad_fn=<AddBackward0>)
# 870 tensor(1.0630, grad_fn=<AddBackward0>)
# 880 tensor(1.0047, grad_fn=<AddBackward0>)
# 890 tensor(1.0232, grad_fn=<AddBackward0>)
# 900 tensor(0.9633, grad_fn=<AddBackward0>)
# 910 tensor(1.0009, grad_fn=<AddBackward0>)
# 920 tensor(0.9694, grad_fn=<AddBackward0>)
# 930 tensor(1.0381, grad_fn=<AddBackward0>)
# 940 tensor(0.9681, grad_fn=<AddBackward0>)
# 950 tensor(1.0454, grad_fn=<AddBackward0>)
# 960 tensor(1.0214, grad_fn=<AddBackward0>)
# 970 tensor(0.9620, grad_fn=<AddBackward0>)
# ...
# 1050 tensor(0.9905, grad_fn=<AddBackward0>)
# 1060 tensor(0.9990, grad_fn=<AddBackward0>)
# 1070 tensor(1.0264, grad_fn=<AddBackward0>)
# 1080 tensor(1.0218, grad_fn=<AddBackward0>)
# 1090 tensor(0.9808, grad_fn=<AddBackward0>)
# 1100 tensor(0.9713, grad_fn=<AddBackward0>)
# 1110 tensor(0.9685, grad_fn=<AddBackward0>)
# 1120 tensor(1.0268, grad_fn=<AddBackward0>)
# 1130 tensor(1.0247, grad_fn=<AddBackward0>)
# 1140 tensor(1.0630, grad_fn=<AddBackward0>)
# 1150 tensor(0.9382, grad_fn=<AddBackward0>)
# 1160 tensor(1.0132, grad_fn=<AddBackward0>)
# 1170 tensor(0.9819, grad_fn=<AddBackward0>)
# 1180 tensor(1.0141, grad_fn=<AddBackward0>)
# 1190 tensor(0.9929, grad_fn=<AddBackward0>)
# 1200 tensor(0.9900, grad_fn=<AddBackward0>)
# 1210 tensor(1.0314, grad_fn=<AddBackward0>)
# 1220 tensor(1.0181, grad_fn=<AddBackward0>)
# 1230 tensor(1.0526, grad_fn=<AddBackward0>)
# 1240 tensor(0.9810, grad_fn=<AddBackward0>)
# 1250 tensor(1.0007, grad_fn=<AddBackward0>)
# 1260 tensor(0.9502, grad_fn=<AddBackward0>)
# 1270 tensor(0.9669, grad_fn=<AddBackward0>)
# 1280 tensor(0.9350, grad_fn=<AddBackward0>)
# 1290 tensor(1.0202, grad_fn=<AddBackward0>)
# 1300 tensor(1.0300, grad_fn=<AddBackward0>)
# 1310 tensor(1.0062, grad_fn=<AddBackward0>)
# 1320 tensor(1.0154, grad_fn=<AddBackward0>)
# 1330 tensor(0.9734, grad_fn=<AddBackward0>)
# 1340 tensor(1.0406, grad_fn=<AddBackward0>)
# 1350 tensor(1.0065, grad_fn=<AddBackward0>)
# 1360 tensor(1.0324, grad_fn=<AddBackward0>)
# 1370 tensor(0.9923, grad_fn=<AddBackward0>)
# 1380 tensor(0.9532, grad_fn=<AddBackward0>)
# 1390 tensor(0.9442, grad_fn=<AddBackward0>)
# 1400 tensor(1.0023, grad_fn=<AddBackward0>)
# 1410 tensor(0.9886, grad_fn=<AddBackward0>)
# 1420 tensor(1.0260, grad_fn=<AddBackward0>)
# 1430 tensor(1.0134, grad_fn=<AddBackward0>)
# 1440 tensor(1.0376, grad_fn=<AddBackward0>)
# 1450 tensor(1.0487, grad_fn=<AddBackward0>)
# 1460 tensor(0.9912, grad_fn=<AddBackward0>)
# 1470 tensor(1.0145, grad_fn=<AddBackward0>)
# 1480 tensor(1.0935, grad_fn=<AddBackward0>)
# 1490 tensor(0.9905, grad_fn=<AddBackward0>)
# 1500 tensor(1.0361, grad_fn=<AddBackward0>)
# 1510 tensor(1.0003, grad_fn=<AddBackward0>)
# 1520 tensor(1.0094, grad_fn=<AddBackward0>)
# 1530 tensor(0.9988, grad_fn=<AddBackward0>)
# 1540 tensor(1.0592, grad_fn=<AddBackward0>)
# 1550 tensor(0.9402, grad_fn=<AddBackward0>)
# 1560 tensor(1.0308, grad_fn=<AddBackward0>)
# 1570 tensor(1.0368, grad_fn=<AddBackward0>)
# 1580 tensor(1.1089, grad_fn=<AddBackward0>)
# 1590 tensor(1.0025, grad_fn=<AddBackward0>)
# 1600 tensor(1.0359, grad_fn=<AddBackward0>)
# 1610 tensor(1.0206, grad_fn=<AddBackward0>)
# 1620 tensor(1.0376, grad_fn=<AddBackward0>)
# 1630 tensor(1.0398, grad_fn=<AddBackward0>)
# 1640 tensor(0.9938, grad_fn=<AddBackward0>)
# 1650 tensor(0.9738, grad_fn=<AddBackward0>)
# 1660 tensor(1.0507, grad_fn=<AddBackward0>)
# 1670 tensor(1.0194, grad_fn=<AddBackward0>)
# 1680 tensor(0.9550, grad_fn=<AddBackward0>)
# 1690 tensor(1.0219, grad_fn=<AddBackward0>)
# 1700 tensor(0.9710, grad_fn=<AddBackward0>)
# 1710 tensor(0.9813, grad_fn=<AddBackward0>)
# 1720 tensor(0.9800, grad_fn=<AddBackward0>)
# 1730 tensor(1.0211, grad_fn=<AddBackward0>)
# 1740 tensor(0.9732, grad_fn=<AddBackward0>)
# 1750 tensor(1.0618, grad_fn=<AddBackward0>)
# 1760 tensor(1.0378, grad_fn=<AddBackward0>)
# 1770 tensor(0.9644, grad_fn=<AddBackward0>)
# 1780 tensor(1.0040, grad_fn=<AddBackward0>)
# 1790 tensor(1.0159, grad_fn=<AddBackward0>)
# 1800 tensor(1.0236, grad_fn=<AddBackward0>)
# 1810 tensor(0.9977, grad_fn=<AddBackward0>)
# 1820 tensor(1.0931, grad_fn=<AddBackward0>)
# 1830 tensor(1.0118, grad_fn=<AddBackward0>)
# 1840 tensor(0.8945, grad_fn=<AddBackward0>)
# 1850 tensor(1.0003, grad_fn=<AddBackward0>)
# 1860 tensor(1.0348, grad_fn=<AddBackward0>)
# 1870 tensor(1.0035, grad_fn=<AddBackward0>)
# 1880 tensor(1.0072, grad_fn=<AddBackward0>)
# 1890 tensor(0.9701, grad_fn=<AddBackward0>)
# 1900 tensor(1.0345, grad_fn=<AddBackward0>)
# 1910 tensor(1.0386, grad_fn=<AddBackward0>)
# 1920 tensor(0.9752, grad_fn=<AddBackward0>)
# 1930 tensor(0.9847, grad_fn=<AddBackward0>)
# 1940 tensor(1.0139, grad_fn=<AddBackward0>)
# 1950 tensor(1.0295, grad_fn=<AddBackward0>)
# 1960 tensor(0.9794, grad_fn=<AddBackward0>)
# 1970 tensor(1.0083, grad_fn=<AddBackward0>)
# 1980 tensor(0.9959, grad_fn=<AddBackward0>)
# 1990 tensor(1.1000, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 1 is bigger than 0.02253351 then go to left, else go to right
#     LEFT:
#     WHEN feature 13 is bigger than 0.07997708 then go to left, else go to right
#         LEFT:
#         WHEN feature 1 is bigger than 0.49629113 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
#         RIGHT:
#         WHEN feature 8 is bigger than 0.5665436 then go to left, else go to right
#             LEFT:
#             RETURN 1
#             RIGHT:
#             RETURN 0
#     RIGHT:
#     WHEN feature 14 is bigger than -0.24727213 then go to left, else go to right
#         LEFT:
#         WHEN feature 1 is bigger than -1.9813352 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
#         RIGHT:
#         WHEN feature 10 is bigger than 0.8254392 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
# accuracy:
#  0.7594185094185094
# f1_score:
#  0.43163039683463283
# confusion_matrix:
#  [[3709    0]
#  [1175    0]]
# =============================================================
# (43958, 108) (43958, 1)
# (4884, 108) (4884, 1)
# LinearTree(
#   (child_left): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (child_right): Node(
#     (child_left): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#     (child_right): Node(
#       (child_left): Node()
#       (child_right): Node()
#     )
#   )
#   (linear1): Linear(in_features=108, out_features=64, bias=True)
#   (linear2): Linear(in_features=64, out_features=64, bias=True)
#   (linear3): Linear(in_features=64, out_features=64, bias=True)
#   (linear4): Linear(in_features=64, out_features=16, bias=True)
# )
# =============================================================
# {'batch_size': 512, 'focus_on_cont': True}
# Num Label: [33410 10548]
# Label Weight: [1.        3.1674251]
# 0 tensor(1.0718, grad_fn=<AddBackward0>)
# 10 tensor(1.0163, grad_fn=<AddBackward0>)
# 20 tensor(1.0176, grad_fn=<AddBackward0>)
# 30 tensor(1.0021, grad_fn=<AddBackward0>)
# 40 tensor(1.0194, grad_fn=<AddBackward0>)
# 50 tensor(0.9752, grad_fn=<AddBackward0>)
# 60 tensor(1.0140, grad_fn=<AddBackward0>)
# 70 tensor(0.9792, grad_fn=<AddBackward0>)
# 80 tensor(1.0197, grad_fn=<AddBackward0>)
# 90 tensor(1.0167, grad_fn=<AddBackward0>)
# 100 tensor(1.0219, grad_fn=<AddBackward0>)
# 110 tensor(1.0014, grad_fn=<AddBackward0>)
# 120 tensor(1.0191, grad_fn=<AddBackward0>)
# 130 tensor(1.0182, grad_fn=<AddBackward0>)
# 140 tensor(1.0420, grad_fn=<AddBackward0>)
# 150 tensor(0.9968, grad_fn=<AddBackward0>)
# 160 tensor(1.0684, grad_fn=<AddBackward0>)
# 170 tensor(1.0699, grad_fn=<AddBackward0>)
# 180 tensor(1.0051, grad_fn=<AddBackward0>)
# 190 tensor(1.0129, grad_fn=<AddBackward0>)
# 200 tensor(1.0162, grad_fn=<AddBackward0>)
# 210 tensor(1.0172, grad_fn=<AddBackward0>)
# 220 tensor(1.0029, grad_fn=<AddBackward0>)
# 230 tensor(0.9731, grad_fn=<AddBackward0>)
# 240 tensor(0.9960, grad_fn=<AddBackward0>)
# 250 tensor(1.0454, grad_fn=<AddBackward0>)
# 260 tensor(1.0163, grad_fn=<AddBackward0>)
# 270 tensor(0.9988, grad_fn=<AddBackward0>)
# 280 tensor(1.0111, grad_fn=<AddBackward0>)
# 290 tensor(0.9749, grad_fn=<AddBackward0>)
# 300 tensor(0.9687, grad_fn=<AddBackward0>)
# 310 tensor(1.0075, grad_fn=<AddBackward0>)
# 320 tensor(1.0107, grad_fn=<AddBackward0>)
# 330 tensor(0.9507, grad_fn=<AddBackward0>)
# 340 tensor(0.9549, grad_fn=<AddBackward0>)
# 350 tensor(0.9882, grad_fn=<AddBackward0>)
# 360 tensor(1.0206, grad_fn=<AddBackward0>)
# 370 tensor(1.0323, grad_fn=<AddBackward0>)
# 380 tensor(1.0256, grad_fn=<AddBackward0>)
# 390 tensor(1.0131, grad_fn=<AddBackward0>)
# 400 tensor(0.9411, grad_fn=<AddBackward0>)
# 410 tensor(0.9639, grad_fn=<AddBackward0>)
# 420 tensor(0.9612, grad_fn=<AddBackward0>)
# 430 tensor(0.9893, grad_fn=<AddBackward0>)
# 440 tensor(0.9545, grad_fn=<AddBackward0>)
# 450 tensor(0.9973, grad_fn=<AddBackward0>)
# 460 tensor(0.9554, grad_fn=<AddBackward0>)
# 470 tensor(1.0152, grad_fn=<AddBackward0>)
# 480 tensor(1.0200, grad_fn=<AddBackward0>)
# 490 tensor(1.0480, grad_fn=<AddBackward0>)
# 500 tensor(0.9604, grad_fn=<AddBackward0>)
# 510 tensor(1.0018, grad_fn=<AddBackward0>)
# 520 tensor(0.9914, grad_fn=<AddBackward0>)
# 530 tensor(1.0065, grad_fn=<AddBackward0>)
# 540 tensor(0.9650, grad_fn=<AddBackward0>)
# 550 tensor(1.0056, grad_fn=<AddBackward0>)
# 560 tensor(1.0224, grad_fn=<AddBackward0>)
# 570 tensor(0.9648, grad_fn=<AddBackward0>)
# 580 tensor(0.9870, grad_fn=<AddBackward0>)
# 590 tensor(1.0164, grad_fn=<AddBackward0>)
# 600 tensor(1.0304, grad_fn=<AddBackward0>)
# 610 tensor(1.0319, grad_fn=<AddBackward0>)
# 620 tensor(1.0002, grad_fn=<AddBackward0>)
# 630 tensor(0.9986, grad_fn=<AddBackward0>)
# 640 tensor(0.9818, grad_fn=<AddBackward0>)
# 650 tensor(1.0479, grad_fn=<AddBackward0>)
# 660 tensor(0.9706, grad_fn=<AddBackward0>)
# 670 tensor(0.9738, grad_fn=<AddBackward0>)
# 680 tensor(1.0292, grad_fn=<AddBackward0>)
# 690 tensor(0.9993, grad_fn=<AddBackward0>)
# 700 tensor(0.9544, grad_fn=<AddBackward0>)
# 710 tensor(0.9902, grad_fn=<AddBackward0>)
# 720 tensor(0.9484, grad_fn=<AddBackward0>)
# 730 tensor(1.0025, grad_fn=<AddBackward0>)
# 740 tensor(0.9780, grad_fn=<AddBackward0>)
# 750 tensor(1.0164, grad_fn=<AddBackward0>)
# 760 tensor(1.0062, grad_fn=<AddBackward0>)
# 770 tensor(1.0316, grad_fn=<AddBackward0>)
# 780 tensor(1.0922, grad_fn=<AddBackward0>)
# 790 tensor(0.9538, grad_fn=<AddBackward0>)
# 800 tensor(1.0429, grad_fn=<AddBackward0>)
# 810 tensor(0.9778, grad_fn=<AddBackward0>)
# 820 tensor(1.0007, grad_fn=<AddBackward0>)
# 830 tensor(1.0129, grad_fn=<AddBackward0>)
# 840 tensor(1.0051, grad_fn=<AddBackward0>)
# 850 tensor(0.9948, grad_fn=<AddBackward0>)
# 860 tensor(0.9740, grad_fn=<AddBackward0>)
# 870 tensor(1.0500, grad_fn=<AddBackward0>)
# 880 tensor(0.9932, grad_fn=<AddBackward0>)
# 890 tensor(1.0312, grad_fn=<AddBackward0>)
# 900 tensor(0.9811, grad_fn=<AddBackward0>)
# 910 tensor(0.9593, grad_fn=<AddBackward0>)
# 920 tensor(1.0330, grad_fn=<AddBackward0>)
# 930 tensor(1.0199, grad_fn=<AddBackward0>)
# 940 tensor(1.0055, grad_fn=<AddBackward0>)
# 950 tensor(1.0007, grad_fn=<AddBackward0>)
# 960 tensor(0.9970, grad_fn=<AddBackward0>)
# 970 tensor(1.0406, grad_fn=<AddBackward0>)
# 980 tensor(0.9822, grad_fn=<AddBackward0>)
# 990 tensor(0.9811, grad_fn=<AddBackward0>)
# 1000 tensor(1.0286, grad_fn=<AddBackward0>)
# 1010 tensor(1.0277, grad_fn=<AddBackward0>)
# 1020 tensor(1.0292, grad_fn=<AddBackward0>)
# 1030 tensor(0.9319, grad_fn=<AddBackward0>)
# 1040 tensor(1.0171, grad_fn=<AddBackward0>)
# 1050 tensor(0.9570, grad_fn=<AddBackward0>)
# 1060 tensor(1.0307, grad_fn=<AddBackward0>)
# 1070 tensor(1.0245, grad_fn=<AddBackward0>)
# 1080 tensor(0.9801, grad_fn=<AddBackward0>)
# 1090 tensor(0.9653, grad_fn=<AddBackward0>)
# 1100 tensor(1.0377, grad_fn=<AddBackward0>)
# 1110 tensor(1.0045, grad_fn=<AddBackward0>)
# 1120 tensor(0.9523, grad_fn=<AddBackward0>)
# 1130 tensor(0.9651, grad_fn=<AddBackward0>)
# 1140 tensor(0.9800, grad_fn=<AddBackward0>)
# 1150 tensor(1.0240, grad_fn=<AddBackward0>)
# 1160 tensor(0.9644, grad_fn=<AddBackward0>)
# 1170 tensor(1.0165, grad_fn=<AddBackward0>)
# 1180 tensor(0.9656, grad_fn=<AddBackward0>)
# 1190 tensor(0.9531, grad_fn=<AddBackward0>)
# 1200 tensor(0.9844, grad_fn=<AddBackward0>)
# 1210 tensor(1.0351, grad_fn=<AddBackward0>)
# 1220 tensor(1.0461, grad_fn=<AddBackward0>)
# 1230 tensor(1.0018, grad_fn=<AddBackward0>)
# 1240 tensor(1.0810, grad_fn=<AddBackward0>)
# 1250 tensor(1.0137, grad_fn=<AddBackward0>)
# 1260 tensor(0.9909, grad_fn=<AddBackward0>)
# 1270 tensor(0.9822, grad_fn=<AddBackward0>)
# 1280 tensor(0.9970, grad_fn=<AddBackward0>)
# 1290 tensor(1.0047, grad_fn=<AddBackward0>)
# 1300 tensor(1.0015, grad_fn=<AddBackward0>)
# 1310 tensor(1.0059, grad_fn=<AddBackward0>)
# 1320 tensor(0.9867, grad_fn=<AddBackward0>)
# 1330 tensor(0.9534, grad_fn=<AddBackward0>)
# 1340 tensor(0.9737, grad_fn=<AddBackward0>)
# 1350 tensor(0.9936, grad_fn=<AddBackward0>)
# 1360 tensor(0.9691, grad_fn=<AddBackward0>)
# 1370 tensor(0.9747, grad_fn=<AddBackward0>)
# 1380 tensor(1.0704, grad_fn=<AddBackward0>)
# 1390 tensor(1.0612, grad_fn=<AddBackward0>)
# 1400 tensor(0.9760, grad_fn=<AddBackward0>)
# 1410 tensor(1.0146, grad_fn=<AddBackward0>)
# 1420 tensor(0.9793, grad_fn=<AddBackward0>)
# 1430 tensor(0.9938, grad_fn=<AddBackward0>)
# 1440 tensor(0.9586, grad_fn=<AddBackward0>)
# 1450 tensor(0.9795, grad_fn=<AddBackward0>)
# 1460 tensor(0.9961, grad_fn=<AddBackward0>)
# 1470 tensor(0.9795, grad_fn=<AddBackward0>)
# 1480 tensor(1.0628, grad_fn=<AddBackward0>)
# 1490 tensor(0.9441, grad_fn=<AddBackward0>)
# 1500 tensor(1.0075, grad_fn=<AddBackward0>)
# 1510 tensor(1.0301, grad_fn=<AddBackward0>)
# 1520 tensor(1.0029, grad_fn=<AddBackward0>)
# 1530 tensor(1.0116, grad_fn=<AddBackward0>)
# 1540 tensor(1.0347, grad_fn=<AddBackward0>)
# 1550 tensor(0.9423, grad_fn=<AddBackward0>)
# 1560 tensor(0.9696, grad_fn=<AddBackward0>)
# 1570 tensor(1.0355, grad_fn=<AddBackward0>)
# 1580 tensor(1.0439, grad_fn=<AddBackward0>)
# 1590 tensor(1.0004, grad_fn=<AddBackward0>)
# 1600 tensor(1.0192, grad_fn=<AddBackward0>)
# 1610 tensor(1.0056, grad_fn=<AddBackward0>)
# 1620 tensor(1.0266, grad_fn=<AddBackward0>)
# 1630 tensor(0.9986, grad_fn=<AddBackward0>)
# 1640 tensor(0.9718, grad_fn=<AddBackward0>)
# 1650 tensor(1.0155, grad_fn=<AddBackward0>)
# 1660 tensor(0.9608, grad_fn=<AddBackward0>)
# 1670 tensor(1.0232, grad_fn=<AddBackward0>)
# 1680 tensor(1.0526, grad_fn=<AddBackward0>)
# 1690 tensor(1.0093, grad_fn=<AddBackward0>)
# 1700 tensor(0.9852, grad_fn=<AddBackward0>)
# 1710 tensor(0.9935, grad_fn=<AddBackward0>)
# 1720 tensor(1.0429, grad_fn=<AddBackward0>)
# 1730 tensor(1.0131, grad_fn=<AddBackward0>)
# 1740 tensor(1.0237, grad_fn=<AddBackward0>)
# 1750 tensor(1.0378, grad_fn=<AddBackward0>)
# 1760 tensor(0.9574, grad_fn=<AddBackward0>)
# 1770 tensor(1.0397, grad_fn=<AddBackward0>)
# 1780 tensor(0.9806, grad_fn=<AddBackward0>)
# 1790 tensor(1.0000, grad_fn=<AddBackward0>)
# 1800 tensor(1.0550, grad_fn=<AddBackward0>)
# 1810 tensor(0.9406, grad_fn=<AddBackward0>)
# 1820 tensor(0.9417, grad_fn=<AddBackward0>)
# 1830 tensor(1.0686, grad_fn=<AddBackward0>)
# 1840 tensor(1.1381, grad_fn=<AddBackward0>)
# 1850 tensor(0.9760, grad_fn=<AddBackward0>)
# 1860 tensor(0.9580, grad_fn=<AddBackward0>)
# 1870 tensor(1.0243, grad_fn=<AddBackward0>)
# 1880 tensor(1.0300, grad_fn=<AddBackward0>)
# 1890 tensor(0.9344, grad_fn=<AddBackward0>)
# 1900 tensor(1.1075, grad_fn=<AddBackward0>)
# 1910 tensor(0.9715, grad_fn=<AddBackward0>)
# 1920 tensor(0.9875, grad_fn=<AddBackward0>)
# 1930 tensor(1.0129, grad_fn=<AddBackward0>)
# 1940 tensor(0.8964, grad_fn=<AddBackward0>)
# 1950 tensor(0.9782, grad_fn=<AddBackward0>)
# 1960 tensor(1.0677, grad_fn=<AddBackward0>)
# 1970 tensor(1.0479, grad_fn=<AddBackward0>)
# 1980 tensor(0.8930, grad_fn=<AddBackward0>)
# 1990 tensor(0.9661, grad_fn=<AddBackward0>)
# RULES:
#  WHEN feature 3 is bigger than 1.1686077 then go to left, else go to right
#     LEFT:
#     WHEN feature 13 is bigger than -0.0366271 then go to left, else go to right
#         LEFT:
#         WHEN feature 11 is bigger than -0.89997816 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 1
#         RIGHT:
#         WHEN feature 13 is bigger than -0.42125046 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#     RIGHT:
#     WHEN feature 15 is bigger than 0.45831457 then go to left, else go to right
#         LEFT:
#         WHEN feature 11 is bigger than 0.100530215 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
#         RIGHT:
#         WHEN feature 12 is bigger than -0.6022549 then go to left, else go to right
#             LEFT:
#             RETURN 0
#             RIGHT:
#             RETURN 0
# accuracy:
#  0.7667895167895168
# f1_score:
#  0.43400162243597173
# confusion_matrix:
#  [[3745    0]
#  [1139    0]]

# %%
print("accuracy:\n", np.array(all_results['accuracy']).mean())
print("f1_score:\n", np.array(all_results['f1_score']).mean())
print("confusion_matrix:\n", np.array(all_results['confusion_matrix']).mean(0))
# Out:
# accuracy:
#  0.7607084357084357
# f1_score:
#  0.43203432772852823
# confusion_matrix:
#  [[3715.3    0. ]
#  [1168.7    0. ]]

# %% [markdown]
# # Reference
# - Differentiable Decision Tree, https://proceedings.mlr.press/v108/silva20a/silva20a.pdf
# - Mixup Augmentation, https://arxiv.org/pdf/1710.09412
# - Straight-Throught Estimator, https://arxiv.org/abs/1308.3432
# - Adam Optimization, https://arxiv.org/abs/1412.6980
